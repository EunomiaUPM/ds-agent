# %% [markdown]
# # Preconditions
# `./setup_auth.ipynb` and `./setup_catalog_policies.ipynb`will run

# %%
# %run ./setup_catalog_policies.ipynb
# Out:
# /Users/apabook/Desktop/ds-protocol/static/tutorial/venv/bin/python
# {
#     "participant_id": "did:jwk:...",
#     "participant_slug": "Myself",
#     "participant_type": "Agent",
#     "base_url": "http://127.0.0.1:1200",
#     "token": null,
#     "saved_at": "2026-05-04T10:34:26.339988",
#     "last_interaction": "2026-05-05T12:03:36.530123",
#     "extra_fields": {},
#     "is_me": true
# }
# {
#     "participant_id": "did:jwk:...",
#     "participant_slug": "Myself",
#     "participant_type": "Agent",
#     "base_url": "http://127.0.0.1:1100",
#     "token": null,
#     "saved_at": "2026-05-04T10:34:26.414517",
#     "last_interaction": "2026-05-05T12:03:22.835236",
#     "extra_fields": {},
#     "is_me": true
# }
# Provider DID: did:jwk:...
#
# Provider token: TZHWnOtRj-esY4imsfdK9dNPavCoELr-AGfygGm2deY
#
# Consumer DID: did:jwk:...
#
# Consumer token: TZHWnOtRj-esY4imsfdK9dNPavCoELr-AGfygGm2deY
# {
#     "dctConformsTo": null,
#     "dctCreator": null,
#     "dctIdentifier": "urn:catalog:49b4b6d1-ce00-463c-9a28-1b757bd335c2",
#     "dctIssued": "2026-05-04T10:34:26.391164Z",
#     "dctModified": null,
#     "dctTitle": null,
#     "dspaceMainCatalog": true,
#     "dspaceParticipantId": "did:jwk:...",
#     "foafHomePage": null,
#     "id": "urn:catalog:49b4b6d1-ce00-463c-9a28-1b757bd335c2"
# }
# {
#     "catalogId": "urn:catalog:49b4b6d1-ce00-463c-9a28-1b757bd335c2",
#     "dcatEndpointDescription": null,
#     "dcatEndpointUrl": "http://127.0.0.1:1200/dsp/current",
#     "dctConformsTo": null,
#     "dctCreator": null,
#     "dctDescription": null,
#     "dctIdentifier": "urn:data-service:f2f1770a-36df-4c75-bf54-43447dc82025",
#     "dctIssued": "2026-05-04T10:34:26.480769Z",
#     "dctModified": null,
#     "dctTitle": null,
#     "dspaceMainDataService": true,
#     "id": "urn:data-service:f2f1770a-36df-4c75-bf54-43447dc82025"
# }
# {
#     "catalogId": "urn:catalog:49b4b6d1-ce00-463c-9a28-1b757bd335c2",
#     "dctConformsTo": null,
#     "dctCreator": null,
#     "dctDescription": null,
#     "dctIdentifier": "urn:dataset:714c33b6-23d1-4eab-82de-2f8474ebf07f",
#     "dctIssued": "2026-05-07T08:44:59.805309Z",
#     "dctModified": null,
#     "dctTitle": "My dataspace dataset",
#     "id": "urn:dataset:714c33b6-23d1-4eab-82de-2f8474ebf07f"
# }
# {
#     "datasetId": "urn:dataset:714c33b6-23d1-4eab-82de-2f8474ebf07f",
#     "dcatAccessService": "urn:data-service:f2f1770a-36df-4c75-bf54-43447dc82025",
#     "dctDescription": "This is the distribution of my dataset",
#     "dctFormat": "http+asd",
#     "dctIssued": "2026-05-07T08:44:59.886453Z",
#     "dctModified": null,
#     "dctTitle": "Distribution of my dataset",
#     "id": "urn:distribution:2800391a-4766-4285-99cd-89e714d86c63"
# }
# {
#     "datasetId": "urn:dataset:714c33b6-23d1-4eab-82de-2f8474ebf07f",
#     "dcatAccessService": "urn:data-service:f2f1770a-36df-4c75-bf54-43447dc82025",
#     "dctDescription": "This is the distribution of my streaming dataset",
#     "dctFormat": "http+pushing",
#     "dctIssued": "2026-05-07T08:44:59.899143Z",
#     "dctModified": null,
#     "dctTitle": "Distribution of a streaming dataset",
#     "id": "urn:distribution:7adb2e95-58d0-4b09-940d-546d0aadf378"
# }
# [
#     {
#         "author": "",
#         "content": {
#             "permission": [
#                 {
#                     "action": "use",
#                     "constraint": [
#                         {
#                             "leftOperand": "bla",
#                             "operator": "eq",
#                             "rightOperand": "$bla"
#                         }
#                     ]
#                 }
#             ]
#         },
#         "date": "2026-05-04T10:34:26.489731Z",
#         "description": "Mi example super policy",
#         "id": "policy-1",
#         "parameters": {
#             "$bla": {
#                 "dataType": "string",
#                 "restrictions": {},
#                 "ui": {
#                     "hidden": false
#                 }
#             }
#         },
#         "title": "Mi example policy",
#         "version": "1.0"
#     }
# ]
# {
#     "createdAt": "2026-05-07T08:44:59.916466Z",
#     "description": "Research access for UPM: grants read access to did:web:university.upm.es valid until 2025-12-31.",
#     "entity": "urn:dataset:714c33b6-23d1-4eab-82de-2f8474ebf07f",
#     "entityType": "Dataset",
#     "id": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#     "instantiationParameters": {
#         "$bla": "did:web:university.upm.es"
#     },
#     "odrlOffer": {
#         "permission": [
#             {
#                 "action": "use",
#                 "constraint": [
#                     {
#                         "leftOperand": "bla",
#                         "operator": "eq",
#                         "rightOperand": "did:web:university.upm.es"
#                     }
#                 ]
#             }
#         ]
#     },
#     "sourceTemplateId": "policy-1",
#     "sourceTemplateVersion": "1.0"
# }
# {
#     "createdAt": "2026-05-07T08:44:59.927903Z",
#     "description": "Commercial use licence valid for 2025: permits usage for commercial purposes with mandatory attribution. Derivation of the dataset is prohibited.",
#     "entity": "urn:dataset:714c33b6-23d1-4eab-82de-2f8474ebf07f",
#     "entityType": "Dataset",
#     "id": "urn:odrl-policy:d21f92da-8dcd-43ef-9f81-f3c6e8bf2990",
#     "instantiationParameters": null,
#     "odrlOffer": {
#         "obligation": [
#             {
#                 "action": "attribut",
#                 "constraint": [
#                     {
#                         "leftOperand": "recipient",
#                         "operator": "isA",
#                         "rightOperand": "public"
#                     }
#                 ]
#             }
#         ],
#         "permission": [
#             {
#                 "action": "use",
#                 "constraint": [
#                     {
#                         "leftOperand": "dateTime",
#                         "operator": "gteq",
#                         "rightOperand": "2025-01-01T00:00:00Z"
#                     },
#                     {
#                         "leftOperand": "dateTime",
#                         "operator": "lteq",
#                         "rightOperand": "2025-12-31T23:59:59Z"
#                     },
#                     {
#                         "leftOperand": "purpose",
#                         "operator": "isA",
#                         "rightOperand": "commercial"
#                     }
#                 ]
#             }
#         ],
#         "prohibition": [
#             {
#                 "action": "derive",
#                 "constraint": []
#             }
#         ]
#     },
#     "sourceTemplateId": null,
#     "sourceTemplateVersion": null
# }
# {
#     "createdAt": "2026-05-07T08:44:59.936618Z",
#     "description": "Research trial access (Mar\u2013Sep 2025): read-only, limited to 10 000 requests, restricted to research purposes. Redistribution and reproduction are prohibited.",
#     "entity": "urn:dataset:714c33b6-23d1-4eab-82de-2f8474ebf07f",
#     "entityType": "Dataset",
#     "id": "urn:odrl-policy:e4ec9d5a-11a7-4382-84c4-8769c06a96a6",
#     "instantiationParameters": null,
#     "odrlOffer": {
#         "obligation": [],
#         "permission": [
#             {
#                 "action": "read",
#                 "constraint": [
#                     {
#                         "leftOperand": "dateTime",
#                         "operator": "gteq",
#                         "rightOperand": "2025-03-01T00:00:00Z"
#                     },
#                     {
#                         "leftOperand": "dateTime",
#                         "operator": "lteq",
#                         "rightOperand": "2025-09-01T00:00:00Z"
#                     },
#                     {
#                         "leftOperand": "purpose",
#                         "operator": "isA",
#                         "rightOperand": "research"
#                     },
#                     {
#                         "leftOperand": "count",
#                         "operator": "lteq",
#                         "rightOperand": "10000"
#                     }
#                 ]
#             }
#         ],
#         "prohibition": [
#             {
#                 "action": "distribute",
#                 "constraint": []
#             },
#             {
#                 "action": "reproduce",
#                 "constraint": []
#             }
#         ]
#     },
#     "sourceTemplateId": null,
#     "sourceTemplateVersion": null
# }
# {
#     "name": "urn:connector-template:50048670-75f9-46cc-844a-67a26296cfe0",
#     "author": "admin",
#     "description": null,
#     "version": "1.0",
#     "createdAt": "2026-05-07T08:44:59.949276Z",
#     "authentication": {
#         "type": "NO_AUTH"
#     },
#     "interaction": {
#         "mode": "PULL",
#         "dataAccess": {
#             "protocol": "HTTP",
#             "urlTemplate": "{{__ACCESS_URL__}}",
#             "method": "{{__ACCESS_METHODS__}}",
#             "headers": "{{__ACCESS_HEADERS__}}",
#             "bodyTemplate": null
#         }
#     },
#     "parameters": [
#         {
#             "name": "ACCESS_URL",
#             "title": "Url",
#             "description": null,
#             "paramType": "STRING",
#             "required": true,
#             "defaultValue": null
#         },
#         {
#             "name": "ACCESS_METHODS",
#             "title": "Methods",
#             "description": null,
#             "paramType": "VEC<STRING>",
#             "required": true,
#             "defaultValue": null
#         },
#         {
#             "name": "ACCESS_HEADERS",
#             "title": "Headers",
#             "description": null,
#             "paramType": "MAP<STRING,STRING>",
#             "required": true,
#             "defaultValue": null
#         }
#     ]
# }
# {
#     "id": "urn:connector-instance:8d477c7e-d9d9-4d7d-a1b9-dbfe0c7ac454",
#     "name": "urn:connector-template:50048670-75f9-46cc-844a-67a26296cfe0",
#     "author": null,
#     "description": null,
#     "version": "1.0",
#     "createdAt": "2026-05-07T08:44:59.966382Z",
#     "authenticationConfig": {
#         "type": "NO_AUTH"
#     },
#     "interaction": {
#         "mode": "PULL",
#         "dataAccess": {
#             "protocol": "HTTP",
#             "urlTemplate": "http://127.0.0.1:8081",
#             "method": [
#                 "GET",
#                 "HEAD"
#             ],
#             "headers": {
#                 "Content-type": "application/json"
#             },
#             "bodyTemplate": null
#         }
#     },
#     "distributionId": "urn:distribution:2800391a-4766-4285-99cd-89e714d86c63"
# }
# {
#     "name": "urn:connector-template:49a70f9a-d679-4ebe-9802-662eb84fb015",
#     "author": "admin",
#     "description": null,
#     "version": "1.0",
#     "createdAt": "2026-05-07T08:45:00.028937Z",
#     "authentication": {
#         "type": "NO_AUTH"
#     },
#     "interaction": {
#         "mode": "PUSH",
#         "subscribe": {
#             "protocol": "HTTP",
#             "urlTemplate": "{{__SUB_URL__}}",
#             "method": "POST",
#             "headers": {},
#             "bodyTemplate": "{\"url\": \"{{__SYS_OWN_URL_DOCKER__}}{{__RUNTIME_INGRESS__}}\", \"event_type\": \"hotel_waste_generated\"}"
#         },
#         "unsubscribe": {
#             "protocol": "HTTP",
#             "urlTemplate": "{{__UNSUB_URL__}}/{{__RUNTIME_JSON_{.subscription.data.ID}__}}",
#             "method": "POST",
#             "headers": {},
#             "bodyTemplate": "{}"
#         }
#     },
#     "parameters": [
#         {
#             "name": "SUB_URL",
#             "title": "Subscription URL",
#             "description": null,
#             "paramType": "STRING",
#             "required": true,
#             "defaultValue": null
#         },
#         {
#             "name": "UNSUB_URL",
#             "title": "Unsubscription URL",
#             "description": null,
#             "paramType": "STRING",
#             "required": true,
#             "defaultValue": null
#         }
#     ]
# }
# {
#     "id": "urn:connector-instance:9c4e1416-f218-470a-a877-6959f1426626",
#     "name": "urn:connector-template:49a70f9a-d679-4ebe-9802-662eb84fb015",
#     "author": null,
#     "description": null,
#     "version": "1.0",
#     "createdAt": "2026-05-07T08:45:00.040231Z",
#     "authenticationConfig": {
#         "type": "NO_AUTH"
#     },
#     "interaction": {
#         "mode": "PUSH",
#         "subscribe": {
#             "protocol": "HTTP",
#             "urlTemplate": "http://127.0.0.1:8082/subscriptions/subscribe",
#             "method": "POST",
#             "headers": {},
#             "bodyTemplate": "{\"url\": \"http://host.docker.internal:1200{{__RUNTIME_INGRESS__}}\", \"event_type\": \"hotel_waste_generated\"}"
#         },
#         "unsubscribe": {
#             "protocol": "HTTP",
#             "urlTemplate": "http://127.0.0.1:8082/subscriptions/unsubscribe/{{__RUNTIME_JSON_{.subscription.data.ID}__}}",
#             "method": "POST",
#             "headers": {},
#             "bodyTemplate": "{}"
#         }
#     },
#     "distributionId": "urn:distribution:7adb2e95-58d0-4b09-940d-546d0aadf378"
# }
# Selected dataset target:
# urn:dataset:714c33b6-23d1-4eab-82de-2f8474ebf07f
#
# Selected policy id:
# urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e
#
# Provider negotiation URL for DSP 2025:
# http://127.0.0.1:1200/dsp/current
#
# Consumer callback address:
# http://127.0.0.1:1100/dsp/current

# %% [markdown]
# # Contract Negotiation

# %% [markdown]
# ## Initialization of negotiation request (Consumer -> Provider)

# %%
url = data_space_consumer + "/dsp/current/negotiations/rpc/setup-request-init"
payload = {
    "associatedAgentPeer": data_space_provider_participant_id,
    "providerAddress": data_space_provider_dsp_endpoint,
    "callbackAddress": data_space_consumer_dsp_endpoint,
    "offer": {
        "@id": policy_id,
        "target": target_id,
        "@type": "Offer",
        "permission": [
            {
                "action": "use", 
                "constraint": [{
                    "leftOperand": "count", 
                    "operator": "gt", 
                    "rightOperand": "18"
                }]
            }
        ]
    }
}




try:
    response = requests.request("POST", url, headers=json_header, data=json.dumps(payload))
    response_as_json = response.json()
    cn_consumer_id = response_as_json["response"]["consumerPid"]
    cn_provider_id = response_as_json["response"]["providerPid"]
    print(json.dumps(response_as_json, indent=2))
except Exception as e:
    print("Error in response, {}.".format(e))
# Out:
# {
#   "request": {
#     "associatedAgentPeer": "did:jwk:...",
#     "providerAddress": "http://127.0.0.1:1200/dsp/current",
#     "callbackAddress": "http://127.0.0.1:1100/dsp/current",
#     "offer": {
#       "@id": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#       "permission": [
#         {
#           "action": "use",
#           "constraint": [
#             {
#               "rightOperand": "18",
#               "leftOperand": "count",
#               "operator": "gt"
#             }
#           ]
#         }
#       ],
#       "@type": "Offer",
#       "target": "urn:dataset:714c33b6-23d1-4eab-82de-2f8474ebf07f"
#     }
#   },
#   "response": {
#     "@context": [
#       "https://w3id.org/dspace/2025/1/context.jsonld"
#     ],
#     "@type": "ContractNegotiation",
#     "consumerPid": "urn:consumer-pid:1d199a96-4988-4ef8-94db-97e3abbae34b",
#     "providerPid": "urn:provider-pid:44bf7aa3-b162-49e8-b94c-891b3e1fcfd8",
#     "state": "REQUESTED"
#   },
#   "negotiationAgentModel": {
#     "id": "urn:negotiation-process:c0797de0-4b93-475d-a0d5-8117c96d4aa1",
#     "state": "REQUESTED",
#     "stateAttribute": null,
#     "associatedAgentPeer": "did:jwk:...",
#     "protocol": "DSP",
#     "callbackAddress": "http://127.0.0.1:1200/dsp/current",
#     "role": "Consumer",
#     "properties": {},
#     "errorDetails": null,
#     "createdAt": "2026-05-07T08:45:00.179484Z",
#     "updatedAt": null,
#     "identifiers": {
#       "consumerPid": "urn:consumer-pid:1d199a96-4988-4ef8-94db-97e3abbae34b",
#       "providerPid": "urn:provider-pid:44bf7aa3-b162-49e8-b94c-891b3e1fcfd8"
#     },
#     "messages": [
#       {
#         "id": "urn:negotiation-message:f1ccb1e3-ac15-4e04-be4a-a05ac6e70932",
#         "negotiationAgentProcessId": "urn:negotiation-process:c0797de0-4b93-475d-a0d5-8117c96d4aa1",
#         "createdAt": "2026-05-07T08:45:00.282966Z",
#         "direction": "OUTBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractRequestMessage",
#         "stateTransitionFrom": "-",
#         "stateTransitionTo": "REQUESTED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractRequestMessage",
#           "associatedAgentPeer": "did:jwk:...",
#           "callbackAddress": "http://127.0.0.1:1100/dsp/current",
#           "offer": {
#             "@id": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#             "@type": "Offer",
#             "permission": [
#               {
#                 "action": "use",
#                 "constraint": [
#                   {
#                     "leftOperand": "count",
#                     "operator": "gt",
#                     "rightOperand": "18"
#                   }
#                 ]
#               }
#             ],
#             "target": "urn:dataset:714c33b6-23d1-4eab-82de-2f8474ebf07f"
#           },
#           "providerAddress": "http://127.0.0.1:1200/dsp/current"
#         }
#       }
#     ],
#     "offers": [
#       {
#         "id": "urn:offer:02e42c94-36ff-4a72-b006-ae99ae3f2df6",
#         "negotiationAgentProcessId": "urn:negotiation-process:c0797de0-4b93-475d-a0d5-8117c96d4aa1",
#         "negotiationAgentMessageId": "urn:negotiation-message:f1ccb1e3-ac15-4e04-be4a-a05ac6e70932",
#         "offerId": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#         "offerContent": {
#           "@id": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#           "@type": "Offer",
#           "permission": [
#             {
#               "action": "use",
#               "constraint": [
#                 {
#                   "leftOperand": "count",
#                   "operator": "gt",
#                   "rightOperand": "18"
#                 }
#               ]
#             }
#           ],
#           "target": "urn:dataset:714c33b6-23d1-4eab-82de-2f8474ebf07f"
#         },
#         "createdAt": "2026-05-07T08:45:00.285300Z"
#       }
#     ],
#     "agreement": null
#   }
# }

# %% [markdown]
# ## Provider creates initial offer (Provider -> Consumer)

# %%
# Provider creates initial offer (Provider -> Consumer)
url = data_space_provider + "/dsp/current/negotiations/rpc/setup-offer"
payload = {
    "consumerPid": cn_consumer_id,  # remove to test offer from provider
    "providerPid": cn_provider_id,  # remove to test offer from provider
    "offer": {
        "@id": policy_id,
        "target": target_id,
        "@type": "Offer",
        "permission": [
            {
                "action": "use", 
                "constraint": [{
                    "leftOperand": "count", 
                    "operator": "gt", 
                    "rightOperand": "21"
                }]
            }
        ]
    }
}
response = requests.request("POST", url, headers=json_header, data=json.dumps(payload))
response_as_json = response.json()
try:
    print(json.dumps(response_as_json, indent=2))
except KeyError:
    print("Error in response, check the payload and the endpoint.")
    print(json.dumps(response_as_json, indent=2))
    raise
# Out:
# {
#   "request": {
#     "offer": {
#       "@id": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#       "permission": [
#         {
#           "action": "use",
#           "constraint": [
#             {
#               "rightOperand": "21",
#               "leftOperand": "count",
#               "operator": "gt"
#             }
#           ]
#         }
#       ],
#       "@type": "Offer",
#       "target": "urn:dataset:714c33b6-23d1-4eab-82de-2f8474ebf07f"
#     },
#     "providerPid": "urn:provider-pid:44bf7aa3-b162-49e8-b94c-891b3e1fcfd8",
#     "consumerPid": "urn:consumer-pid:1d199a96-4988-4ef8-94db-97e3abbae34b"
#   },
#   "response": {
#     "@context": [
#       "https://w3id.org/dspace/2025/1/context.jsonld"
#     ],
#     "@type": "ContractNegotiation",
#     "consumerPid": "urn:consumer-pid:1d199a96-4988-4ef8-94db-97e3abbae34b",
#     "providerPid": "urn:provider-pid:44bf7aa3-b162-49e8-b94c-891b3e1fcfd8",
#     "state": "OFFERED"
#   },
#   "negotiationAgentModel": {
#     "id": "urn:negotiation-process:8fa54d41-d6a5-403f-913e-f2f185bb92ef",
#     "state": "OFFERED",
#     "stateAttribute": null,
#     "associatedAgentPeer": "did:jwk:...",
#     "protocol": "DSP",
#     "callbackAddress": "http://127.0.0.1:1100/dsp/current",
#     "role": "Provider",
#     "properties": {},
#     "errorDetails": null,
#     "createdAt": "2026-05-07T08:45:00.111951Z",
#     "updatedAt": "2026-05-07T08:45:00.352406Z",
#     "identifiers": {
#       "consumerPid": "urn:consumer-pid:1d199a96-4988-4ef8-94db-97e3abbae34b",
#       "providerPid": "urn:provider-pid:44bf7aa3-b162-49e8-b94c-891b3e1fcfd8"
#     },
#     "messages": [
#       {
#         "id": "urn:negotiation-message:4bccc5e6-1435-443c-a682-8bc032852445",
#         "negotiationAgentProcessId": "urn:negotiation-process:8fa54d41-d6a5-403f-913e-f2f185bb92ef",
#         "createdAt": "2026-05-07T08:45:00.173854Z",
#         "direction": "INBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractRequestMessage",
#         "stateTransitionFrom": "-",
#         "stateTransitionTo": "REQUESTED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractRequestMessage",
#           "callbackAddress": "http://127.0.0.1:1100/dsp/current",
#           "consumerPid": "urn:consumer-pid:1d199a96-4988-4ef8-94db-97e3abbae34b",
#           "offer": {
#             "@id": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#             "@type": "Offer",
#             "permission": [
#               {
#                 "action": "use",
#                 "constraint": [
#                   {
#                     "leftOperand": "count",
#                     "operator": "gt",
#                     "rightOperand": "18"
#                   }
#                 ]
#               }
#             ],
#             "target": "urn:dataset:714c33b6-23d1-4eab-82de-2f8474ebf07f"
#           }
#         }
#       },
#       {
#         "id": "urn:negotiation-message:943fa774-8573-472a-83cf-614958216f3c",
#         "negotiationAgentProcessId": "urn:negotiation-process:8fa54d41-d6a5-403f-913e-f2f185bb92ef",
#         "createdAt": "2026-05-07T08:45:00.357104Z",
#         "direction": "OUTBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractOfferMessage",
#         "stateTransitionFrom": "REQUESTED",
#         "stateTransitionTo": "OFFERED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractOfferMessage",
#           "consumerPid": "urn:consumer-pid:1d199a96-4988-4ef8-94db-97e3abbae34b",
#           "offer": {
#             "@id": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#             "@type": "Offer",
#             "permission": [
#               {
#                 "action": "use",
#                 "constraint": [
#                   {
#                     "leftOperand": "count",
#                     "operator": "gt",
#                     "rightOperand": "21"
#                   }
#                 ]
#               }
#             ],
#             "target": "urn:dataset:714c33b6-23d1-4eab-82de-2f8474ebf07f"
#           },
#           "providerPid": "urn:provider-pid:44bf7aa3-b162-49e8-b94c-891b3e1fcfd8"
#         }
#       }
#     ],
#     "offers": [
#       {
#         "id": "urn:offer:b2c6f28e-b404-40dd-b464-5872ab4243b1",
#         "negotiationAgentProcessId": "urn:negotiation-process:8fa54d41-d6a5-403f-913e-f2f185bb92ef",
#         "negotiationAgentMessageId": "urn:negotiation-message:4bccc5e6-1435-443c-a682-8bc032852445",
#         "offerId": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#         "offerContent": {
#           "@id": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#           "@type": "Offer",
#           "permission": [
#             {
#               "action": "use",
#               "constraint": [
#                 {
#                   "leftOperand": "count",
#                   "operator": "gt",
#                   "rightOperand": "18"
#                 }
#               ]
#             }
#           ],
#           "target": "urn:dataset:714c33b6-23d1-4eab-82de-2f8474ebf07f"
#         },
#         "createdAt": "2026-05-07T08:45:00.176584Z"
#       },
#       {
#         "id": "urn:offer:2142869b-e09b-42ba-ab0c-9ff3549b924f",
#         "negotiationAgentProcessId": "urn:negotiation-process:8fa54d41-d6a5-403f-913e-f2f185bb92ef",
#         "negotiationAgentMessageId": "urn:negotiation-message:943fa774-8573-472a-83cf-614958216f3c",
#         "offerId": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#         "offerContent": {
#           "@id": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#           "@type": "Offer",
#           "permission": [
#             {
#               "action": "use",
#               "constraint": [
#                 {
#                   "leftOperand": "count",
#                   "operator": "gt",
#                   "rightOperand": "21"
#                 }
#               ]
#             }
#           ],
#           "target": "urn:dataset:714c33b6-23d1-4eab-82de-2f8474ebf07f"
#         },
#         "createdAt": "2026-05-07T08:45:00.358711Z"
#       }
#     ],
#     "agreement": null
#   }
# }

# %% [markdown]
# ## Consumer sends negotiation request based on offer (Consumer -> Provider)

# %%
url = data_space_consumer + "/dsp/current/negotiations/rpc/setup-request"
payload = {
    "consumerPid": cn_consumer_id,
    "providerPid": cn_provider_id,
    "offer": {
        "@id": policy_id,
        "target": target_id,
        "@type": "Offer",
        "permission": [
            {
                "action": "use"

            }
        ]
    }
}
response = requests.request("POST", url, headers=json_header, data=json.dumps(payload))
response_as_json = response.json()
try:
    print(json.dumps(response_as_json, indent=2))
except KeyError:
    print("Error in response, check the payload and the endpoint.")
    print(json.dumps(response_as_json, indent=2))
    raise
# Out:
# {
#   "request": {
#     "offer": {
#       "@id": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#       "permission": [
#         {
#           "action": "use"
#         }
#       ],
#       "@type": "Offer",
#       "target": "urn:dataset:714c33b6-23d1-4eab-82de-2f8474ebf07f"
#     },
#     "providerPid": "urn:provider-pid:44bf7aa3-b162-49e8-b94c-891b3e1fcfd8",
#     "consumerPid": "urn:consumer-pid:1d199a96-4988-4ef8-94db-97e3abbae34b"
#   },
#   "response": {
#     "@context": [
#       "https://w3id.org/dspace/2025/1/context.jsonld"
#     ],
#     "@type": "ContractNegotiation",
#     "consumerPid": "urn:consumer-pid:1d199a96-4988-4ef8-94db-97e3abbae34b",
#     "providerPid": "urn:provider-pid:44bf7aa3-b162-49e8-b94c-891b3e1fcfd8",
#     "state": "REQUESTED"
#   },
#   "negotiationAgentModel": {
#     "id": "urn:negotiation-process:c0797de0-4b93-475d-a0d5-8117c96d4aa1",
#     "state": "REQUESTED",
#     "stateAttribute": null,
#     "associatedAgentPeer": "did:jwk:...",
#     "protocol": "DSP",
#     "callbackAddress": "http://127.0.0.1:1200/dsp/current",
#     "role": "Consumer",
#     "properties": {},
#     "errorDetails": null,
#     "createdAt": "2026-05-07T08:45:00.179484Z",
#     "updatedAt": "2026-05-07T08:45:00.418784Z",
#     "identifiers": {
#       "providerPid": "urn:provider-pid:44bf7aa3-b162-49e8-b94c-891b3e1fcfd8",
#       "consumerPid": "urn:consumer-pid:1d199a96-4988-4ef8-94db-97e3abbae34b"
#     },
#     "messages": [
#       {
#         "id": "urn:negotiation-message:f1ccb1e3-ac15-4e04-be4a-a05ac6e70932",
#         "negotiationAgentProcessId": "urn:negotiation-process:c0797de0-4b93-475d-a0d5-8117c96d4aa1",
#         "createdAt": "2026-05-07T08:45:00.282966Z",
#         "direction": "OUTBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractRequestMessage",
#         "stateTransitionFrom": "-",
#         "stateTransitionTo": "REQUESTED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractRequestMessage",
#           "associatedAgentPeer": "did:jwk:...",
#           "callbackAddress": "http://127.0.0.1:1100/dsp/current",
#           "offer": {
#             "@id": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#             "@type": "Offer",
#             "permission": [
#               {
#                 "action": "use",
#                 "constraint": [
#                   {
#                     "leftOperand": "count",
#                     "operator": "gt",
#                     "rightOperand": "18"
#                   }
#                 ]
#               }
#             ],
#             "target": "urn:dataset:714c33b6-23d1-4eab-82de-2f8474ebf07f"
#           },
#           "providerAddress": "http://127.0.0.1:1200/dsp/current"
#         }
#       },
#       {
#         "id": "urn:negotiation-message:8aa49de8-b29c-47b9-a4f1-ae74d8fefb0f",
#         "negotiationAgentProcessId": "urn:negotiation-process:c0797de0-4b93-475d-a0d5-8117c96d4aa1",
#         "createdAt": "2026-05-07T08:45:00.343550Z",
#         "direction": "INBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractOfferMessage",
#         "stateTransitionFrom": "REQUESTED",
#         "stateTransitionTo": "OFFERED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractOfferMessage",
#           "consumerPid": "urn:consumer-pid:1d199a96-4988-4ef8-94db-97e3abbae34b",
#           "offer": {
#             "@id": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#             "@type": "Offer",
#             "permission": [
#               {
#                 "action": "use",
#                 "constraint": [
#                   {
#                     "leftOperand": "count",
#                     "operator": "gt",
#                     "rightOperand": "21"
#                   }
#                 ]
#               }
#             ],
#             "target": "urn:dataset:714c33b6-23d1-4eab-82de-2f8474ebf07f"
#           },
#           "providerPid": "urn:provider-pid:44bf7aa3-b162-49e8-b94c-891b3e1fcfd8"
#         }
#       },
#       {
#         "id": "urn:negotiation-message:2e5de0a8-c0ae-4e67-a34d-fbbe64e8d6c9",
#         "negotiationAgentProcessId": "urn:negotiation-process:c0797de0-4b93-475d-a0d5-8117c96d4aa1",
#         "createdAt": "2026-05-07T08:45:00.422779Z",
#         "direction": "OUTBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractRequestMessage",
#         "stateTransitionFrom": "OFFERED",
#         "stateTransitionTo": "REQUESTED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractRequestMessage",
#           "consumerPid": "urn:consumer-pid:1d199a96-4988-4ef8-94db-97e3abbae34b",
#           "offer": {
#             "@id": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#             "@type": "Offer",
#             "permission": [
#               {
#                 "action": "use"
#               }
#             ],
#             "target": "urn:dataset:714c33b6-23d1-4eab-82de-2f8474ebf07f"
#           },
#           "providerPid": "urn:provider-pid:44bf7aa3-b162-49e8-b94c-891b3e1fcfd8"
#         }
#       }
#     ],
#     "offers": [
#       {
#         "id": "urn:offer:02e42c94-36ff-4a72-b006-ae99ae3f2df6",
#         "negotiationAgentProcessId": "urn:negotiation-process:c0797de0-4b93-475d-a0d5-8117c96d4aa1",
#         "negotiationAgentMessageId": "urn:negotiation-message:f1ccb1e3-ac15-4e04-be4a-a05ac6e70932",
#         "offerId": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#         "offerContent": {
#           "@id": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#           "@type": "Offer",
#           "permission": [
#             {
#               "action": "use",
#               "constraint": [
#                 {
#                   "leftOperand": "count",
#                   "operator": "gt",
#                   "rightOperand": "18"
#                 }
#               ]
#             }
#           ],
#           "target": "urn:dataset:714c33b6-23d1-4eab-82de-2f8474ebf07f"
#         },
#         "createdAt": "2026-05-07T08:45:00.285300Z"
#       },
#       {
#         "id": "urn:offer:029edd0f-d07b-4bcd-94d9-699b9f9d09b6",
#         "negotiationAgentProcessId": "urn:negotiation-process:c0797de0-4b93-475d-a0d5-8117c96d4aa1",
#         "negotiationAgentMessageId": "urn:negotiation-message:8aa49de8-b29c-47b9-a4f1-ae74d8fefb0f",
#         "offerId": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#         "offerContent": {
#           "@id": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#           "@type": "Offer",
#           "permission": [
#             {
#               "action": "use",
#               "constraint": [
#                 {
#                   "leftOperand": "count",
#                   "operator": "gt",
#                   "rightOperand": "21"
#                 }
#               ]
#             }
#           ],
#           "target": "urn:dataset:714c33b6-23d1-4eab-82de-2f8474ebf07f"
#         },
#         "createdAt": "2026-05-07T08:45:00.345318Z"
#       },
#       {
#         "id": "urn:offer:62f1bb24-832d-4742-8ad8-47c175b8c8b6",
#         "negotiationAgentProcessId": "urn:negotiation-process:c0797de0-4b93-475d-a0d5-8117c96d4aa1",
#         "negotiationAgentMessageId": "urn:negotiation-message:2e5de0a8-c0ae-4e67-a34d-fbbe64e8d6c9",
#         "offerId": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#         "offerContent": {
#           "@id": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#           "@type": "Offer",
#           "permission": [
#             {
#               "action": "use"
#             }
#           ],
#           "target": "urn:dataset:714c33b6-23d1-4eab-82de-2f8474ebf07f"
#         },
#         "createdAt": "2026-05-07T08:45:00.424046Z"
#       }
#     ],
#     "agreement": null
#   }
# }

# %% [markdown]
# ## Provider updates/confirms the offer (Provider -> Consumer)

# %%
url = data_space_provider + "/dsp/current/negotiations/rpc/setup-offer"
payload = {
    "consumerPid": cn_consumer_id,
    "providerPid": cn_provider_id,
    "offer": {
        "@id": policy_id,
        "target": target_id,
        "@type": "Offer",
        "permission": [
            {
                "action": "supermegause"
            }
        ]
    }
}
response = requests.request("POST", url, headers=json_header, data=json.dumps(payload))
response_as_json = response.json()
try:
    print(json.dumps(response_as_json, indent=2))
except KeyError:
    print("Error in response, check the payload and the endpoint.")
    print(json.dumps(response_as_json, indent=2))
    raise
# Out:
# {
#   "request": {
#     "offer": {
#       "@id": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#       "permission": [
#         {
#           "action": "supermegause"
#         }
#       ],
#       "@type": "Offer",
#       "target": "urn:dataset:714c33b6-23d1-4eab-82de-2f8474ebf07f"
#     },
#     "providerPid": "urn:provider-pid:44bf7aa3-b162-49e8-b94c-891b3e1fcfd8",
#     "consumerPid": "urn:consumer-pid:1d199a96-4988-4ef8-94db-97e3abbae34b"
#   },
#   "response": {
#     "@context": [
#       "https://w3id.org/dspace/2025/1/context.jsonld"
#     ],
#     "@type": "ContractNegotiation",
#     "consumerPid": "urn:consumer-pid:1d199a96-4988-4ef8-94db-97e3abbae34b",
#     "providerPid": "urn:provider-pid:44bf7aa3-b162-49e8-b94c-891b3e1fcfd8",
#     "state": "OFFERED"
#   },
#   "negotiationAgentModel": {
#     "id": "urn:negotiation-process:8fa54d41-d6a5-403f-913e-f2f185bb92ef",
#     "state": "OFFERED",
#     "stateAttribute": null,
#     "associatedAgentPeer": "did:jwk:...",
#     "protocol": "DSP",
#     "callbackAddress": "http://127.0.0.1:1100/dsp/current",
#     "role": "Provider",
#     "properties": {},
#     "errorDetails": null,
#     "createdAt": "2026-05-07T08:45:00.111951Z",
#     "updatedAt": "2026-05-07T08:45:00.489317Z",
#     "identifiers": {
#       "consumerPid": "urn:consumer-pid:1d199a96-4988-4ef8-94db-97e3abbae34b",
#       "providerPid": "urn:provider-pid:44bf7aa3-b162-49e8-b94c-891b3e1fcfd8"
#     },
#     "messages": [
#       {
#         "id": "urn:negotiation-message:4bccc5e6-1435-443c-a682-8bc032852445",
#         "negotiationAgentProcessId": "urn:negotiation-process:8fa54d41-d6a5-403f-913e-f2f185bb92ef",
#         "createdAt": "2026-05-07T08:45:00.173854Z",
#         "direction": "INBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractRequestMessage",
#         "stateTransitionFrom": "-",
#         "stateTransitionTo": "REQUESTED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractRequestMessage",
#           "callbackAddress": "http://127.0.0.1:1100/dsp/current",
#           "consumerPid": "urn:consumer-pid:1d199a96-4988-4ef8-94db-97e3abbae34b",
#           "offer": {
#             "@id": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#             "@type": "Offer",
#             "permission": [
#               {
#                 "action": "use",
#                 "constraint": [
#                   {
#                     "leftOperand": "count",
#                     "operator": "gt",
#                     "rightOperand": "18"
#                   }
#                 ]
#               }
#             ],
#             "target": "urn:dataset:714c33b6-23d1-4eab-82de-2f8474ebf07f"
#           }
#         }
#       },
#       {
#         "id": "urn:negotiation-message:943fa774-8573-472a-83cf-614958216f3c",
#         "negotiationAgentProcessId": "urn:negotiation-process:8fa54d41-d6a5-403f-913e-f2f185bb92ef",
#         "createdAt": "2026-05-07T08:45:00.357104Z",
#         "direction": "OUTBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractOfferMessage",
#         "stateTransitionFrom": "REQUESTED",
#         "stateTransitionTo": "OFFERED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractOfferMessage",
#           "consumerPid": "urn:consumer-pid:1d199a96-4988-4ef8-94db-97e3abbae34b",
#           "offer": {
#             "@id": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#             "@type": "Offer",
#             "permission": [
#               {
#                 "action": "use",
#                 "constraint": [
#                   {
#                     "leftOperand": "count",
#                     "operator": "gt",
#                     "rightOperand": "21"
#                   }
#                 ]
#               }
#             ],
#             "target": "urn:dataset:714c33b6-23d1-4eab-82de-2f8474ebf07f"
#           },
#           "providerPid": "urn:provider-pid:44bf7aa3-b162-49e8-b94c-891b3e1fcfd8"
#         }
#       },
#       {
#         "id": "urn:negotiation-message:66de81c1-5425-4fd2-9a3f-fff2d412e2b5",
#         "negotiationAgentProcessId": "urn:negotiation-process:8fa54d41-d6a5-403f-913e-f2f185bb92ef",
#         "createdAt": "2026-05-07T08:45:00.410826Z",
#         "direction": "INBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractRequestMessage",
#         "stateTransitionFrom": "OFFERED",
#         "stateTransitionTo": "REQUESTED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractRequestMessage",
#           "consumerPid": "urn:consumer-pid:1d199a96-4988-4ef8-94db-97e3abbae34b",
#           "offer": {
#             "@id": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#             "@type": "Offer",
#             "permission": [
#               {
#                 "action": "use"
#               }
#             ],
#             "target": "urn:dataset:714c33b6-23d1-4eab-82de-2f8474ebf07f"
#           },
#           "providerPid": "urn:provider-pid:44bf7aa3-b162-49e8-b94c-891b3e1fcfd8"
#         }
#       },
#       {
#         "id": "urn:negotiation-message:fbcb970e-af92-4b69-918f-b5b1f1eb40e3",
#         "negotiationAgentProcessId": "urn:negotiation-process:8fa54d41-d6a5-403f-913e-f2f185bb92ef",
#         "createdAt": "2026-05-07T08:45:00.497543Z",
#         "direction": "OUTBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractOfferMessage",
#         "stateTransitionFrom": "REQUESTED",
#         "stateTransitionTo": "OFFERED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractOfferMessage",
#           "consumerPid": "urn:consumer-pid:1d199a96-4988-4ef8-94db-97e3abbae34b",
#           "offer": {
#             "@id": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#             "@type": "Offer",
#             "permission": [
#               {
#                 "action": "supermegause"
#               }
#             ],
#             "target": "urn:dataset:714c33b6-23d1-4eab-82de-2f8474ebf07f"
#           },
#           "providerPid": "urn:provider-pid:44bf7aa3-b162-49e8-b94c-891b3e1fcfd8"
#         }
#       }
#     ],
#     "offers": [
#       {
#         "id": "urn:offer:b2c6f28e-b404-40dd-b464-5872ab4243b1",
#         "negotiationAgentProcessId": "urn:negotiation-process:8fa54d41-d6a5-403f-913e-f2f185bb92ef",
#         "negotiationAgentMessageId": "urn:negotiation-message:4bccc5e6-1435-443c-a682-8bc032852445",
#         "offerId": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#         "offerContent": {
#           "@id": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#           "@type": "Offer",
#           "permission": [
#             {
#               "action": "use",
#               "constraint": [
#                 {
#                   "leftOperand": "count",
#                   "operator": "gt",
#                   "rightOperand": "18"
#                 }
#               ]
#             }
#           ],
#           "target": "urn:dataset:714c33b6-23d1-4eab-82de-2f8474ebf07f"
#         },
#         "createdAt": "2026-05-07T08:45:00.176584Z"
#       },
#       {
#         "id": "urn:offer:2142869b-e09b-42ba-ab0c-9ff3549b924f",
#         "negotiationAgentProcessId": "urn:negotiation-process:8fa54d41-d6a5-403f-913e-f2f185bb92ef",
#         "negotiationAgentMessageId": "urn:negotiation-message:943fa774-8573-472a-83cf-614958216f3c",
#         "offerId": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#         "offerContent": {
#           "@id": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#           "@type": "Offer",
#           "permission": [
#             {
#               "action": "use",
#               "constraint": [
#                 {
#                   "leftOperand": "count",
#                   "operator": "gt",
#                   "rightOperand": "21"
#                 }
#               ]
#             }
#           ],
#           "target": "urn:dataset:714c33b6-23d1-4eab-82de-2f8474ebf07f"
#         },
#         "createdAt": "2026-05-07T08:45:00.358711Z"
#       },
#       {
#         "id": "urn:offer:796d43c4-8866-4c2b-9508-cf65eacad9c5",
#         "negotiationAgentProcessId": "urn:negotiation-process:8fa54d41-d6a5-403f-913e-f2f185bb92ef",
#         "negotiationAgentMessageId": "urn:negotiation-message:66de81c1-5425-4fd2-9a3f-fff2d412e2b5",
#         "offerId": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#         "offerContent": {
#           "@id": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#           "@type": "Offer",
#           "permission": [
#             {
#               "action": "use"
#             }
#           ],
#           "target": "urn:dataset:714c33b6-23d1-4eab-82de-2f8474ebf07f"
#         },
#         "createdAt": "2026-05-07T08:45:00.412071Z"
#       },
#       {
#         "id": "urn:offer:d3ad4217-8c99-4fd9-b218-df5c3913e007",
#         "negotiationAgentProcessId": "urn:negotiation-process:8fa54d41-d6a5-403f-913e-f2f185bb92ef",
#         "negotiationAgentMessageId": "urn:negotiation-message:fbcb970e-af92-4b69-918f-b5b1f1eb40e3",
#         "offerId": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#         "offerContent": {
#           "@id": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#           "@type": "Offer",
#           "permission": [
#             {
#               "action": "supermegause"
#             }
#           ],
#           "target": "urn:dataset:714c33b6-23d1-4eab-82de-2f8474ebf07f"
#         },
#         "createdAt": "2026-05-07T08:45:00.547244Z"
#       }
#     ],
#     "agreement": null
#   }
# }

# %% [markdown]
# ## Consumer accepts the offer (Consumer -> Provider)

# %%
url = data_space_consumer + "/dsp/current/negotiations/rpc/setup-acceptance"
payload = {
    "consumerPid": cn_consumer_id,
    "providerPid": cn_provider_id
}
response = requests.request("POST", url, headers=json_header, data=json.dumps(payload))
response_as_json = response.json()
try:
    print(json.dumps(response_as_json, indent=2))
except KeyError:
    print("Error in response, check the payload and the endpoint.")
    print(json.dumps(response_as_json, indent=2))
    raise
# Out:
# {
#   "request": {
#     "providerPid": "urn:provider-pid:44bf7aa3-b162-49e8-b94c-891b3e1fcfd8",
#     "consumerPid": "urn:consumer-pid:1d199a96-4988-4ef8-94db-97e3abbae34b"
#   },
#   "response": {
#     "@context": [
#       "https://w3id.org/dspace/2025/1/context.jsonld"
#     ],
#     "@type": "ContractNegotiation",
#     "consumerPid": "urn:consumer-pid:1d199a96-4988-4ef8-94db-97e3abbae34b",
#     "providerPid": "urn:provider-pid:44bf7aa3-b162-49e8-b94c-891b3e1fcfd8",
#     "state": "ACCEPTED"
#   },
#   "negotiationAgentModel": {
#     "id": "urn:negotiation-process:c0797de0-4b93-475d-a0d5-8117c96d4aa1",
#     "state": "ACCEPTED",
#     "stateAttribute": null,
#     "associatedAgentPeer": "did:jwk:...",
#     "protocol": "DSP",
#     "callbackAddress": "http://127.0.0.1:1200/dsp/current",
#     "role": "Consumer",
#     "properties": {},
#     "errorDetails": null,
#     "createdAt": "2026-05-07T08:45:00.179484Z",
#     "updatedAt": "2026-05-07T08:45:00.604705Z",
#     "identifiers": {
#       "providerPid": "urn:provider-pid:44bf7aa3-b162-49e8-b94c-891b3e1fcfd8",
#       "consumerPid": "urn:consumer-pid:1d199a96-4988-4ef8-94db-97e3abbae34b"
#     },
#     "messages": [
#       {
#         "id": "urn:negotiation-message:f1ccb1e3-ac15-4e04-be4a-a05ac6e70932",
#         "negotiationAgentProcessId": "urn:negotiation-process:c0797de0-4b93-475d-a0d5-8117c96d4aa1",
#         "createdAt": "2026-05-07T08:45:00.282966Z",
#         "direction": "OUTBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractRequestMessage",
#         "stateTransitionFrom": "-",
#         "stateTransitionTo": "REQUESTED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractRequestMessage",
#           "associatedAgentPeer": "did:jwk:...",
#           "callbackAddress": "http://127.0.0.1:1100/dsp/current",
#           "offer": {
#             "@id": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#             "@type": "Offer",
#             "permission": [
#               {
#                 "action": "use",
#                 "constraint": [
#                   {
#                     "leftOperand": "count",
#                     "operator": "gt",
#                     "rightOperand": "18"
#                   }
#                 ]
#               }
#             ],
#             "target": "urn:dataset:714c33b6-23d1-4eab-82de-2f8474ebf07f"
#           },
#           "providerAddress": "http://127.0.0.1:1200/dsp/current"
#         }
#       },
#       {
#         "id": "urn:negotiation-message:8aa49de8-b29c-47b9-a4f1-ae74d8fefb0f",
#         "negotiationAgentProcessId": "urn:negotiation-process:c0797de0-4b93-475d-a0d5-8117c96d4aa1",
#         "createdAt": "2026-05-07T08:45:00.343550Z",
#         "direction": "INBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractOfferMessage",
#         "stateTransitionFrom": "REQUESTED",
#         "stateTransitionTo": "OFFERED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractOfferMessage",
#           "consumerPid": "urn:consumer-pid:1d199a96-4988-4ef8-94db-97e3abbae34b",
#           "offer": {
#             "@id": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#             "@type": "Offer",
#             "permission": [
#               {
#                 "action": "use",
#                 "constraint": [
#                   {
#                     "leftOperand": "count",
#                     "operator": "gt",
#                     "rightOperand": "21"
#                   }
#                 ]
#               }
#             ],
#             "target": "urn:dataset:714c33b6-23d1-4eab-82de-2f8474ebf07f"
#           },
#           "providerPid": "urn:provider-pid:44bf7aa3-b162-49e8-b94c-891b3e1fcfd8"
#         }
#       },
#       {
#         "id": "urn:negotiation-message:2e5de0a8-c0ae-4e67-a34d-fbbe64e8d6c9",
#         "negotiationAgentProcessId": "urn:negotiation-process:c0797de0-4b93-475d-a0d5-8117c96d4aa1",
#         "createdAt": "2026-05-07T08:45:00.422779Z",
#         "direction": "OUTBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractRequestMessage",
#         "stateTransitionFrom": "OFFERED",
#         "stateTransitionTo": "REQUESTED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractRequestMessage",
#           "consumerPid": "urn:consumer-pid:1d199a96-4988-4ef8-94db-97e3abbae34b",
#           "offer": {
#             "@id": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#             "@type": "Offer",
#             "permission": [
#               {
#                 "action": "use"
#               }
#             ],
#             "target": "urn:dataset:714c33b6-23d1-4eab-82de-2f8474ebf07f"
#           },
#           "providerPid": "urn:provider-pid:44bf7aa3-b162-49e8-b94c-891b3e1fcfd8"
#         }
#       },
#       {
#         "id": "urn:negotiation-message:55c4e262-3e6f-4ac8-8e63-df12f0c87e98",
#         "negotiationAgentProcessId": "urn:negotiation-process:c0797de0-4b93-475d-a0d5-8117c96d4aa1",
#         "createdAt": "2026-05-07T08:45:00.480422Z",
#         "direction": "INBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractOfferMessage",
#         "stateTransitionFrom": "REQUESTED",
#         "stateTransitionTo": "OFFERED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractOfferMessage",
#           "consumerPid": "urn:consumer-pid:1d199a96-4988-4ef8-94db-97e3abbae34b",
#           "offer": {
#             "@id": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#             "@type": "Offer",
#             "permission": [
#               {
#                 "action": "supermegause"
#               }
#             ],
#             "target": "urn:dataset:714c33b6-23d1-4eab-82de-2f8474ebf07f"
#           },
#           "providerPid": "urn:provider-pid:44bf7aa3-b162-49e8-b94c-891b3e1fcfd8"
#         }
#       },
#       {
#         "id": "urn:negotiation-message:29fa2e17-c4d1-4514-af5c-f27c55b63675",
#         "negotiationAgentProcessId": "urn:negotiation-process:c0797de0-4b93-475d-a0d5-8117c96d4aa1",
#         "createdAt": "2026-05-07T08:45:00.608106Z",
#         "direction": "OUTBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractNegotiationEventMessage",
#         "stateTransitionFrom": "OFFERED",
#         "stateTransitionTo": "ACCEPTED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractNegotiationEventMessage",
#           "consumerPid": "urn:consumer-pid:1d199a96-4988-4ef8-94db-97e3abbae34b",
#           "providerPid": "urn:provider-pid:44bf7aa3-b162-49e8-b94c-891b3e1fcfd8"
#         }
#       }
#     ],
#     "offers": [
#       {
#         "id": "urn:offer:02e42c94-36ff-4a72-b006-ae99ae3f2df6",
#         "negotiationAgentProcessId": "urn:negotiation-process:c0797de0-4b93-475d-a0d5-8117c96d4aa1",
#         "negotiationAgentMessageId": "urn:negotiation-message:f1ccb1e3-ac15-4e04-be4a-a05ac6e70932",
#         "offerId": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#         "offerContent": {
#           "@id": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#           "@type": "Offer",
#           "permission": [
#             {
#               "action": "use",
#               "constraint": [
#                 {
#                   "leftOperand": "count",
#                   "operator": "gt",
#                   "rightOperand": "18"
#                 }
#               ]
#             }
#           ],
#           "target": "urn:dataset:714c33b6-23d1-4eab-82de-2f8474ebf07f"
#         },
#         "createdAt": "2026-05-07T08:45:00.285300Z"
#       },
#       {
#         "id": "urn:offer:029edd0f-d07b-4bcd-94d9-699b9f9d09b6",
#         "negotiationAgentProcessId": "urn:negotiation-process:c0797de0-4b93-475d-a0d5-8117c96d4aa1",
#         "negotiationAgentMessageId": "urn:negotiation-message:8aa49de8-b29c-47b9-a4f1-ae74d8fefb0f",
#         "offerId": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#         "offerContent": {
#           "@id": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#           "@type": "Offer",
#           "permission": [
#             {
#               "action": "use",
#               "constraint": [
#                 {
#                   "leftOperand": "count",
#                   "operator": "gt",
#                   "rightOperand": "21"
#                 }
#               ]
#             }
#           ],
#           "target": "urn:dataset:714c33b6-23d1-4eab-82de-2f8474ebf07f"
#         },
#         "createdAt": "2026-05-07T08:45:00.345318Z"
#       },
#       {
#         "id": "urn:offer:62f1bb24-832d-4742-8ad8-47c175b8c8b6",
#         "negotiationAgentProcessId": "urn:negotiation-process:c0797de0-4b93-475d-a0d5-8117c96d4aa1",
#         "negotiationAgentMessageId": "urn:negotiation-message:2e5de0a8-c0ae-4e67-a34d-fbbe64e8d6c9",
#         "offerId": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#         "offerContent": {
#           "@id": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#           "@type": "Offer",
#           "permission": [
#             {
#               "action": "use"
#             }
#           ],
#           "target": "urn:dataset:714c33b6-23d1-4eab-82de-2f8474ebf07f"
#         },
#         "createdAt": "2026-05-07T08:45:00.424046Z"
#       },
#       {
#         "id": "urn:offer:c3880c6c-16bb-4aaa-b44a-7f883a61dee2",
#         "negotiationAgentProcessId": "urn:negotiation-process:c0797de0-4b93-475d-a0d5-8117c96d4aa1",
#         "negotiationAgentMessageId": "urn:negotiation-message:55c4e262-3e6f-4ac8-8e63-df12f0c87e98",
#         "offerId": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#         "offerContent": {
#           "@id": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#           "@type": "Offer",
#           "permission": [
#             {
#               "action": "supermegause"
#             }
#           ],
#           "target": "urn:dataset:714c33b6-23d1-4eab-82de-2f8474ebf07f"
#         },
#         "createdAt": "2026-05-07T08:45:00.481851Z"
#       }
#     ],
#     "agreement": null
#   }
# }

# %% [markdown]
# ## Provider creates the Agreement (Provider -> Consumer)

# %%
url = data_space_provider + "/dsp/current/negotiations/rpc/setup-agreement"
payload = {
    "consumerPid": cn_consumer_id,
    "providerPid": cn_provider_id
}
response = requests.request("POST", url, headers=json_header, data=json.dumps(payload))
response_as_json = response.json()
try:
    print(json.dumps(response_as_json, indent=2))
except KeyError:
    print("Error in response, check the payload and the endpoint.")
    print(json.dumps(response_as_json, indent=2))
    raise
# Out:
# {
#   "request": {
#     "providerPid": "urn:provider-pid:44bf7aa3-b162-49e8-b94c-891b3e1fcfd8",
#     "consumerPid": "urn:consumer-pid:1d199a96-4988-4ef8-94db-97e3abbae34b"
#   },
#   "response": {
#     "@context": [
#       "https://w3id.org/dspace/2025/1/context.jsonld"
#     ],
#     "@type": "ContractNegotiation",
#     "consumerPid": "urn:consumer-pid:1d199a96-4988-4ef8-94db-97e3abbae34b",
#     "providerPid": "urn:provider-pid:44bf7aa3-b162-49e8-b94c-891b3e1fcfd8",
#     "state": "AGREED"
#   },
#   "negotiationAgentModel": {
#     "id": "urn:negotiation-process:8fa54d41-d6a5-403f-913e-f2f185bb92ef",
#     "state": "AGREED",
#     "stateAttribute": null,
#     "associatedAgentPeer": "did:jwk:...",
#     "protocol": "DSP",
#     "callbackAddress": "http://127.0.0.1:1100/dsp/current",
#     "role": "Provider",
#     "properties": {},
#     "errorDetails": null,
#     "createdAt": "2026-05-07T08:45:00.111951Z",
#     "updatedAt": "2026-05-07T08:45:00.662164Z",
#     "identifiers": {
#       "consumerPid": "urn:consumer-pid:1d199a96-4988-4ef8-94db-97e3abbae34b",
#       "providerPid": "urn:provider-pid:44bf7aa3-b162-49e8-b94c-891b3e1fcfd8"
#     },
#     "messages": [
#       {
#         "id": "urn:negotiation-message:4bccc5e6-1435-443c-a682-8bc032852445",
#         "negotiationAgentProcessId": "urn:negotiation-process:8fa54d41-d6a5-403f-913e-f2f185bb92ef",
#         "createdAt": "2026-05-07T08:45:00.173854Z",
#         "direction": "INBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractRequestMessage",
#         "stateTransitionFrom": "-",
#         "stateTransitionTo": "REQUESTED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractRequestMessage",
#           "callbackAddress": "http://127.0.0.1:1100/dsp/current",
#           "consumerPid": "urn:consumer-pid:1d199a96-4988-4ef8-94db-97e3abbae34b",
#           "offer": {
#             "@id": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#             "@type": "Offer",
#             "permission": [
#               {
#                 "action": "use",
#                 "constraint": [
#                   {
#                     "leftOperand": "count",
#                     "operator": "gt",
#                     "rightOperand": "18"
#                   }
#                 ]
#               }
#             ],
#             "target": "urn:dataset:714c33b6-23d1-4eab-82de-2f8474ebf07f"
#           }
#         }
#       },
#       {
#         "id": "urn:negotiation-message:943fa774-8573-472a-83cf-614958216f3c",
#         "negotiationAgentProcessId": "urn:negotiation-process:8fa54d41-d6a5-403f-913e-f2f185bb92ef",
#         "createdAt": "2026-05-07T08:45:00.357104Z",
#         "direction": "OUTBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractOfferMessage",
#         "stateTransitionFrom": "REQUESTED",
#         "stateTransitionTo": "OFFERED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractOfferMessage",
#           "consumerPid": "urn:consumer-pid:1d199a96-4988-4ef8-94db-97e3abbae34b",
#           "offer": {
#             "@id": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#             "@type": "Offer",
#             "permission": [
#               {
#                 "action": "use",
#                 "constraint": [
#                   {
#                     "leftOperand": "count",
#                     "operator": "gt",
#                     "rightOperand": "21"
#                   }
#                 ]
#               }
#             ],
#             "target": "urn:dataset:714c33b6-23d1-4eab-82de-2f8474ebf07f"
#           },
#           "providerPid": "urn:provider-pid:44bf7aa3-b162-49e8-b94c-891b3e1fcfd8"
#         }
#       },
#       {
#         "id": "urn:negotiation-message:66de81c1-5425-4fd2-9a3f-fff2d412e2b5",
#         "negotiationAgentProcessId": "urn:negotiation-process:8fa54d41-d6a5-403f-913e-f2f185bb92ef",
#         "createdAt": "2026-05-07T08:45:00.410826Z",
#         "direction": "INBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractRequestMessage",
#         "stateTransitionFrom": "OFFERED",
#         "stateTransitionTo": "REQUESTED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractRequestMessage",
#           "consumerPid": "urn:consumer-pid:1d199a96-4988-4ef8-94db-97e3abbae34b",
#           "offer": {
#             "@id": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#             "@type": "Offer",
#             "permission": [
#               {
#                 "action": "use"
#               }
#             ],
#             "target": "urn:dataset:714c33b6-23d1-4eab-82de-2f8474ebf07f"
#           },
#           "providerPid": "urn:provider-pid:44bf7aa3-b162-49e8-b94c-891b3e1fcfd8"
#         }
#       },
#       {
#         "id": "urn:negotiation-message:fbcb970e-af92-4b69-918f-b5b1f1eb40e3",
#         "negotiationAgentProcessId": "urn:negotiation-process:8fa54d41-d6a5-403f-913e-f2f185bb92ef",
#         "createdAt": "2026-05-07T08:45:00.497543Z",
#         "direction": "OUTBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractOfferMessage",
#         "stateTransitionFrom": "REQUESTED",
#         "stateTransitionTo": "OFFERED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractOfferMessage",
#           "consumerPid": "urn:consumer-pid:1d199a96-4988-4ef8-94db-97e3abbae34b",
#           "offer": {
#             "@id": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#             "@type": "Offer",
#             "permission": [
#               {
#                 "action": "supermegause"
#               }
#             ],
#             "target": "urn:dataset:714c33b6-23d1-4eab-82de-2f8474ebf07f"
#           },
#           "providerPid": "urn:provider-pid:44bf7aa3-b162-49e8-b94c-891b3e1fcfd8"
#         }
#       },
#       {
#         "id": "urn:negotiation-message:1c1f2e93-a8ab-480f-b01d-7f16db17af0d",
#         "negotiationAgentProcessId": "urn:negotiation-process:8fa54d41-d6a5-403f-913e-f2f185bb92ef",
#         "createdAt": "2026-05-07T08:45:00.598172Z",
#         "direction": "INBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractNegotiationEventMessage",
#         "stateTransitionFrom": "OFFERED",
#         "stateTransitionTo": "ACCEPTED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractNegotiationEventMessage",
#           "consumerPid": "urn:consumer-pid:1d199a96-4988-4ef8-94db-97e3abbae34b",
#           "eventType": "ACCEPTED",
#           "providerPid": "urn:provider-pid:44bf7aa3-b162-49e8-b94c-891b3e1fcfd8"
#         }
#       },
#       {
#         "id": "urn:negotiation-message:238105ec-5c05-4e0a-b0b1-faf8c8f42dd7",
#         "negotiationAgentProcessId": "urn:negotiation-process:8fa54d41-d6a5-403f-913e-f2f185bb92ef",
#         "createdAt": "2026-05-07T08:45:00.665419Z",
#         "direction": "OUTBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractAgreementMessage",
#         "stateTransitionFrom": "ACCEPTED",
#         "stateTransitionTo": "AGREED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractAgreementMessage",
#           "consumerPid": "urn:consumer-pid:1d199a96-4988-4ef8-94db-97e3abbae34b",
#           "providerPid": "urn:provider-pid:44bf7aa3-b162-49e8-b94c-891b3e1fcfd8"
#         }
#       }
#     ],
#     "offers": [
#       {
#         "id": "urn:offer:b2c6f28e-b404-40dd-b464-5872ab4243b1",
#         "negotiationAgentProcessId": "urn:negotiation-process:8fa54d41-d6a5-403f-913e-f2f185bb92ef",
#         "negotiationAgentMessageId": "urn:negotiation-message:4bccc5e6-1435-443c-a682-8bc032852445",
#         "offerId": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#         "offerContent": {
#           "@id": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#           "@type": "Offer",
#           "permission": [
#             {
#               "action": "use",
#               "constraint": [
#                 {
#                   "leftOperand": "count",
#                   "operator": "gt",
#                   "rightOperand": "18"
#                 }
#               ]
#             }
#           ],
#           "target": "urn:dataset:714c33b6-23d1-4eab-82de-2f8474ebf07f"
#         },
#         "createdAt": "2026-05-07T08:45:00.176584Z"
#       },
#       {
#         "id": "urn:offer:2142869b-e09b-42ba-ab0c-9ff3549b924f",
#         "negotiationAgentProcessId": "urn:negotiation-process:8fa54d41-d6a5-403f-913e-f2f185bb92ef",
#         "negotiationAgentMessageId": "urn:negotiation-message:943fa774-8573-472a-83cf-614958216f3c",
#         "offerId": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#         "offerContent": {
#           "@id": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#           "@type": "Offer",
#           "permission": [
#             {
#               "action": "use",
#               "constraint": [
#                 {
#                   "leftOperand": "count",
#                   "operator": "gt",
#                   "rightOperand": "21"
#                 }
#               ]
#             }
#           ],
#           "target": "urn:dataset:714c33b6-23d1-4eab-82de-2f8474ebf07f"
#         },
#         "createdAt": "2026-05-07T08:45:00.358711Z"
#       },
#       {
#         "id": "urn:offer:796d43c4-8866-4c2b-9508-cf65eacad9c5",
#         "negotiationAgentProcessId": "urn:negotiation-process:8fa54d41-d6a5-403f-913e-f2f185bb92ef",
#         "negotiationAgentMessageId": "urn:negotiation-message:66de81c1-5425-4fd2-9a3f-fff2d412e2b5",
#         "offerId": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#         "offerContent": {
#           "@id": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#           "@type": "Offer",
#           "permission": [
#             {
#               "action": "use"
#             }
#           ],
#           "target": "urn:dataset:714c33b6-23d1-4eab-82de-2f8474ebf07f"
#         },
#         "createdAt": "2026-05-07T08:45:00.412071Z"
#       },
#       {
#         "id": "urn:offer:d3ad4217-8c99-4fd9-b218-df5c3913e007",
#         "negotiationAgentProcessId": "urn:negotiation-process:8fa54d41-d6a5-403f-913e-f2f185bb92ef",
#         "negotiationAgentMessageId": "urn:negotiation-message:fbcb970e-af92-4b69-918f-b5b1f1eb40e3",
#         "offerId": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#         "offerContent": {
#           "@id": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#           "@type": "Offer",
#           "permission": [
#             {
#               "action": "supermegause"
#             }
#           ],
#           "target": "urn:dataset:714c33b6-23d1-4eab-82de-2f8474ebf07f"
#         },
#         "createdAt": "2026-05-07T08:45:00.547244Z"
#       }
#     ],
#     "agreement": {
#       "id": "urn:agreement:04b2ecf6-22a4-4f46-8a4d-65c3f0af3c1b",
#       "negotiationAgentProcessId": "urn:negotiation-process:8fa54d41-d6a5-403f-913e-f2f185bb92ef",
#       "negotiationAgentMessageId": "urn:negotiation-message:238105ec-5c05-4e0a-b0b1-faf8c8f42dd7",
#       "consumerParticipantId": "did:jwk:...",
#       "providerParticipantId": "did:jwk:...",
#       "agreementContent": {
#         "@id": "urn:agreement:04b2ecf6-22a4-4f46-8a4d-65c3f0af3c1b",
#         "@type": "Agreement",
#         "assignee": "did:jwk:...",
#         "assigner": "did:jwk:...",
#         "permission": [
#           {
#             "action": "supermegause"
#           }
#         ],
#         "target": "urn:dataset:714c33b6-23d1-4eab-82de-2f8474ebf07f",
#         "timestamp": "1778143500"
#       },
#       "target": "urn:dataset:714c33b6-23d1-4eab-82de-2f8474ebf07f",
#       "state": "REQUESTED",
#       "createdAt": "2026-05-07T08:45:00.666325Z",
#       "updatedAt": null
#     }
#   }
# }

# %% [markdown]
# ## Consumer verifies the agreement (Consumer -> Provider)

# %%
url = data_space_consumer + "/dsp/current/negotiations/rpc/setup-verification"
payload = {
    "consumerPid": cn_consumer_id,
    "providerPid": cn_provider_id
}
response = requests.request("POST", url, headers=json_header, data=json.dumps(payload))
response_as_json = response.json()
try:
    print(json.dumps(response_as_json, indent=2))
except KeyError:
    print("Error in response, check the payload and the endpoint.")
    print(json.dumps(response_as_json, indent=2))
    raise
# Out:
# {
#   "request": {
#     "providerPid": "urn:provider-pid:44bf7aa3-b162-49e8-b94c-891b3e1fcfd8",
#     "consumerPid": "urn:consumer-pid:1d199a96-4988-4ef8-94db-97e3abbae34b"
#   },
#   "response": {
#     "@context": [
#       "https://w3id.org/dspace/2025/1/context.jsonld"
#     ],
#     "@type": "ContractNegotiation",
#     "consumerPid": "urn:consumer-pid:1d199a96-4988-4ef8-94db-97e3abbae34b",
#     "providerPid": "urn:provider-pid:44bf7aa3-b162-49e8-b94c-891b3e1fcfd8",
#     "state": "VERIFIED"
#   },
#   "negotiationAgentModel": {
#     "id": "urn:negotiation-process:c0797de0-4b93-475d-a0d5-8117c96d4aa1",
#     "state": "VERIFIED",
#     "stateAttribute": null,
#     "associatedAgentPeer": "did:jwk:...",
#     "protocol": "DSP",
#     "callbackAddress": "http://127.0.0.1:1200/dsp/current",
#     "role": "Consumer",
#     "properties": {},
#     "errorDetails": null,
#     "createdAt": "2026-05-07T08:45:00.179484Z",
#     "updatedAt": "2026-05-07T08:45:00.721471Z",
#     "identifiers": {
#       "consumerPid": "urn:consumer-pid:1d199a96-4988-4ef8-94db-97e3abbae34b",
#       "providerPid": "urn:provider-pid:44bf7aa3-b162-49e8-b94c-891b3e1fcfd8"
#     },
#     "messages": [
#       {
#         "id": "urn:negotiation-message:f1ccb1e3-ac15-4e04-be4a-a05ac6e70932",
#         "negotiationAgentProcessId": "urn:negotiation-process:c0797de0-4b93-475d-a0d5-8117c96d4aa1",
#         "createdAt": "2026-05-07T08:45:00.282966Z",
#         "direction": "OUTBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractRequestMessage",
#         "stateTransitionFrom": "-",
#         "stateTransitionTo": "REQUESTED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractRequestMessage",
#           "associatedAgentPeer": "did:jwk:...",
#           "callbackAddress": "http://127.0.0.1:1100/dsp/current",
#           "offer": {
#             "@id": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#             "@type": "Offer",
#             "permission": [
#               {
#                 "action": "use",
#                 "constraint": [
#                   {
#                     "leftOperand": "count",
#                     "operator": "gt",
#                     "rightOperand": "18"
#                   }
#                 ]
#               }
#             ],
#             "target": "urn:dataset:714c33b6-23d1-4eab-82de-2f8474ebf07f"
#           },
#           "providerAddress": "http://127.0.0.1:1200/dsp/current"
#         }
#       },
#       {
#         "id": "urn:negotiation-message:8aa49de8-b29c-47b9-a4f1-ae74d8fefb0f",
#         "negotiationAgentProcessId": "urn:negotiation-process:c0797de0-4b93-475d-a0d5-8117c96d4aa1",
#         "createdAt": "2026-05-07T08:45:00.343550Z",
#         "direction": "INBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractOfferMessage",
#         "stateTransitionFrom": "REQUESTED",
#         "stateTransitionTo": "OFFERED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractOfferMessage",
#           "consumerPid": "urn:consumer-pid:1d199a96-4988-4ef8-94db-97e3abbae34b",
#           "offer": {
#             "@id": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#             "@type": "Offer",
#             "permission": [
#               {
#                 "action": "use",
#                 "constraint": [
#                   {
#                     "leftOperand": "count",
#                     "operator": "gt",
#                     "rightOperand": "21"
#                   }
#                 ]
#               }
#             ],
#             "target": "urn:dataset:714c33b6-23d1-4eab-82de-2f8474ebf07f"
#           },
#           "providerPid": "urn:provider-pid:44bf7aa3-b162-49e8-b94c-891b3e1fcfd8"
#         }
#       },
#       {
#         "id": "urn:negotiation-message:2e5de0a8-c0ae-4e67-a34d-fbbe64e8d6c9",
#         "negotiationAgentProcessId": "urn:negotiation-process:c0797de0-4b93-475d-a0d5-8117c96d4aa1",
#         "createdAt": "2026-05-07T08:45:00.422779Z",
#         "direction": "OUTBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractRequestMessage",
#         "stateTransitionFrom": "OFFERED",
#         "stateTransitionTo": "REQUESTED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractRequestMessage",
#           "consumerPid": "urn:consumer-pid:1d199a96-4988-4ef8-94db-97e3abbae34b",
#           "offer": {
#             "@id": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#             "@type": "Offer",
#             "permission": [
#               {
#                 "action": "use"
#               }
#             ],
#             "target": "urn:dataset:714c33b6-23d1-4eab-82de-2f8474ebf07f"
#           },
#           "providerPid": "urn:provider-pid:44bf7aa3-b162-49e8-b94c-891b3e1fcfd8"
#         }
#       },
#       {
#         "id": "urn:negotiation-message:55c4e262-3e6f-4ac8-8e63-df12f0c87e98",
#         "negotiationAgentProcessId": "urn:negotiation-process:c0797de0-4b93-475d-a0d5-8117c96d4aa1",
#         "createdAt": "2026-05-07T08:45:00.480422Z",
#         "direction": "INBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractOfferMessage",
#         "stateTransitionFrom": "REQUESTED",
#         "stateTransitionTo": "OFFERED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractOfferMessage",
#           "consumerPid": "urn:consumer-pid:1d199a96-4988-4ef8-94db-97e3abbae34b",
#           "offer": {
#             "@id": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#             "@type": "Offer",
#             "permission": [
#               {
#                 "action": "supermegause"
#               }
#             ],
#             "target": "urn:dataset:714c33b6-23d1-4eab-82de-2f8474ebf07f"
#           },
#           "providerPid": "urn:provider-pid:44bf7aa3-b162-49e8-b94c-891b3e1fcfd8"
#         }
#       },
#       {
#         "id": "urn:negotiation-message:29fa2e17-c4d1-4514-af5c-f27c55b63675",
#         "negotiationAgentProcessId": "urn:negotiation-process:c0797de0-4b93-475d-a0d5-8117c96d4aa1",
#         "createdAt": "2026-05-07T08:45:00.608106Z",
#         "direction": "OUTBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractNegotiationEventMessage",
#         "stateTransitionFrom": "OFFERED",
#         "stateTransitionTo": "ACCEPTED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractNegotiationEventMessage",
#           "consumerPid": "urn:consumer-pid:1d199a96-4988-4ef8-94db-97e3abbae34b",
#           "providerPid": "urn:provider-pid:44bf7aa3-b162-49e8-b94c-891b3e1fcfd8"
#         }
#       },
#       {
#         "id": "urn:negotiation-message:a84eccde-260c-4aea-8b08-9d2f7b6f58f0",
#         "negotiationAgentProcessId": "urn:negotiation-process:c0797de0-4b93-475d-a0d5-8117c96d4aa1",
#         "createdAt": "2026-05-07T08:45:00.652474Z",
#         "direction": "INBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractAgreementMessage",
#         "stateTransitionFrom": "ACCEPTED",
#         "stateTransitionTo": "AGREED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractAgreementMessage",
#           "agreement": {
#             "@id": "urn:agreement:04b2ecf6-22a4-4f46-8a4d-65c3f0af3c1b",
#             "@type": "Agreement",
#             "assignee": "did:jwk:...",
#             "assigner": "did:jwk:...",
#             "permission": [
#               {
#                 "action": "supermegause"
#               }
#             ],
#             "target": "urn:dataset:714c33b6-23d1-4eab-82de-2f8474ebf07f",
#             "timestamp": "1778143500"
#           },
#           "consumerPid": "urn:consumer-pid:1d199a96-4988-4ef8-94db-97e3abbae34b",
#           "providerPid": "urn:provider-pid:44bf7aa3-b162-49e8-b94c-891b3e1fcfd8"
#         }
#       },
#       {
#         "id": "urn:negotiation-message:91aa8523-6cea-4468-b958-d843a9d03f1d",
#         "negotiationAgentProcessId": "urn:negotiation-process:c0797de0-4b93-475d-a0d5-8117c96d4aa1",
#         "createdAt": "2026-05-07T08:45:00.725644Z",
#         "direction": "OUTBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractAgreementVerificationMessage",
#         "stateTransitionFrom": "AGREED",
#         "stateTransitionTo": "VERIFIED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractAgreementVerificationMessage",
#           "consumerPid": "urn:consumer-pid:1d199a96-4988-4ef8-94db-97e3abbae34b",
#           "providerPid": "urn:provider-pid:44bf7aa3-b162-49e8-b94c-891b3e1fcfd8"
#         }
#       }
#     ],
#     "offers": [
#       {
#         "id": "urn:offer:02e42c94-36ff-4a72-b006-ae99ae3f2df6",
#         "negotiationAgentProcessId": "urn:negotiation-process:c0797de0-4b93-475d-a0d5-8117c96d4aa1",
#         "negotiationAgentMessageId": "urn:negotiation-message:f1ccb1e3-ac15-4e04-be4a-a05ac6e70932",
#         "offerId": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#         "offerContent": {
#           "@id": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#           "@type": "Offer",
#           "permission": [
#             {
#               "action": "use",
#               "constraint": [
#                 {
#                   "leftOperand": "count",
#                   "operator": "gt",
#                   "rightOperand": "18"
#                 }
#               ]
#             }
#           ],
#           "target": "urn:dataset:714c33b6-23d1-4eab-82de-2f8474ebf07f"
#         },
#         "createdAt": "2026-05-07T08:45:00.285300Z"
#       },
#       {
#         "id": "urn:offer:029edd0f-d07b-4bcd-94d9-699b9f9d09b6",
#         "negotiationAgentProcessId": "urn:negotiation-process:c0797de0-4b93-475d-a0d5-8117c96d4aa1",
#         "negotiationAgentMessageId": "urn:negotiation-message:8aa49de8-b29c-47b9-a4f1-ae74d8fefb0f",
#         "offerId": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#         "offerContent": {
#           "@id": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#           "@type": "Offer",
#           "permission": [
#             {
#               "action": "use",
#               "constraint": [
#                 {
#                   "leftOperand": "count",
#                   "operator": "gt",
#                   "rightOperand": "21"
#                 }
#               ]
#             }
#           ],
#           "target": "urn:dataset:714c33b6-23d1-4eab-82de-2f8474ebf07f"
#         },
#         "createdAt": "2026-05-07T08:45:00.345318Z"
#       },
#       {
#         "id": "urn:offer:62f1bb24-832d-4742-8ad8-47c175b8c8b6",
#         "negotiationAgentProcessId": "urn:negotiation-process:c0797de0-4b93-475d-a0d5-8117c96d4aa1",
#         "negotiationAgentMessageId": "urn:negotiation-message:2e5de0a8-c0ae-4e67-a34d-fbbe64e8d6c9",
#         "offerId": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#         "offerContent": {
#           "@id": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#           "@type": "Offer",
#           "permission": [
#             {
#               "action": "use"
#             }
#           ],
#           "target": "urn:dataset:714c33b6-23d1-4eab-82de-2f8474ebf07f"
#         },
#         "createdAt": "2026-05-07T08:45:00.424046Z"
#       },
#       {
#         "id": "urn:offer:c3880c6c-16bb-4aaa-b44a-7f883a61dee2",
#         "negotiationAgentProcessId": "urn:negotiation-process:c0797de0-4b93-475d-a0d5-8117c96d4aa1",
#         "negotiationAgentMessageId": "urn:negotiation-message:55c4e262-3e6f-4ac8-8e63-df12f0c87e98",
#         "offerId": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#         "offerContent": {
#           "@id": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#           "@type": "Offer",
#           "permission": [
#             {
#               "action": "supermegause"
#             }
#           ],
#           "target": "urn:dataset:714c33b6-23d1-4eab-82de-2f8474ebf07f"
#         },
#         "createdAt": "2026-05-07T08:45:00.481851Z"
#       }
#     ],
#     "agreement": {
#       "id": "urn:agreement:04b2ecf6-22a4-4f46-8a4d-65c3f0af3c1b",
#       "negotiationAgentProcessId": "urn:negotiation-process:c0797de0-4b93-475d-a0d5-8117c96d4aa1",
#       "negotiationAgentMessageId": "urn:negotiation-message:a84eccde-260c-4aea-8b08-9d2f7b6f58f0",
#       "consumerParticipantId": "did:jwk:...",
#       "providerParticipantId": "did:jwk:...",
#       "agreementContent": {
#         "@id": "urn:agreement:04b2ecf6-22a4-4f46-8a4d-65c3f0af3c1b",
#         "@type": "Agreement",
#         "assignee": "did:jwk:...",
#         "assigner": "did:jwk:...",
#         "permission": [
#           {
#             "action": "supermegause"
#           }
#         ],
#         "target": "urn:dataset:714c33b6-23d1-4eab-82de-2f8474ebf07f",
#         "timestamp": "1778143500"
#       },
#       "target": "urn:dataset:714c33b6-23d1-4eab-82de-2f8474ebf07f",
#       "state": "ACTIVE",
#       "createdAt": "2026-05-07T08:45:00.653811Z",
#       "updatedAt": "2026-05-07T08:45:00.729885Z"
#     }
#   }
# }

# %% [markdown]
# ## Provider finalizes the negotiation (Provider -> Consumer)

# %%
url = data_space_provider + "/dsp/current/negotiations/rpc/setup-finalization"
payload = {
    "consumerPid": cn_consumer_id,
    "providerPid": cn_provider_id
}
response = requests.request("POST", url, headers=json_header, data=json.dumps(payload))
response_as_json = response.json()
try:
    agreement = response_as_json
    agreement_id = response_as_json["negotiationAgentModel"]["agreement"]["id"]
    print(json.dumps(response_as_json, indent=2))
except KeyError:
    print("Error in response, check the payload and the endpoint.")
    print(json.dumps(response_as_json, indent=2))
    raise
# Out:
# {
#   "request": {
#     "providerPid": "urn:provider-pid:44bf7aa3-b162-49e8-b94c-891b3e1fcfd8",
#     "consumerPid": "urn:consumer-pid:1d199a96-4988-4ef8-94db-97e3abbae34b"
#   },
#   "response": {
#     "@context": [
#       "https://w3id.org/dspace/2025/1/context.jsonld"
#     ],
#     "@type": "ContractNegotiation",
#     "consumerPid": "urn:consumer-pid:1d199a96-4988-4ef8-94db-97e3abbae34b",
#     "providerPid": "urn:provider-pid:44bf7aa3-b162-49e8-b94c-891b3e1fcfd8",
#     "state": "FINALIZED"
#   },
#   "negotiationAgentModel": {
#     "id": "urn:negotiation-process:8fa54d41-d6a5-403f-913e-f2f185bb92ef",
#     "state": "FINALIZED",
#     "stateAttribute": null,
#     "associatedAgentPeer": "did:jwk:...",
#     "protocol": "DSP",
#     "callbackAddress": "http://127.0.0.1:1100/dsp/current",
#     "role": "Provider",
#     "properties": {},
#     "errorDetails": null,
#     "createdAt": "2026-05-07T08:45:00.111951Z",
#     "updatedAt": "2026-05-07T08:45:00.788715Z",
#     "identifiers": {
#       "consumerPid": "urn:consumer-pid:1d199a96-4988-4ef8-94db-97e3abbae34b",
#       "providerPid": "urn:provider-pid:44bf7aa3-b162-49e8-b94c-891b3e1fcfd8"
#     },
#     "messages": [
#       {
#         "id": "urn:negotiation-message:4bccc5e6-1435-443c-a682-8bc032852445",
#         "negotiationAgentProcessId": "urn:negotiation-process:8fa54d41-d6a5-403f-913e-f2f185bb92ef",
#         "createdAt": "2026-05-07T08:45:00.173854Z",
#         "direction": "INBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractRequestMessage",
#         "stateTransitionFrom": "-",
#         "stateTransitionTo": "REQUESTED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractRequestMessage",
#           "callbackAddress": "http://127.0.0.1:1100/dsp/current",
#           "consumerPid": "urn:consumer-pid:1d199a96-4988-4ef8-94db-97e3abbae34b",
#           "offer": {
#             "@id": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#             "@type": "Offer",
#             "permission": [
#               {
#                 "action": "use",
#                 "constraint": [
#                   {
#                     "leftOperand": "count",
#                     "operator": "gt",
#                     "rightOperand": "18"
#                   }
#                 ]
#               }
#             ],
#             "target": "urn:dataset:714c33b6-23d1-4eab-82de-2f8474ebf07f"
#           }
#         }
#       },
#       {
#         "id": "urn:negotiation-message:943fa774-8573-472a-83cf-614958216f3c",
#         "negotiationAgentProcessId": "urn:negotiation-process:8fa54d41-d6a5-403f-913e-f2f185bb92ef",
#         "createdAt": "2026-05-07T08:45:00.357104Z",
#         "direction": "OUTBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractOfferMessage",
#         "stateTransitionFrom": "REQUESTED",
#         "stateTransitionTo": "OFFERED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractOfferMessage",
#           "consumerPid": "urn:consumer-pid:1d199a96-4988-4ef8-94db-97e3abbae34b",
#           "offer": {
#             "@id": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#             "@type": "Offer",
#             "permission": [
#               {
#                 "action": "use",
#                 "constraint": [
#                   {
#                     "leftOperand": "count",
#                     "operator": "gt",
#                     "rightOperand": "21"
#                   }
#                 ]
#               }
#             ],
#             "target": "urn:dataset:714c33b6-23d1-4eab-82de-2f8474ebf07f"
#           },
#           "providerPid": "urn:provider-pid:44bf7aa3-b162-49e8-b94c-891b3e1fcfd8"
#         }
#       },
#       {
#         "id": "urn:negotiation-message:66de81c1-5425-4fd2-9a3f-fff2d412e2b5",
#         "negotiationAgentProcessId": "urn:negotiation-process:8fa54d41-d6a5-403f-913e-f2f185bb92ef",
#         "createdAt": "2026-05-07T08:45:00.410826Z",
#         "direction": "INBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractRequestMessage",
#         "stateTransitionFrom": "OFFERED",
#         "stateTransitionTo": "REQUESTED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractRequestMessage",
#           "consumerPid": "urn:consumer-pid:1d199a96-4988-4ef8-94db-97e3abbae34b",
#           "offer": {
#             "@id": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#             "@type": "Offer",
#             "permission": [
#               {
#                 "action": "use"
#               }
#             ],
#             "target": "urn:dataset:714c33b6-23d1-4eab-82de-2f8474ebf07f"
#           },
#           "providerPid": "urn:provider-pid:44bf7aa3-b162-49e8-b94c-891b3e1fcfd8"
#         }
#       },
#       {
#         "id": "urn:negotiation-message:fbcb970e-af92-4b69-918f-b5b1f1eb40e3",
#         "negotiationAgentProcessId": "urn:negotiation-process:8fa54d41-d6a5-403f-913e-f2f185bb92ef",
#         "createdAt": "2026-05-07T08:45:00.497543Z",
#         "direction": "OUTBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractOfferMessage",
#         "stateTransitionFrom": "REQUESTED",
#         "stateTransitionTo": "OFFERED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractOfferMessage",
#           "consumerPid": "urn:consumer-pid:1d199a96-4988-4ef8-94db-97e3abbae34b",
#           "offer": {
#             "@id": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#             "@type": "Offer",
#             "permission": [
#               {
#                 "action": "supermegause"
#               }
#             ],
#             "target": "urn:dataset:714c33b6-23d1-4eab-82de-2f8474ebf07f"
#           },
#           "providerPid": "urn:provider-pid:44bf7aa3-b162-49e8-b94c-891b3e1fcfd8"
#         }
#       },
#       {
#         "id": "urn:negotiation-message:1c1f2e93-a8ab-480f-b01d-7f16db17af0d",
#         "negotiationAgentProcessId": "urn:negotiation-process:8fa54d41-d6a5-403f-913e-f2f185bb92ef",
#         "createdAt": "2026-05-07T08:45:00.598172Z",
#         "direction": "INBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractNegotiationEventMessage",
#         "stateTransitionFrom": "OFFERED",
#         "stateTransitionTo": "ACCEPTED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractNegotiationEventMessage",
#           "consumerPid": "urn:consumer-pid:1d199a96-4988-4ef8-94db-97e3abbae34b",
#           "eventType": "ACCEPTED",
#           "providerPid": "urn:provider-pid:44bf7aa3-b162-49e8-b94c-891b3e1fcfd8"
#         }
#       },
#       {
#         "id": "urn:negotiation-message:238105ec-5c05-4e0a-b0b1-faf8c8f42dd7",
#         "negotiationAgentProcessId": "urn:negotiation-process:8fa54d41-d6a5-403f-913e-f2f185bb92ef",
#         "createdAt": "2026-05-07T08:45:00.665419Z",
#         "direction": "OUTBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractAgreementMessage",
#         "stateTransitionFrom": "ACCEPTED",
#         "stateTransitionTo": "AGREED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractAgreementMessage",
#           "consumerPid": "urn:consumer-pid:1d199a96-4988-4ef8-94db-97e3abbae34b",
#           "providerPid": "urn:provider-pid:44bf7aa3-b162-49e8-b94c-891b3e1fcfd8"
#         }
#       },
#       {
#         "id": "urn:negotiation-message:bd6408ab-2494-4371-b93e-fdb693c9f613",
#         "negotiationAgentProcessId": "urn:negotiation-process:8fa54d41-d6a5-403f-913e-f2f185bb92ef",
#         "createdAt": "2026-05-07T08:45:00.714749Z",
#         "direction": "INBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractAgreementVerificationMessage",
#         "stateTransitionFrom": "AGREED",
#         "stateTransitionTo": "VERIFIED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractAgreementVerificationMessage",
#           "consumerPid": "urn:consumer-pid:1d199a96-4988-4ef8-94db-97e3abbae34b",
#           "providerPid": "urn:provider-pid:44bf7aa3-b162-49e8-b94c-891b3e1fcfd8"
#         }
#       },
#       {
#         "id": "urn:negotiation-message:3a236f2c-61c3-47b2-9054-b901b32c7f7f",
#         "negotiationAgentProcessId": "urn:negotiation-process:8fa54d41-d6a5-403f-913e-f2f185bb92ef",
#         "createdAt": "2026-05-07T08:45:00.793159Z",
#         "direction": "OUTBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractNegotiationEventMessage",
#         "stateTransitionFrom": "VERIFIED",
#         "stateTransitionTo": "FINALIZED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractNegotiationEventMessage",
#           "consumerPid": "urn:consumer-pid:1d199a96-4988-4ef8-94db-97e3abbae34b",
#           "providerPid": "urn:provider-pid:44bf7aa3-b162-49e8-b94c-891b3e1fcfd8"
#         }
#       }
#     ],
#     "offers": [
#       {
#         "id": "urn:offer:b2c6f28e-b404-40dd-b464-5872ab4243b1",
#         "negotiationAgentProcessId": "urn:negotiation-process:8fa54d41-d6a5-403f-913e-f2f185bb92ef",
#         "negotiationAgentMessageId": "urn:negotiation-message:4bccc5e6-1435-443c-a682-8bc032852445",
#         "offerId": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#         "offerContent": {
#           "@id": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#           "@type": "Offer",
#           "permission": [
#             {
#               "action": "use",
#               "constraint": [
#                 {
#                   "leftOperand": "count",
#                   "operator": "gt",
#                   "rightOperand": "18"
#                 }
#               ]
#             }
#           ],
#           "target": "urn:dataset:714c33b6-23d1-4eab-82de-2f8474ebf07f"
#         },
#         "createdAt": "2026-05-07T08:45:00.176584Z"
#       },
#       {
#         "id": "urn:offer:2142869b-e09b-42ba-ab0c-9ff3549b924f",
#         "negotiationAgentProcessId": "urn:negotiation-process:8fa54d41-d6a5-403f-913e-f2f185bb92ef",
#         "negotiationAgentMessageId": "urn:negotiation-message:943fa774-8573-472a-83cf-614958216f3c",
#         "offerId": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#         "offerContent": {
#           "@id": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#           "@type": "Offer",
#           "permission": [
#             {
#               "action": "use",
#               "constraint": [
#                 {
#                   "leftOperand": "count",
#                   "operator": "gt",
#                   "rightOperand": "21"
#                 }
#               ]
#             }
#           ],
#           "target": "urn:dataset:714c33b6-23d1-4eab-82de-2f8474ebf07f"
#         },
#         "createdAt": "2026-05-07T08:45:00.358711Z"
#       },
#       {
#         "id": "urn:offer:796d43c4-8866-4c2b-9508-cf65eacad9c5",
#         "negotiationAgentProcessId": "urn:negotiation-process:8fa54d41-d6a5-403f-913e-f2f185bb92ef",
#         "negotiationAgentMessageId": "urn:negotiation-message:66de81c1-5425-4fd2-9a3f-fff2d412e2b5",
#         "offerId": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#         "offerContent": {
#           "@id": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#           "@type": "Offer",
#           "permission": [
#             {
#               "action": "use"
#             }
#           ],
#           "target": "urn:dataset:714c33b6-23d1-4eab-82de-2f8474ebf07f"
#         },
#         "createdAt": "2026-05-07T08:45:00.412071Z"
#       },
#       {
#         "id": "urn:offer:d3ad4217-8c99-4fd9-b218-df5c3913e007",
#         "negotiationAgentProcessId": "urn:negotiation-process:8fa54d41-d6a5-403f-913e-f2f185bb92ef",
#         "negotiationAgentMessageId": "urn:negotiation-message:fbcb970e-af92-4b69-918f-b5b1f1eb40e3",
#         "offerId": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#         "offerContent": {
#           "@id": "urn:odrl-policy:f6bed689-9db1-46d4-bc6f-2e507e0e689e",
#           "@type": "Offer",
#           "permission": [
#             {
#               "action": "supermegause"
#             }
#           ],
#           "target": "urn:dataset:714c33b6-23d1-4eab-82de-2f8474ebf07f"
#         },
#         "createdAt": "2026-05-07T08:45:00.547244Z"
#       }
#     ],
#     "agreement": {
#       "id": "urn:agreement:04b2ecf6-22a4-4f46-8a4d-65c3f0af3c1b",
#       "negotiationAgentProcessId": "urn:negotiation-process:8fa54d41-d6a5-403f-913e-f2f185bb92ef",
#       "negotiationAgentMessageId": "urn:negotiation-message:238105ec-5c05-4e0a-b0b1-faf8c8f42dd7",
#       "consumerParticipantId": "did:jwk:...",
#       "providerParticipantId": "did:jwk:...",
#       "agreementContent": {
#         "@id": "urn:agreement:04b2ecf6-22a4-4f46-8a4d-65c3f0af3c1b",
#         "@type": "Agreement",
#         "assignee": "did:jwk:...",
#         "assigner": "did:jwk:...",
#         "permission": [
#           {
#             "action": "supermegause"
#           }
#         ],
#         "target": "urn:dataset:714c33b6-23d1-4eab-82de-2f8474ebf07f",
#         "timestamp": "1778143500"
#       },
#       "target": "urn:dataset:714c33b6-23d1-4eab-82de-2f8474ebf07f",
#       "state": "ACTIVE",
#       "createdAt": "2026-05-07T08:45:00.666325Z",
#       "updatedAt": "2026-05-07T08:45:00.796684Z"
#     }
#   }
# }

# %% [markdown]
# ## Final agreement

# %%
print("Final agreement: \n{}\n".format(json.dumps(agreement["negotiationAgentModel"]["agreement"], indent=2)))
print("Final agreement id: \n{}\n".format(agreement_id))
# Out:
# Final agreement:
# {
#   "id": "urn:agreement:04b2ecf6-22a4-4f46-8a4d-65c3f0af3c1b",
#   "negotiationAgentProcessId": "urn:negotiation-process:8fa54d41-d6a5-403f-913e-f2f185bb92ef",
#   "negotiationAgentMessageId": "urn:negotiation-message:238105ec-5c05-4e0a-b0b1-faf8c8f42dd7",
#   "consumerParticipantId": "did:jwk:...",
#   "providerParticipantId": "did:jwk:...",
#   "agreementContent": {
#     "@id": "urn:agreement:04b2ecf6-22a4-4f46-8a4d-65c3f0af3c1b",
#     "@type": "Agreement",
#     "assignee": "did:jwk:...",
#     "assigner": "did:jwk:...",
#     "permission": [
#       {
#         "action": "supermegause"
#       }
#     ],
#     "target": "urn:dataset:714c33b6-23d1-4eab-82de-2f8474ebf07f",
#     "timestamp": "1778143500"
#   },
#   "target": "urn:dataset:714c33b6-23d1-4eab-82de-2f8474ebf07f",
#   "state": "ACTIVE",
#   "createdAt": "2026-05-07T08:45:00.666325Z",
#   "updatedAt": "2026-05-07T08:45:00.796684Z"
# }
#
# Final agreement id:
# urn:agreement:04b2ecf6-22a4-4f46-8a4d-65c3f0af3c1b

# %% [markdown]
# # Transfer Negotiation with Agents

# %% [markdown]
# ## Transfer request setup (Consumer -> Provider)

# %%
url = data_space_consumer + "/dsp/current/transfers/rpc/setup-request"
payload = {
    "associatedAgentPeer": data_space_provider_participant_id,
    "providerAddress": data_space_provider_dsp_endpoint,
    "callbackAddress": data_space_consumer_dsp_endpoint,
    "agreementId": agreement_id,
    "format": "http+asd",
}
response = requests.request("POST", url, headers=json_header, data=json.dumps(payload))
response_as_json = response.json()
transfer_process_consumer_pid = response_as_json["response"]["consumerPid"]
transfer_process_provider_pid = response_as_json["response"]["providerPid"]
print(json.dumps(response_as_json, indent=2))
# Out:
# {
#   "request": {
#     "associatedAgentPeer": "did:jwk:...",
#     "agreementId": "urn:agreement:04b2ecf6-22a4-4f46-8a4d-65c3f0af3c1b",
#     "format": "http+asd",
#     "dataAddress": null,
#     "providerAddress": "http://127.0.0.1:1200/dsp/current",
#     "callbackAddress": "http://127.0.0.1:1100/dsp/current"
#   },
#   "response": {
#     "@context": [
#       "https://w3id.org/dspace/2025/1/context.jsonld"
#     ],
#     "@type": "TransferProcess",
#     "consumerPid": "urn:consumer-pid:d66e1c6b-574e-4002-ae39-2841830dbaad",
#     "providerPid": "urn:provider-pid:ae233a06-d0d3-4cc2-b259-20d99bd63892",
#     "state": "REQUESTED"
#   },
#   "transferAgentModel": {
#     "id": "urn:transfer-process:b0440e23-3b86-46ef-95fa-9fe8ed874d73",
#     "state": "REQUESTED",
#     "stateAttribute": "OnRequest",
#     "associatedAgentPeer": "did:jwk:...",
#     "protocol": "DSP",
#     "connectorInstanceId": "http+asd",
#     "transferDirection": "Pull",
#     "agreementId": "urn:agreement:04b2ecf6-22a4-4f46-8a4d-65c3f0af3c1b",
#     "callbackAddress": "http://127.0.0.1:1200/dsp/current",
#     "role": "Consumer",
#     "properties": {},
#     "errorDetails": null,
#     "createdAt": "2026-05-07T08:45:01.120090Z",
#     "updatedAt": null,
#     "identifiers": {
#       "consumerPid": "urn:consumer-pid:d66e1c6b-574e-4002-ae39-2841830dbaad",
#       "providerPid": "urn:provider-pid:ae233a06-d0d3-4cc2-b259-20d99bd63892"
#     },
#     "messages": [
#       {
#         "id": "urn:uuid:f290cd68-9886-47b9-b5e5-1255166f72f6",
#         "transferAgentProcessId": "urn:transfer-process:b0440e23-3b86-46ef-95fa-9fe8ed874d73",
#         "createdAt": "2026-05-07T08:45:01.192672Z",
#         "direction": "OUTBOUND",
#         "protocol": "DSP",
#         "messageType": "TransferRequestMessage",
#         "stateTransitionFrom": "-",
#         "stateTransitionTo": "REQUESTED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "TransferRequestMessage",
#           "agreementId": "urn:agreement:04b2ecf6-22a4-4f46-8a4d-65c3f0af3c1b",
#           "callbackAddress": "http://127.0.0.1:1100/dsp/current",
#           "consumerPid": "urn:consumer-pid:d66e1c6b-574e-4002-ae39-2841830dbaad",
#           "format": "http+asd"
#         }
#       }
#     ]
#   }
# }

# %% [markdown]
# ## Start transfer (Provider -> Consumer)

# %%
url = data_space_provider + "/dsp/current/transfers/rpc/setup-start"
payload = {
    "consumerPid": transfer_process_consumer_pid,
    "providerPid": transfer_process_provider_pid,
}
response = requests.request("POST", url, headers=json_header, data=json.dumps(payload))
response_as_json = response.json()

print(json.dumps(response_as_json, indent=2))
# Out:
# {
#   "request": {
#     "consumerPid": "urn:consumer-pid:d66e1c6b-574e-4002-ae39-2841830dbaad",
#     "providerPid": "urn:provider-pid:ae233a06-d0d3-4cc2-b259-20d99bd63892"
#   },
#   "response": {
#     "@context": [
#       "https://w3id.org/dspace/2025/1/context.jsonld"
#     ],
#     "@type": "TransferProcess",
#     "consumerPid": "urn:consumer-pid:d66e1c6b-574e-4002-ae39-2841830dbaad",
#     "providerPid": "urn:provider-pid:ae233a06-d0d3-4cc2-b259-20d99bd63892",
#     "state": "STARTED"
#   },
#   "transferAgentModel": {
#     "id": "urn:transfer-process:811b5aee-a803-4a16-92bc-c734949aa1f8",
#     "state": "STARTED",
#     "stateAttribute": "OnRequest",
#     "associatedAgentPeer": "did:jwk:...",
#     "protocol": "DSP",
#     "connectorInstanceId": "http+asd",
#     "transferDirection": "Pull",
#     "agreementId": "urn:agreement:04b2ecf6-22a4-4f46-8a4d-65c3f0af3c1b",
#     "callbackAddress": "http://127.0.0.1:1100/dsp/current",
#     "role": "Provider",
#     "properties": {},
#     "errorDetails": null,
#     "createdAt": "2026-05-07T08:45:00.975959Z",
#     "updatedAt": "2026-05-07T08:45:01.319490Z",
#     "identifiers": {
#       "providerPid": "urn:provider-pid:ae233a06-d0d3-4cc2-b259-20d99bd63892",
#       "consumerPid": "urn:consumer-pid:d66e1c6b-574e-4002-ae39-2841830dbaad"
#     },
#     "messages": [
#       {
#         "id": "urn:uuid:76a168c8-ff34-4184-bfda-7a80362e7128",
#         "transferAgentProcessId": "urn:transfer-process:811b5aee-a803-4a16-92bc-c734949aa1f8",
#         "createdAt": "2026-05-07T08:45:01.039309Z",
#         "direction": "INBOUND",
#         "protocol": "DSP",
#         "messageType": "TransferRequestMessage",
#         "stateTransitionFrom": "-",
#         "stateTransitionTo": "REQUESTED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "TransferRequestMessage",
#           "agreementId": "urn:agreement:04b2ecf6-22a4-4f46-8a4d-65c3f0af3c1b",
#           "callbackAddress": "http://127.0.0.1:1100/dsp/current",
#           "consumerPid": "urn:consumer-pid:d66e1c6b-574e-4002-ae39-2841830dbaad",
#           "format": "http+asd"
#         }
#       },
#       {
#         "id": "urn:uuid:87725d50-6d63-43f9-bbe8-f937c24ea83d",
#         "transferAgentProcessId": "urn:transfer-process:811b5aee-a803-4a16-92bc-c734949aa1f8",
#         "createdAt": "2026-05-07T08:45:01.326170Z",
#         "direction": "OUTBOUND",
#         "protocol": "DSP",
#         "messageType": "TransferStartMessage",
#         "stateTransitionFrom": "REQUESTED",
#         "stateTransitionTo": "STARTED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "TransferStartMessage",
#           "consumerPid": "urn:consumer-pid:d66e1c6b-574e-4002-ae39-2841830dbaad",
#           "dataAddress": {
#             "endpoint": "http://127.0.0.1:1200/dataplane/proxy/urn:dataplane-transfer:22b15296-56df-41a5-97b7-1028b170fc45",
#             "endpointProperties": null,
#             "endpointType": "HTTP"
#           },
#           "providerPid": "urn:provider-pid:ae233a06-d0d3-4cc2-b259-20d99bd63892"
#         }
#       }
#     ]
#   }
# }

# %% [markdown]
# ## Suspend transfer (Consumer -> Provider)

# %%
url = data_space_consumer + "/dsp/current/transfers/rpc/setup-suspension"
payload = {
    "consumerPid": transfer_process_consumer_pid,
    "providerPid": transfer_process_provider_pid,
    "code": "SUSPEND",
    "reason": ["Suspending for demonstration purposes"]
}
response = requests.request("POST", url, headers=json_header, data=json.dumps(payload))
response_as_json = response.json()
print(json.dumps(response_as_json, indent=2))
# Out:
# {
#   "request": {
#     "consumerPid": "urn:consumer-pid:d66e1c6b-574e-4002-ae39-2841830dbaad",
#     "providerPid": "urn:provider-pid:ae233a06-d0d3-4cc2-b259-20d99bd63892",
#     "code": "SUSPEND",
#     "reason": [
#       "Suspending for demonstration purposes"
#     ]
#   },
#   "response": {
#     "@context": [
#       "https://w3id.org/dspace/2025/1/context.jsonld"
#     ],
#     "@type": "TransferProcess",
#     "consumerPid": "urn:consumer-pid:d66e1c6b-574e-4002-ae39-2841830dbaad",
#     "providerPid": "urn:provider-pid:ae233a06-d0d3-4cc2-b259-20d99bd63892",
#     "state": "SUSPENDED"
#   },
#   "transferAgentModel": {
#     "id": "urn:transfer-process:b0440e23-3b86-46ef-95fa-9fe8ed874d73",
#     "state": "SUSPENDED",
#     "stateAttribute": "ByConsumer",
#     "associatedAgentPeer": "did:jwk:...",
#     "protocol": "DSP",
#     "connectorInstanceId": "http+asd",
#     "transferDirection": "Pull",
#     "agreementId": "urn:agreement:04b2ecf6-22a4-4f46-8a4d-65c3f0af3c1b",
#     "callbackAddress": "http://127.0.0.1:1200/dsp/current",
#     "role": "Consumer",
#     "properties": {},
#     "errorDetails": null,
#     "createdAt": "2026-05-07T08:45:01.120090Z",
#     "updatedAt": "2026-05-07T08:45:01.413978Z",
#     "identifiers": {
#       "providerPid": "urn:provider-pid:ae233a06-d0d3-4cc2-b259-20d99bd63892",
#       "consumerPid": "urn:consumer-pid:d66e1c6b-574e-4002-ae39-2841830dbaad"
#     },
#     "messages": [
#       {
#         "id": "urn:uuid:f290cd68-9886-47b9-b5e5-1255166f72f6",
#         "transferAgentProcessId": "urn:transfer-process:b0440e23-3b86-46ef-95fa-9fe8ed874d73",
#         "createdAt": "2026-05-07T08:45:01.192672Z",
#         "direction": "OUTBOUND",
#         "protocol": "DSP",
#         "messageType": "TransferRequestMessage",
#         "stateTransitionFrom": "-",
#         "stateTransitionTo": "REQUESTED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "TransferRequestMessage",
#           "agreementId": "urn:agreement:04b2ecf6-22a4-4f46-8a4d-65c3f0af3c1b",
#           "callbackAddress": "http://127.0.0.1:1100/dsp/current",
#           "consumerPid": "urn:consumer-pid:d66e1c6b-574e-4002-ae39-2841830dbaad",
#           "format": "http+asd"
#         }
#       },
#       {
#         "id": "urn:uuid:d0ec2180-6681-4b04-b6c6-fadf7db99961",
#         "transferAgentProcessId": "urn:transfer-process:b0440e23-3b86-46ef-95fa-9fe8ed874d73",
#         "createdAt": "2026-05-07T08:45:01.259865Z",
#         "direction": "INBOUND",
#         "protocol": "DSP",
#         "messageType": "TransferStartMessage",
#         "stateTransitionFrom": "REQUESTED",
#         "stateTransitionTo": "STARTED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "TransferStartMessage",
#           "consumerPid": "urn:consumer-pid:d66e1c6b-574e-4002-ae39-2841830dbaad",
#           "dataAddress": {
#             "endpoint": "http://127.0.0.1:1200/dataplane/proxy/urn:dataplane-transfer:22b15296-56df-41a5-97b7-1028b170fc45",
#             "endpointProperties": null,
#             "endpointType": "HTTP"
#           },
#           "providerPid": "urn:provider-pid:ae233a06-d0d3-4cc2-b259-20d99bd63892"
#         }
#       },
#       {
#         "id": "urn:uuid:b3ed7cea-d6ef-4f62-bc10-0fa462987159",
#         "transferAgentProcessId": "urn:transfer-process:b0440e23-3b86-46ef-95fa-9fe8ed874d73",
#         "createdAt": "2026-05-07T08:45:01.417056Z",
#         "direction": "OUTBOUND",
#         "protocol": "DSP",
#         "messageType": "TransferSuspensionMessage",
#         "stateTransitionFrom": "STARTED",
#         "stateTransitionTo": "SUSPENDED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "TransferSuspensionMessage",
#           "code": "SUSPEND",
#           "consumerPid": "urn:consumer-pid:d66e1c6b-574e-4002-ae39-2841830dbaad",
#           "providerPid": "urn:provider-pid:ae233a06-d0d3-4cc2-b259-20d99bd63892",
#           "reason": [
#             "Suspending for demonstration purposes"
#           ]
#         }
#       }
#     ]
#   }
# }

# %% [markdown]
# ## Restart transfer (Consumer -> Provider)

# %%
url = data_space_consumer + "/dsp/current/transfers/rpc/setup-start"
payload = {
    "consumerPid": transfer_process_consumer_pid,
    "providerPid": transfer_process_provider_pid,
}
response = requests.request("POST", url, headers=json_header, data=json.dumps(payload))
response_as_json = response.json()

print(json.dumps(response_as_json, indent=2))
# Out:
# {
#   "request": {
#     "consumerPid": "urn:consumer-pid:d66e1c6b-574e-4002-ae39-2841830dbaad",
#     "providerPid": "urn:provider-pid:ae233a06-d0d3-4cc2-b259-20d99bd63892"
#   },
#   "response": {
#     "@context": [
#       "https://w3id.org/dspace/2025/1/context.jsonld"
#     ],
#     "@type": "TransferProcess",
#     "consumerPid": "urn:consumer-pid:d66e1c6b-574e-4002-ae39-2841830dbaad",
#     "providerPid": "urn:provider-pid:ae233a06-d0d3-4cc2-b259-20d99bd63892",
#     "state": "STARTED"
#   },
#   "transferAgentModel": {
#     "id": "urn:transfer-process:b0440e23-3b86-46ef-95fa-9fe8ed874d73",
#     "state": "STARTED",
#     "stateAttribute": "ByConsumer",
#     "associatedAgentPeer": "did:jwk:...",
#     "protocol": "DSP",
#     "connectorInstanceId": "http+asd",
#     "transferDirection": "Pull",
#     "agreementId": "urn:agreement:04b2ecf6-22a4-4f46-8a4d-65c3f0af3c1b",
#     "callbackAddress": "http://127.0.0.1:1200/dsp/current",
#     "role": "Consumer",
#     "properties": {},
#     "errorDetails": null,
#     "createdAt": "2026-05-07T08:45:01.120090Z",
#     "updatedAt": "2026-05-07T08:45:01.495509Z",
#     "identifiers": {
#       "consumerPid": "urn:consumer-pid:d66e1c6b-574e-4002-ae39-2841830dbaad",
#       "providerPid": "urn:provider-pid:ae233a06-d0d3-4cc2-b259-20d99bd63892"
#     },
#     "messages": [
#       {
#         "id": "urn:uuid:f290cd68-9886-47b9-b5e5-1255166f72f6",
#         "transferAgentProcessId": "urn:transfer-process:b0440e23-3b86-46ef-95fa-9fe8ed874d73",
#         "createdAt": "2026-05-07T08:45:01.192672Z",
#         "direction": "OUTBOUND",
#         "protocol": "DSP",
#         "messageType": "TransferRequestMessage",
#         "stateTransitionFrom": "-",
#         "stateTransitionTo": "REQUESTED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "TransferRequestMessage",
#           "agreementId": "urn:agreement:04b2ecf6-22a4-4f46-8a4d-65c3f0af3c1b",
#           "callbackAddress": "http://127.0.0.1:1100/dsp/current",
#           "consumerPid": "urn:consumer-pid:d66e1c6b-574e-4002-ae39-2841830dbaad",
#           "format": "http+asd"
#         }
#       },
#       {
#         "id": "urn:uuid:d0ec2180-6681-4b04-b6c6-fadf7db99961",
#         "transferAgentProcessId": "urn:transfer-process:b0440e23-3b86-46ef-95fa-9fe8ed874d73",
#         "createdAt": "2026-05-07T08:45:01.259865Z",
#         "direction": "INBOUND",
#         "protocol": "DSP",
#         "messageType": "TransferStartMessage",
#         "stateTransitionFrom": "REQUESTED",
#         "stateTransitionTo": "STARTED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "TransferStartMessage",
#           "consumerPid": "urn:consumer-pid:d66e1c6b-574e-4002-ae39-2841830dbaad",
#           "dataAddress": {
#             "endpoint": "http://127.0.0.1:1200/dataplane/proxy/urn:dataplane-transfer:22b15296-56df-41a5-97b7-1028b170fc45",
#             "endpointProperties": null,
#             "endpointType": "HTTP"
#           },
#           "providerPid": "urn:provider-pid:ae233a06-d0d3-4cc2-b259-20d99bd63892"
#         }
#       },
#       {
#         "id": "urn:uuid:b3ed7cea-d6ef-4f62-bc10-0fa462987159",
#         "transferAgentProcessId": "urn:transfer-process:b0440e23-3b86-46ef-95fa-9fe8ed874d73",
#         "createdAt": "2026-05-07T08:45:01.417056Z",
#         "direction": "OUTBOUND",
#         "protocol": "DSP",
#         "messageType": "TransferSuspensionMessage",
#         "stateTransitionFrom": "STARTED",
#         "stateTransitionTo": "SUSPENDED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "TransferSuspensionMessage",
#           "code": "SUSPEND",
#           "consumerPid": "urn:consumer-pid:d66e1c6b-574e-4002-ae39-2841830dbaad",
#           "providerPid": "urn:provider-pid:ae233a06-d0d3-4cc2-b259-20d99bd63892",
#           "reason": [
#             "Suspending for demonstration purposes"
#           ]
#         }
#       },
#       {
#         "id": "urn:uuid:0dc94abd-3186-4ec4-89d7-af154f4cb922",
#         "transferAgentProcessId": "urn:transfer-process:b0440e23-3b86-46ef-95fa-9fe8ed874d73",
#         "createdAt": "2026-05-07T08:45:01.498275Z",
#         "direction": "OUTBOUND",
#         "protocol": "DSP",
#         "messageType": "TransferStartMessage",
#         "stateTransitionFrom": "SUSPENDED",
#         "stateTransitionTo": "STARTED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "TransferStartMessage",
#           "consumerPid": "urn:consumer-pid:d66e1c6b-574e-4002-ae39-2841830dbaad",
#           "providerPid": "urn:provider-pid:ae233a06-d0d3-4cc2-b259-20d99bd63892"
#         }
#       }
#     ]
#   }
# }

# %% [markdown]
# ## Suspension by Provider (Provider -> Consumer)
# (Note: Testing provider-initiated suspension)

# %%
url = data_space_provider + "/dsp/current/transfers/rpc/setup-suspension"
payload = {
    "consumerPid": transfer_process_consumer_pid,
    "providerPid": transfer_process_provider_pid,
    "code": "SUSPEND",
    "reason": ["Suspending for demonstration purposes"]
}
response = requests.request("POST", url, headers=json_header, data=json.dumps(payload))
response_as_json = response.json()
print(json.dumps(response_as_json, indent=2))
# Out:
# {
#   "request": {
#     "consumerPid": "urn:consumer-pid:d66e1c6b-574e-4002-ae39-2841830dbaad",
#     "providerPid": "urn:provider-pid:ae233a06-d0d3-4cc2-b259-20d99bd63892",
#     "code": "SUSPEND",
#     "reason": [
#       "Suspending for demonstration purposes"
#     ]
#   },
#   "response": {
#     "@context": [
#       "https://w3id.org/dspace/2025/1/context.jsonld"
#     ],
#     "@type": "TransferProcess",
#     "consumerPid": "urn:consumer-pid:d66e1c6b-574e-4002-ae39-2841830dbaad",
#     "providerPid": "urn:provider-pid:ae233a06-d0d3-4cc2-b259-20d99bd63892",
#     "state": "SUSPENDED"
#   },
#   "transferAgentModel": {
#     "id": "urn:transfer-process:811b5aee-a803-4a16-92bc-c734949aa1f8",
#     "state": "SUSPENDED",
#     "stateAttribute": "ByProvider",
#     "associatedAgentPeer": "did:jwk:...",
#     "protocol": "DSP",
#     "connectorInstanceId": "http+asd",
#     "transferDirection": "Pull",
#     "agreementId": "urn:agreement:04b2ecf6-22a4-4f46-8a4d-65c3f0af3c1b",
#     "callbackAddress": "http://127.0.0.1:1100/dsp/current",
#     "role": "Provider",
#     "properties": {},
#     "errorDetails": null,
#     "createdAt": "2026-05-07T08:45:00.975959Z",
#     "updatedAt": "2026-05-07T08:45:01.627700Z",
#     "identifiers": {
#       "consumerPid": "urn:consumer-pid:d66e1c6b-574e-4002-ae39-2841830dbaad",
#       "providerPid": "urn:provider-pid:ae233a06-d0d3-4cc2-b259-20d99bd63892"
#     },
#     "messages": [
#       {
#         "id": "urn:uuid:76a168c8-ff34-4184-bfda-7a80362e7128",
#         "transferAgentProcessId": "urn:transfer-process:811b5aee-a803-4a16-92bc-c734949aa1f8",
#         "createdAt": "2026-05-07T08:45:01.039309Z",
#         "direction": "INBOUND",
#         "protocol": "DSP",
#         "messageType": "TransferRequestMessage",
#         "stateTransitionFrom": "-",
#         "stateTransitionTo": "REQUESTED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "TransferRequestMessage",
#           "agreementId": "urn:agreement:04b2ecf6-22a4-4f46-8a4d-65c3f0af3c1b",
#           "callbackAddress": "http://127.0.0.1:1100/dsp/current",
#           "consumerPid": "urn:consumer-pid:d66e1c6b-574e-4002-ae39-2841830dbaad",
#           "format": "http+asd"
#         }
#       },
#       {
#         "id": "urn:uuid:87725d50-6d63-43f9-bbe8-f937c24ea83d",
#         "transferAgentProcessId": "urn:transfer-process:811b5aee-a803-4a16-92bc-c734949aa1f8",
#         "createdAt": "2026-05-07T08:45:01.326170Z",
#         "direction": "OUTBOUND",
#         "protocol": "DSP",
#         "messageType": "TransferStartMessage",
#         "stateTransitionFrom": "REQUESTED",
#         "stateTransitionTo": "STARTED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "TransferStartMessage",
#           "consumerPid": "urn:consumer-pid:d66e1c6b-574e-4002-ae39-2841830dbaad",
#           "dataAddress": {
#             "endpoint": "http://127.0.0.1:1200/dataplane/proxy/urn:dataplane-transfer:22b15296-56df-41a5-97b7-1028b170fc45",
#             "endpointProperties": null,
#             "endpointType": "HTTP"
#           },
#           "providerPid": "urn:provider-pid:ae233a06-d0d3-4cc2-b259-20d99bd63892"
#         }
#       },
#       {
#         "id": "urn:uuid:b6e37d2e-7d26-485f-94a3-6626479f1dc7",
#         "transferAgentProcessId": "urn:transfer-process:811b5aee-a803-4a16-92bc-c734949aa1f8",
#         "createdAt": "2026-05-07T08:45:01.392454Z",
#         "direction": "INBOUND",
#         "protocol": "DSP",
#         "messageType": "TransferSuspensionMessage",
#         "stateTransitionFrom": "STARTED",
#         "stateTransitionTo": "SUSPENDED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "TransferSuspensionMessage",
#           "code": "SUSPEND",
#           "consumerPid": "urn:consumer-pid:d66e1c6b-574e-4002-ae39-2841830dbaad",
#           "providerPid": "urn:provider-pid:ae233a06-d0d3-4cc2-b259-20d99bd63892",
#           "reason": [
#             "Suspending for demonstration purposes"
#           ]
#         }
#       },
#       {
#         "id": "urn:uuid:e80a4d3b-cf0e-4ed6-93d7-e38c24d66e68",
#         "transferAgentProcessId": "urn:transfer-process:811b5aee-a803-4a16-92bc-c734949aa1f8",
#         "createdAt": "2026-05-07T08:45:01.480022Z",
#         "direction": "INBOUND",
#         "protocol": "DSP",
#         "messageType": "TransferStartMessage",
#         "stateTransitionFrom": "SUSPENDED",
#         "stateTransitionTo": "STARTED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "TransferStartMessage",
#           "consumerPid": "urn:consumer-pid:d66e1c6b-574e-4002-ae39-2841830dbaad",
#           "providerPid": "urn:provider-pid:ae233a06-d0d3-4cc2-b259-20d99bd63892"
#         }
#       },
#       {
#         "id": "urn:uuid:f2961250-8de7-4866-8c3c-81313d2ebadb",
#         "transferAgentProcessId": "urn:transfer-process:811b5aee-a803-4a16-92bc-c734949aa1f8",
#         "createdAt": "2026-05-07T08:45:01.631496Z",
#         "direction": "OUTBOUND",
#         "protocol": "DSP",
#         "messageType": "TransferSuspensionMessage",
#         "stateTransitionFrom": "STARTED",
#         "stateTransitionTo": "SUSPENDED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "TransferSuspensionMessage",
#           "code": "SUSPEND",
#           "consumerPid": "urn:consumer-pid:d66e1c6b-574e-4002-ae39-2841830dbaad",
#           "providerPid": "urn:provider-pid:ae233a06-d0d3-4cc2-b259-20d99bd63892",
#           "reason": [
#             "Suspending for demonstration purposes"
#           ]
#         }
#       }
#     ]
#   }
# }

# %% [markdown]
# ## Failure Test: Attempt start with invalid parameters

# %%
url = data_space_consumer + "/dsp/current/transfers/rpc/setup-start"
payload = {
    "consumerPid": transfer_process_consumer_pid,
    "providerPid": transfer_process_provider_pid,
}
response = requests.request("POST", url, headers=json_header, data=json.dumps(payload))
response_as_json = response.json()
print(json.dumps(response_as_json, indent=2))
# Out:
# {
#   "request": {
#     "consumerPid": "urn:consumer-pid:d66e1c6b-574e-4002-ae39-2841830dbaad",
#     "providerPid": "urn:provider-pid:ae233a06-d0d3-4cc2-b259-20d99bd63892"
#   },
#   "error": {
#     "@context": [
#       "https://w3id.org/dspace/2025/1/context.jsonld"
#     ],
#     "@type": "TransferError",
#     "consumerPid": null,
#     "providerPid": null,
#     "code": "5000",
#     "reason": [
#       "Petition Error\n",
#       "{\"@context\":[\"https://w3id.org/dspace/2025/1/context.jsonld\"],\"@type\":\"TransferError\",\"consumerPid\":null,\"providerPid\":null,\"code\":\"5000\",\"reason\":[\"Parse Error\",\"Parse Error\",\"\",\"\"]}",
#       "",
#       "Url: unknown \nMethod: unknown \nHttp Code: 400 Bad Request \n"
#     ]
#   }
# }

# %% [markdown]
# ## Failure Test: Attempt duplicate or invalid suspension

# %%
url = data_space_consumer + "/dsp/current/transfers/rpc/setup-suspension"
payload = {
    "consumerPid": transfer_process_consumer_pid,
    "providerPid": transfer_process_provider_pid,
    "code": "SUSPEND",
    "reason": ["Suspending for demonstration purposes"]
}
response = requests.request("POST", url, headers=json_header, data=json.dumps(payload))
response_as_json = response.json()
print(json.dumps(response_as_json, indent=2))
# Out:
# {
#   "request": {
#     "consumerPid": "urn:consumer-pid:d66e1c6b-574e-4002-ae39-2841830dbaad",
#     "providerPid": "urn:provider-pid:ae233a06-d0d3-4cc2-b259-20d99bd63892",
#     "code": "SUSPEND",
#     "reason": [
#       "Suspending for demonstration purposes"
#     ]
#   },
#   "error": {
#     "@context": [
#       "https://w3id.org/dspace/2025/1/context.jsonld"
#     ],
#     "@type": "TransferError",
#     "consumerPid": null,
#     "providerPid": null,
#     "code": "5000",
#     "reason": [
#       "Parse Error",
#       "Parse Error",
#       "",
#       ""
#     ]
#   }
# }

# %% [markdown]
# ## Finalize transfer (Provider -> Consumer)

# %%
url = data_space_provider + "/dsp/current/transfers/rpc/setup-completion"
payload = {
    "consumerPid": transfer_process_consumer_pid,
    "providerPid": transfer_process_provider_pid,
}
response = requests.request("POST", url, headers=json_header, data=json.dumps(payload))
response_as_json = response.json()
print(json.dumps(response_as_json, indent=2))
# Out:
# {
#   "request": {
#     "consumerPid": "urn:consumer-pid:d66e1c6b-574e-4002-ae39-2841830dbaad",
#     "providerPid": "urn:provider-pid:ae233a06-d0d3-4cc2-b259-20d99bd63892"
#   },
#   "response": {
#     "@context": [
#       "https://w3id.org/dspace/2025/1/context.jsonld"
#     ],
#     "@type": "TransferProcess",
#     "consumerPid": "urn:consumer-pid:d66e1c6b-574e-4002-ae39-2841830dbaad",
#     "providerPid": "urn:provider-pid:ae233a06-d0d3-4cc2-b259-20d99bd63892",
#     "state": "COMPLETED"
#   },
#   "transferAgentModel": {
#     "id": "urn:transfer-process:811b5aee-a803-4a16-92bc-c734949aa1f8",
#     "state": "COMPLETED",
#     "stateAttribute": "ByProvider",
#     "associatedAgentPeer": "did:jwk:...",
#     "protocol": "DSP",
#     "connectorInstanceId": "http+asd",
#     "transferDirection": "Pull",
#     "agreementId": "urn:agreement:04b2ecf6-22a4-4f46-8a4d-65c3f0af3c1b",
#     "callbackAddress": "http://127.0.0.1:1100/dsp/current",
#     "role": "Provider",
#     "properties": {},
#     "errorDetails": null,
#     "createdAt": "2026-05-07T08:45:00.975959Z",
#     "updatedAt": "2026-05-07T08:45:01.807736Z",
#     "identifiers": {
#       "providerPid": "urn:provider-pid:ae233a06-d0d3-4cc2-b259-20d99bd63892",
#       "consumerPid": "urn:consumer-pid:d66e1c6b-574e-4002-ae39-2841830dbaad"
#     },
#     "messages": [
#       {
#         "id": "urn:uuid:76a168c8-ff34-4184-bfda-7a80362e7128",
#         "transferAgentProcessId": "urn:transfer-process:811b5aee-a803-4a16-92bc-c734949aa1f8",
#         "createdAt": "2026-05-07T08:45:01.039309Z",
#         "direction": "INBOUND",
#         "protocol": "DSP",
#         "messageType": "TransferRequestMessage",
#         "stateTransitionFrom": "-",
#         "stateTransitionTo": "REQUESTED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "TransferRequestMessage",
#           "agreementId": "urn:agreement:04b2ecf6-22a4-4f46-8a4d-65c3f0af3c1b",
#           "callbackAddress": "http://127.0.0.1:1100/dsp/current",
#           "consumerPid": "urn:consumer-pid:d66e1c6b-574e-4002-ae39-2841830dbaad",
#           "format": "http+asd"
#         }
#       },
#       {
#         "id": "urn:uuid:87725d50-6d63-43f9-bbe8-f937c24ea83d",
#         "transferAgentProcessId": "urn:transfer-process:811b5aee-a803-4a16-92bc-c734949aa1f8",
#         "createdAt": "2026-05-07T08:45:01.326170Z",
#         "direction": "OUTBOUND",
#         "protocol": "DSP",
#         "messageType": "TransferStartMessage",
#         "stateTransitionFrom": "REQUESTED",
#         "stateTransitionTo": "STARTED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "TransferStartMessage",
#           "consumerPid": "urn:consumer-pid:d66e1c6b-574e-4002-ae39-2841830dbaad",
#           "dataAddress": {
#             "endpoint": "http://127.0.0.1:1200/dataplane/proxy/urn:dataplane-transfer:22b15296-56df-41a5-97b7-1028b170fc45",
#             "endpointProperties": null,
#             "endpointType": "HTTP"
#           },
#           "providerPid": "urn:provider-pid:ae233a06-d0d3-4cc2-b259-20d99bd63892"
#         }
#       },
#       {
#         "id": "urn:uuid:b6e37d2e-7d26-485f-94a3-6626479f1dc7",
#         "transferAgentProcessId": "urn:transfer-process:811b5aee-a803-4a16-92bc-c734949aa1f8",
#         "createdAt": "2026-05-07T08:45:01.392454Z",
#         "direction": "INBOUND",
#         "protocol": "DSP",
#         "messageType": "TransferSuspensionMessage",
#         "stateTransitionFrom": "STARTED",
#         "stateTransitionTo": "SUSPENDED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "TransferSuspensionMessage",
#           "code": "SUSPEND",
#           "consumerPid": "urn:consumer-pid:d66e1c6b-574e-4002-ae39-2841830dbaad",
#           "providerPid": "urn:provider-pid:ae233a06-d0d3-4cc2-b259-20d99bd63892",
#           "reason": [
#             "Suspending for demonstration purposes"
#           ]
#         }
#       },
#       {
#         "id": "urn:uuid:e80a4d3b-cf0e-4ed6-93d7-e38c24d66e68",
#         "transferAgentProcessId": "urn:transfer-process:811b5aee-a803-4a16-92bc-c734949aa1f8",
#         "createdAt": "2026-05-07T08:45:01.480022Z",
#         "direction": "INBOUND",
#         "protocol": "DSP",
#         "messageType": "TransferStartMessage",
#         "stateTransitionFrom": "SUSPENDED",
#         "stateTransitionTo": "STARTED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "TransferStartMessage",
#           "consumerPid": "urn:consumer-pid:d66e1c6b-574e-4002-ae39-2841830dbaad",
#           "providerPid": "urn:provider-pid:ae233a06-d0d3-4cc2-b259-20d99bd63892"
#         }
#       },
#       {
#         "id": "urn:uuid:f2961250-8de7-4866-8c3c-81313d2ebadb",
#         "transferAgentProcessId": "urn:transfer-process:811b5aee-a803-4a16-92bc-c734949aa1f8",
#         "createdAt": "2026-05-07T08:45:01.631496Z",
#         "direction": "OUTBOUND",
#         "protocol": "DSP",
#         "messageType": "TransferSuspensionMessage",
#         "stateTransitionFrom": "STARTED",
#         "stateTransitionTo": "SUSPENDED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "TransferSuspensionMessage",
#           "code": "SUSPEND",
#           "consumerPid": "urn:consumer-pid:d66e1c6b-574e-4002-ae39-2841830dbaad",
#           "providerPid": "urn:provider-pid:ae233a06-d0d3-4cc2-b259-20d99bd63892",
#           "reason": [
#             "Suspending for demonstration purposes"
#           ]
#         }
#       },
#       {
#         "id": "urn:uuid:a85206de-731e-43de-8c6a-0052bd0d0d3c",
#         "transferAgentProcessId": "urn:transfer-process:811b5aee-a803-4a16-92bc-c734949aa1f8",
#         "createdAt": "2026-05-07T08:45:01.812859Z",
#         "direction": "OUTBOUND",
#         "protocol": "DSP",
#         "messageType": "TransferCompletionMessage",
#         "stateTransitionFrom": "SUSPENDED",
#         "stateTransitionTo": "COMPLETED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "TransferCompletionMessage",
#           "consumerPid": "urn:consumer-pid:d66e1c6b-574e-4002-ae39-2841830dbaad",
#           "providerPid": "urn:provider-pid:ae233a06-d0d3-4cc2-b259-20d99bd63892"
#         }
#       }
#     ]
#   }
# }
