# %% [markdown]
# # Preconditions
# `./setup_auth.ipynb` and `./setup_catalog_policies.ipynb`will run

# %%
# %run ./setup_catalog_policies_oauth.ipynb
# Out:
# /Users/apabook/Desktop/ds-protocol/static/tutorial/venv/bin/python
# {
#     "participant_id": "did:jwk:...",
#     "participant_nick": "Myself",
#     "participant_type": "Agent",
#     "base_url": "http://127.0.0.1:1200",
#     "token": null,
#     "saved_at": "2026-08-20T15:25:23.508312Z",
#     "last_interaction": "2026-08-20T21:52:20.067010Z",
#     "extra_fields": {},
#     "is_me": true
# }
# {
#     "participant_id": "did:jwk:...",
#     "participant_nick": "Myself",
#     "participant_type": "Agent",
#     "base_url": "http://127.0.0.1:1100",
#     "token": null,
#     "saved_at": "2026-08-20T22:16:10.727195Z",
#     "last_interaction": "2026-08-20T22:16:10.727198Z",
#     "extra_fields": {},
#     "is_me": true
# }
# Provider DID: did:jwk:...
#
# Provider token: 6BWir9NBYEEmniXWI3Ilqe39VKy4O-rl66JXxf4XV6o
#
# Consumer DID: did:jwk:...
#
# Consumer token: 6BWir9NBYEEmniXWI3Ilqe39VKy4O-rl66JXxf4XV6o
# {
#     "dctConformsTo": null,
#     "dctCreator": null,
#     "dctIdentifier": "urn:catalog:35d5127d-e7d4-43c0-8b1b-c073f1025fe6",
#     "dctIssued": "2026-08-20T15:25:23.917933Z",
#     "dctModified": null,
#     "dctTitle": null,
#     "dspaceMainCatalog": true,
#     "dspaceParticipantId": "did:jwk:...",
#     "foafHomePage": null,
#     "id": "urn:catalog:35d5127d-e7d4-43c0-8b1b-c073f1025fe6"
# }
# {
#     "catalogId": "urn:catalog:35d5127d-e7d4-43c0-8b1b-c073f1025fe6",
#     "dcatEndpointDescription": null,
#     "dcatEndpointUrl": "http://127.0.0.1:1200/dsp/current",
#     "dctConformsTo": null,
#     "dctCreator": null,
#     "dctDescription": null,
#     "dctIdentifier": "urn:data-service:ccb9e881-0aa1-462b-be8a-2361b9ea664f",
#     "dctIssued": "2026-08-20T15:25:23.990687Z",
#     "dctModified": null,
#     "dctTitle": null,
#     "dspaceMainDataService": true,
#     "id": "urn:data-service:ccb9e881-0aa1-462b-be8a-2361b9ea664f"
# }
# {
#     "catalogId": "urn:catalog:35d5127d-e7d4-43c0-8b1b-c073f1025fe6",
#     "dctConformsTo": null,
#     "dctCreator": null,
#     "dctDescription": null,
#     "dctIdentifier": "urn:dataset:875dedc3-cb03-4f26-a865-be1eb295dc0a",
#     "dctIssued": "2026-08-20T22:26:52.939363Z",
#     "dctModified": null,
#     "dctTitle": "My dataspace dataset",
#     "id": "urn:dataset:875dedc3-cb03-4f26-a865-be1eb295dc0a"
# }
# {
#     "datasetId": "urn:dataset:875dedc3-cb03-4f26-a865-be1eb295dc0a",
#     "dcatAccessService": "urn:data-service:ccb9e881-0aa1-462b-be8a-2361b9ea664f",
#     "dctDescription": "This is the distribution of my dataset",
#     "dctFormat": "http+asd",
#     "dctIssued": "2026-08-20T22:26:52.949547Z",
#     "dctModified": null,
#     "dctTitle": "Distribution of my dataset",
#     "id": "urn:distribution:8473d918-06bf-46a6-8ce9-1530f88dbbdc"
# }
# {
#     "datasetId": "urn:dataset:875dedc3-cb03-4f26-a865-be1eb295dc0a",
#     "dcatAccessService": "urn:data-service:ccb9e881-0aa1-462b-be8a-2361b9ea664f",
#     "dctDescription": "This is the distribution of my streaming dataset",
#     "dctFormat": "http+pushing",
#     "dctIssued": "2026-08-20T22:26:52.955719Z",
#     "dctModified": null,
#     "dctTitle": "Distribution of a streaming dataset",
#     "id": "urn:distribution:f74a8413-fefd-4300-85ba-ad60b141f2fd"
# }
# [
#     {
#         "author": "",
#         "content": {
#             "permission": [
#                 {
#                     "action": "use",
#                     "constraint": [
#                         {
#                             "leftOperand": "bla",
#                             "operator": "eq",
#                             "rightOperand": "$bla"
#                         }
#                     ]
#                 }
#             ]
#         },
#         "date": "2026-08-20T15:25:23.998680Z",
#         "description": "Mi example super policy",
#         "id": "policy-1",
#         "parameters": {
#             "$bla": {
#                 "dataType": "string",
#                 "restrictions": {},
#                 "ui": {
#                     "hidden": false
#                 }
#             }
#         },
#         "title": "Mi example policy",
#         "version": "1.0"
#     }
# ]
# {
#     "createdAt": "2026-08-20T22:26:52.966556Z",
#     "description": "Research access for UPM: grants read access to did:web:university.upm.es valid until 2025-12-31.",
#     "entity": "urn:dataset:875dedc3-cb03-4f26-a865-be1eb295dc0a",
#     "entityType": "Dataset",
#     "id": "urn:odrl-policy:f9278ffb-78a8-4c7d-8bc7-b73b6bf45809",
#     "instantiationParameters": {
#         "$bla": "did:web:university.upm.es"
#     },
#     "odrlOffer": {
#         "permission": [
#             {
#                 "action": "use",
#                 "constraint": [
#                     {
#                         "leftOperand": "bla",
#                         "operator": "eq",
#                         "rightOperand": "did:web:university.upm.es"
#                     }
#                 ]
#             }
#         ]
#     },
#     "sourceTemplateId": "policy-1",
#     "sourceTemplateVersion": "1.0"
# }
# {
#     "createdAt": "2026-08-20T22:26:52.974429Z",
#     "description": "Commercial use licence valid for 2025: permits usage for commercial purposes with mandatory attribution. Derivation of the dataset is prohibited.",
#     "entity": "urn:dataset:875dedc3-cb03-4f26-a865-be1eb295dc0a",
#     "entityType": "Dataset",
#     "id": "urn:odrl-policy:3fda66a4-b9df-43d3-a66e-1684f49d2e65",
#     "instantiationParameters": null,
#     "odrlOffer": {
#         "obligation": [
#             {
#                 "action": "attribute",
#                 "constraint": [
#                     {
#                         "leftOperand": "recipient",
#                         "operator": "isA",
#                         "rightOperand": "public"
#                     }
#                 ]
#             }
#         ],
#         "permission": [
#             {
#                 "action": "use",
#                 "constraint": [
#                     {
#                         "leftOperand": "dateTime",
#                         "operator": "gteq",
#                         "rightOperand": "2025-01-01T00:00:00Z"
#                     },
#                     {
#                         "leftOperand": "dateTime",
#                         "operator": "lteq",
#                         "rightOperand": "2025-12-31T23:59:59Z"
#                     },
#                     {
#                         "leftOperand": "purpose",
#                         "operator": "isA",
#                         "rightOperand": "commercial"
#                     }
#                 ]
#             }
#         ],
#         "prohibition": [
#             {
#                 "action": "derive",
#                 "constraint": []
#             }
#         ]
#     },
#     "sourceTemplateId": null,
#     "sourceTemplateVersion": null
# }
# {
#     "createdAt": "2026-08-20T22:26:52.980711Z",
#     "description": "Research trial access (Mar\u2013Sep 2025): read-only, limited to 10 000 requests, restricted to research purposes. Redistribution and reproduction are prohibited.",
#     "entity": "urn:dataset:875dedc3-cb03-4f26-a865-be1eb295dc0a",
#     "entityType": "Dataset",
#     "id": "urn:odrl-policy:4f9b3435-ae27-4eaa-afe5-a3d8cb906e8b",
#     "instantiationParameters": null,
#     "odrlOffer": {
#         "obligation": [],
#         "permission": [
#             {
#                 "action": "read",
#                 "constraint": [
#                     {
#                         "leftOperand": "dateTime",
#                         "operator": "gteq",
#                         "rightOperand": "2025-03-01T00:00:00Z"
#                     },
#                     {
#                         "leftOperand": "dateTime",
#                         "operator": "lteq",
#                         "rightOperand": "2025-09-01T00:00:00Z"
#                     },
#                     {
#                         "leftOperand": "purpose",
#                         "operator": "isA",
#                         "rightOperand": "research"
#                     },
#                     {
#                         "leftOperand": "count",
#                         "operator": "lteq",
#                         "rightOperand": "10000"
#                     }
#                 ]
#             }
#         ],
#         "prohibition": [
#             {
#                 "action": "distribute",
#                 "constraint": []
#             },
#             {
#                 "action": "reproduce",
#                 "constraint": []
#             }
#         ]
#     },
#     "sourceTemplateId": null,
#     "sourceTemplateVersion": null
# }
# {
#     "message": "Database Error",
#     "error_code": 5100,
#     "details": "Secret already exists"
# }
# {
#     "name": "urn:connector-template:875ac810-80fa-4473-bbbc-20436ebbddd0",
#     "author": "admin",
#     "description": null,
#     "version": "1.0",
#     "createdAt": "2026-08-20T22:26:53.010665Z",
#     "authentication": {
#         "type": "BEARER_TOKEN",
#         "token": {
#             "type": "PLAIN",
#             "content": "{{__RUNTIME_SECRET_{/ecostars/api_key}__}}"
#         }
#     },
#     "interaction": {
#         "mode": "PULL",
#         "dataAccess": {
#             "protocol": "HTTP",
#             "urlTemplate": "{{__ACCESS_URL__}}",
#             "method": "{{__ACCESS_METHODS__}}",
#             "headers": "{{__ACCESS_HEADERS__}}",
#             "bodyTemplate": null
#         }
#     },
#     "parameters": [
#         {
#             "name": "ACCESS_URL",
#             "title": "Url",
#             "description": null,
#             "paramType": "STRING",
#             "required": true,
#             "defaultValue": null
#         },
#         {
#             "name": "ACCESS_METHODS",
#             "title": "Methods",
#             "description": null,
#             "paramType": "VEC<STRING>",
#             "required": true,
#             "defaultValue": null
#         },
#         {
#             "name": "ACCESS_HEADERS",
#             "title": "Headers",
#             "description": null,
#             "paramType": "MAP<STRING,STRING>",
#             "required": true,
#             "defaultValue": null
#         }
#     ]
# }
# {
#     "id": "urn:connector-instance:60a41abc-71d2-4026-b6dc-d4fdbbcbb52f",
#     "name": "urn:connector-template:875ac810-80fa-4473-bbbc-20436ebbddd0",
#     "author": null,
#     "description": null,
#     "version": "1.0",
#     "createdAt": "2026-08-20T22:26:53.018463Z",
#     "authenticationConfig": {
#         "type": "BEARER_TOKEN",
#         "token": {
#             "type": "PLAIN",
#             "content": "{{__RUNTIME_SECRET_{/ecostars/api_key}__}}"
#         }
#     },
#     "interaction": {
#         "mode": "PULL",
#         "dataAccess": {
#             "protocol": "HTTP",
#             "urlTemplate": "http://127.0.0.1:8081",
#             "method": [
#                 "GET",
#                 "HEAD"
#             ],
#             "headers": {
#                 "Content-type": "application/json"
#             },
#             "bodyTemplate": null
#         }
#     },
#     "distributionId": "urn:distribution:8473d918-06bf-46a6-8ce9-1530f88dbbdc"
# }
# {
#     "name": "urn:connector-template:4a87adb3-bd0e-4fa2-b80e-4cc2dd10faa0",
#     "author": "admin",
#     "description": null,
#     "version": "1.0",
#     "createdAt": "2026-08-20T22:26:53.024304Z",
#     "authentication": {
#         "type": "BEARER_TOKEN",
#         "token": {
#             "type": "PLAIN",
#             "content": "{{__RUNTIME_SECRET_{/ecostars/api_key}__}}"
#         }
#     },
#     "interaction": {
#         "mode": "PUSH",
#         "subscribe": {
#             "protocol": "HTTP",
#             "urlTemplate": "{{__SUB_URL__}}",
#             "method": "POST",
#             "headers": {},
#             "bodyTemplate": "{\"url\": \"{{__SYS_OWN_URL_DOCKER__}}{{__RUNTIME_INGRESS__}}\", \"event_type\": \"hotel_waste_generated\"}"
#         },
#         "unsubscribe": {
#             "protocol": "HTTP",
#             "urlTemplate": "{{__UNSUB_URL__}}/{{__RUNTIME_JSON_{.subscription.data.ID}__}}",
#             "method": "POST",
#             "headers": {},
#             "bodyTemplate": "{}"
#         }
#     },
#     "parameters": [
#         {
#             "name": "SUB_URL",
#             "title": "Subscription URL",
#             "description": null,
#             "paramType": "STRING",
#             "required": true,
#             "defaultValue": null
#         },
#         {
#             "name": "UNSUB_URL",
#             "title": "Unsubscription URL",
#             "description": null,
#             "paramType": "STRING",
#             "required": true,
#             "defaultValue": null
#         }
#     ]
# }
# {
#     "id": "urn:connector-instance:ee55ef8f-5fb6-4147-83fa-5806f825a39a",
#     "name": "urn:connector-template:4a87adb3-bd0e-4fa2-b80e-4cc2dd10faa0",
#     "author": null,
#     "description": null,
#     "version": "1.0",
#     "createdAt": "2026-08-20T22:26:53.029908Z",
#     "authenticationConfig": {
#         "type": "BEARER_TOKEN",
#         "token": {
#             "type": "PLAIN",
#             "content": "{{__RUNTIME_SECRET_{/ecostars/api_key}__}}"
#         }
#     },
#     "interaction": {
#         "mode": "PUSH",
#         "subscribe": {
#             "protocol": "HTTP",
#             "urlTemplate": "http://127.0.0.1:8082/subscriptions/subscribe",
#             "method": "POST",
#             "headers": {},
#             "bodyTemplate": "{\"url\": \"http://host.docker.internal:1200{{__RUNTIME_INGRESS__}}\", \"event_type\": \"hotel_waste_generated\"}"
#         },
#         "unsubscribe": {
#             "protocol": "HTTP",
#             "urlTemplate": "http://127.0.0.1:8082/subscriptions/unsubscribe/{{__RUNTIME_JSON_{.subscription.data.ID}__}}",
#             "method": "POST",
#             "headers": {},
#             "bodyTemplate": "{}"
#         }
#     },
#     "distributionId": "urn:distribution:f74a8413-fefd-4300-85ba-ad60b141f2fd"
# }
# Selected dataset target:
# urn:dataset:875dedc3-cb03-4f26-a865-be1eb295dc0a
#
# Selected policy id:
# urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17
#
# Provider negotiation URL for DSP 2025:
# http://127.0.0.1:1200/dsp/current
#
# Consumer callback address:
# http://127.0.0.1:1100/dsp/current

# %% [markdown]
# # Contract Negotiation

# %% [markdown]
# ## Initialization of negotiation request (Consumer -> Provider)

# %%
url = data_space_consumer + "/dsp/current/negotiations/rpc/setup-request-init"
payload = {
    "associatedAgentPeer": data_space_provider_participant_id,
    "providerAddress": data_space_provider_dsp_endpoint,
    "callbackAddress": data_space_consumer_dsp_endpoint,
    "offer": {
        "@id": policy_id,
        "target": target_id,
        "@type": "Offer",
        "permission": [
            {
                "action": "use", 
                "constraint": [{
                    "leftOperand": "count", 
                    "operator": "gt", 
                    "rightOperand": "18"
                }]
            }
        ]
    }
}




try:
    response = requests.request("POST", url, headers=json_header, data=json.dumps(payload))
    response_as_json = response.json()
    cn_consumer_id = response_as_json["response"]["consumerPid"]
    cn_provider_id = response_as_json["response"]["providerPid"]
    print(json.dumps(response_as_json, indent=2))
except Exception as e:
    print("Error in response, {}.".format(e))
# Out:
# {
#   "request": {
#     "associatedAgentPeer": "did:jwk:...",
#     "providerAddress": "http://127.0.0.1:1200/dsp/current",
#     "callbackAddress": "http://127.0.0.1:1100/dsp/current",
#     "offer": {
#       "@id": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#       "permission": [
#         {
#           "action": "use",
#           "constraint": [
#             {
#               "rightOperand": "18",
#               "leftOperand": "count",
#               "operator": "gt"
#             }
#           ]
#         }
#       ],
#       "@type": "Offer",
#       "target": "urn:dataset:875dedc3-cb03-4f26-a865-be1eb295dc0a"
#     }
#   },
#   "response": {
#     "@context": [
#       "https://w3id.org/dspace/2025/1/context.jsonld"
#     ],
#     "@type": "ContractNegotiation",
#     "consumerPid": "urn:consumer-pid:2e1f1986-c02c-44f0-8c47-f2b4fa75cc61",
#     "providerPid": "urn:provider-pid:5173ad8f-bbea-4253-a737-5d1f8c3107fd",
#     "state": "REQUESTED"
#   },
#   "negotiationAgentModel": {
#     "id": "urn:negotiation-process:ef296f8e-b3a3-487c-b3b3-575b024278f5",
#     "state": "REQUESTED",
#     "stateAttribute": null,
#     "associatedAgentPeer": "did:jwk:...",
#     "protocol": "DSP",
#     "callbackAddress": "http://127.0.0.1:1200/dsp/current",
#     "role": "Consumer",
#     "properties": {},
#     "errorDetails": null,
#     "createdAt": "2026-08-20T22:26:55.252336Z",
#     "updatedAt": null,
#     "identifiers": {
#       "providerPid": "urn:provider-pid:5173ad8f-bbea-4253-a737-5d1f8c3107fd",
#       "consumerPid": "urn:consumer-pid:2e1f1986-c02c-44f0-8c47-f2b4fa75cc61"
#     },
#     "messages": [
#       {
#         "id": "urn:negotiation-message:ba9ea65d-e085-4efa-acae-1efa34ebd65d",
#         "negotiationAgentProcessId": "urn:negotiation-process:ef296f8e-b3a3-487c-b3b3-575b024278f5",
#         "createdAt": "2026-08-20T22:26:55.263711Z",
#         "direction": "OUTBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractRequestMessage",
#         "stateTransitionFrom": "-",
#         "stateTransitionTo": "REQUESTED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractRequestMessage",
#           "associatedAgentPeer": "did:jwk:...",
#           "callbackAddress": "http://127.0.0.1:1100/dsp/current",
#           "offer": {
#             "@id": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#             "@type": "Offer",
#             "permission": [
#               {
#                 "action": "use",
#                 "constraint": [
#                   {
#                     "leftOperand": "count",
#                     "operator": "gt",
#                     "rightOperand": "18"
#                   }
#                 ]
#               }
#             ],
#             "target": "urn:dataset:875dedc3-cb03-4f26-a865-be1eb295dc0a"
#           },
#           "providerAddress": "http://127.0.0.1:1200/dsp/current"
#         }
#       }
#     ],
#     "offers": [
#       {
#         "id": "urn:offer:7b8a0682-7655-4d5a-9ddd-2f5ee8dac726",
#         "negotiationAgentProcessId": "urn:negotiation-process:ef296f8e-b3a3-487c-b3b3-575b024278f5",
#         "negotiationAgentMessageId": "urn:negotiation-message:ba9ea65d-e085-4efa-acae-1efa34ebd65d",
#         "offerId": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#         "offerContent": {
#           "@id": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#           "@type": "Offer",
#           "permission": [
#             {
#               "action": "use",
#               "constraint": [
#                 {
#                   "leftOperand": "count",
#                   "operator": "gt",
#                   "rightOperand": "18"
#                 }
#               ]
#             }
#           ],
#           "target": "urn:dataset:875dedc3-cb03-4f26-a865-be1eb295dc0a"
#         },
#         "createdAt": "2026-08-20T22:26:55.265509Z"
#       }
#     ],
#     "agreement": null
#   }
# }

# %% [markdown]
# ## Provider creates initial offer (Provider -> Consumer)

# %%
# Provider creates initial offer (Provider -> Consumer)
url = data_space_provider + "/dsp/current/negotiations/rpc/setup-offer"
payload = {
    "consumerPid": cn_consumer_id,  # remove to test offer from provider
    "providerPid": cn_provider_id,  # remove to test offer from provider
    "offer": {
        "@id": policy_id,
        "target": target_id,
        "@type": "Offer",
        "permission": [
            {
                "action": "use", 
                "constraint": [{
                    "leftOperand": "count", 
                    "operator": "gt", 
                    "rightOperand": "21"
                }]
            }
        ]
    }
}
response = requests.request("POST", url, headers=json_header, data=json.dumps(payload))
response_as_json = response.json()
try:
    print(json.dumps(response_as_json, indent=2))
except KeyError:
    print("Error in response, check the payload and the endpoint.")
    print(json.dumps(response_as_json, indent=2))
    raise
# Out:
# {
#   "request": {
#     "offer": {
#       "@id": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#       "permission": [
#         {
#           "action": "use",
#           "constraint": [
#             {
#               "rightOperand": "21",
#               "leftOperand": "count",
#               "operator": "gt"
#             }
#           ]
#         }
#       ],
#       "@type": "Offer",
#       "target": "urn:dataset:875dedc3-cb03-4f26-a865-be1eb295dc0a"
#     },
#     "providerPid": "urn:provider-pid:5173ad8f-bbea-4253-a737-5d1f8c3107fd",
#     "consumerPid": "urn:consumer-pid:2e1f1986-c02c-44f0-8c47-f2b4fa75cc61"
#   },
#   "response": {
#     "@context": [
#       "https://w3id.org/dspace/2025/1/context.jsonld"
#     ],
#     "@type": "ContractNegotiation",
#     "consumerPid": "urn:consumer-pid:2e1f1986-c02c-44f0-8c47-f2b4fa75cc61",
#     "providerPid": "urn:provider-pid:5173ad8f-bbea-4253-a737-5d1f8c3107fd",
#     "state": "OFFERED"
#   },
#   "negotiationAgentModel": {
#     "id": "urn:negotiation-process:db89adba-c15e-41dd-8d4c-5b10a6a27467",
#     "state": "OFFERED",
#     "stateAttribute": null,
#     "associatedAgentPeer": "did:jwk:...",
#     "protocol": "DSP",
#     "callbackAddress": "http://127.0.0.1:1100/dsp/current",
#     "role": "Provider",
#     "properties": {},
#     "errorDetails": null,
#     "createdAt": "2026-08-20T22:26:55.233698Z",
#     "updatedAt": "2026-08-20T22:26:55.894915Z",
#     "identifiers": {
#       "consumerPid": "urn:consumer-pid:2e1f1986-c02c-44f0-8c47-f2b4fa75cc61",
#       "providerPid": "urn:provider-pid:5173ad8f-bbea-4253-a737-5d1f8c3107fd"
#     },
#     "messages": [
#       {
#         "id": "urn:negotiation-message:14f371fb-5128-496e-9e1f-b68c52e18428",
#         "negotiationAgentProcessId": "urn:negotiation-process:db89adba-c15e-41dd-8d4c-5b10a6a27467",
#         "createdAt": "2026-08-20T22:26:55.249534Z",
#         "direction": "INBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractRequestMessage",
#         "stateTransitionFrom": "-",
#         "stateTransitionTo": "REQUESTED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractRequestMessage",
#           "callbackAddress": "http://127.0.0.1:1100/dsp/current",
#           "consumerPid": "urn:consumer-pid:2e1f1986-c02c-44f0-8c47-f2b4fa75cc61",
#           "offer": {
#             "@id": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#             "@type": "Offer",
#             "permission": [
#               {
#                 "action": "use",
#                 "constraint": [
#                   {
#                     "leftOperand": "count",
#                     "operator": "gt",
#                     "rightOperand": "18"
#                   }
#                 ]
#               }
#             ],
#             "target": "urn:dataset:875dedc3-cb03-4f26-a865-be1eb295dc0a"
#           }
#         }
#       },
#       {
#         "id": "urn:negotiation-message:c34a7f02-76fa-4e22-a309-bc10db926796",
#         "negotiationAgentProcessId": "urn:negotiation-process:db89adba-c15e-41dd-8d4c-5b10a6a27467",
#         "createdAt": "2026-08-20T22:26:55.908592Z",
#         "direction": "OUTBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractOfferMessage",
#         "stateTransitionFrom": "REQUESTED",
#         "stateTransitionTo": "OFFERED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractOfferMessage",
#           "consumerPid": "urn:consumer-pid:2e1f1986-c02c-44f0-8c47-f2b4fa75cc61",
#           "offer": {
#             "@id": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#             "@type": "Offer",
#             "permission": [
#               {
#                 "action": "use",
#                 "constraint": [
#                   {
#                     "leftOperand": "count",
#                     "operator": "gt",
#                     "rightOperand": "21"
#                   }
#                 ]
#               }
#             ],
#             "target": "urn:dataset:875dedc3-cb03-4f26-a865-be1eb295dc0a"
#           },
#           "providerPid": "urn:provider-pid:5173ad8f-bbea-4253-a737-5d1f8c3107fd"
#         }
#       }
#     ],
#     "offers": [
#       {
#         "id": "urn:offer:0bfb1bfe-f4d4-4985-95c4-ceed0f144163",
#         "negotiationAgentProcessId": "urn:negotiation-process:db89adba-c15e-41dd-8d4c-5b10a6a27467",
#         "negotiationAgentMessageId": "urn:negotiation-message:14f371fb-5128-496e-9e1f-b68c52e18428",
#         "offerId": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#         "offerContent": {
#           "@id": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#           "@type": "Offer",
#           "permission": [
#             {
#               "action": "use",
#               "constraint": [
#                 {
#                   "leftOperand": "count",
#                   "operator": "gt",
#                   "rightOperand": "18"
#                 }
#               ]
#             }
#           ],
#           "target": "urn:dataset:875dedc3-cb03-4f26-a865-be1eb295dc0a"
#         },
#         "createdAt": "2026-08-20T22:26:55.250718Z"
#       },
#       {
#         "id": "urn:offer:b1303cb4-0e17-4768-91b3-315bb5a2b665",
#         "negotiationAgentProcessId": "urn:negotiation-process:db89adba-c15e-41dd-8d4c-5b10a6a27467",
#         "negotiationAgentMessageId": "urn:negotiation-message:c34a7f02-76fa-4e22-a309-bc10db926796",
#         "offerId": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#         "offerContent": {
#           "@id": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#           "@type": "Offer",
#           "permission": [
#             {
#               "action": "use",
#               "constraint": [
#                 {
#                   "leftOperand": "count",
#                   "operator": "gt",
#                   "rightOperand": "21"
#                 }
#               ]
#             }
#           ],
#           "target": "urn:dataset:875dedc3-cb03-4f26-a865-be1eb295dc0a"
#         },
#         "createdAt": "2026-08-20T22:26:55.910692Z"
#       }
#     ],
#     "agreement": null
#   }
# }

# %% [markdown]
# ## Consumer sends negotiation request based on offer (Consumer -> Provider)

# %%
url = data_space_consumer + "/dsp/current/negotiations/rpc/setup-request"
payload = {
    "consumerPid": cn_consumer_id,
    "providerPid": cn_provider_id,
    "offer": {
        "@id": policy_id,
        "target": target_id,
        "@type": "Offer",
        "permission": [
            {
                "action": "use"

            }
        ]
    }
}
response = requests.request("POST", url, headers=json_header, data=json.dumps(payload))
response_as_json = response.json()
try:
    print(json.dumps(response_as_json, indent=2))
except KeyError:
    print("Error in response, check the payload and the endpoint.")
    print(json.dumps(response_as_json, indent=2))
    raise
# Out:
# {
#   "request": {
#     "offer": {
#       "@id": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#       "permission": [
#         {
#           "action": "use"
#         }
#       ],
#       "@type": "Offer",
#       "target": "urn:dataset:875dedc3-cb03-4f26-a865-be1eb295dc0a"
#     },
#     "providerPid": "urn:provider-pid:5173ad8f-bbea-4253-a737-5d1f8c3107fd",
#     "consumerPid": "urn:consumer-pid:2e1f1986-c02c-44f0-8c47-f2b4fa75cc61"
#   },
#   "response": {
#     "@context": [
#       "https://w3id.org/dspace/2025/1/context.jsonld"
#     ],
#     "@type": "ContractNegotiation",
#     "consumerPid": "urn:consumer-pid:2e1f1986-c02c-44f0-8c47-f2b4fa75cc61",
#     "providerPid": "urn:provider-pid:5173ad8f-bbea-4253-a737-5d1f8c3107fd",
#     "state": "REQUESTED"
#   },
#   "negotiationAgentModel": {
#     "id": "urn:negotiation-process:ef296f8e-b3a3-487c-b3b3-575b024278f5",
#     "state": "REQUESTED",
#     "stateAttribute": null,
#     "associatedAgentPeer": "did:jwk:...",
#     "protocol": "DSP",
#     "callbackAddress": "http://127.0.0.1:1200/dsp/current",
#     "role": "Consumer",
#     "properties": {},
#     "errorDetails": null,
#     "createdAt": "2026-08-20T22:26:55.252336Z",
#     "updatedAt": "2026-08-20T22:26:56.064220Z",
#     "identifiers": {
#       "providerPid": "urn:provider-pid:5173ad8f-bbea-4253-a737-5d1f8c3107fd",
#       "consumerPid": "urn:consumer-pid:2e1f1986-c02c-44f0-8c47-f2b4fa75cc61"
#     },
#     "messages": [
#       {
#         "id": "urn:negotiation-message:ba9ea65d-e085-4efa-acae-1efa34ebd65d",
#         "negotiationAgentProcessId": "urn:negotiation-process:ef296f8e-b3a3-487c-b3b3-575b024278f5",
#         "createdAt": "2026-08-20T22:26:55.263711Z",
#         "direction": "OUTBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractRequestMessage",
#         "stateTransitionFrom": "-",
#         "stateTransitionTo": "REQUESTED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractRequestMessage",
#           "associatedAgentPeer": "did:jwk:...",
#           "callbackAddress": "http://127.0.0.1:1100/dsp/current",
#           "offer": {
#             "@id": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#             "@type": "Offer",
#             "permission": [
#               {
#                 "action": "use",
#                 "constraint": [
#                   {
#                     "leftOperand": "count",
#                     "operator": "gt",
#                     "rightOperand": "18"
#                   }
#                 ]
#               }
#             ],
#             "target": "urn:dataset:875dedc3-cb03-4f26-a865-be1eb295dc0a"
#           },
#           "providerAddress": "http://127.0.0.1:1200/dsp/current"
#         }
#       },
#       {
#         "id": "urn:negotiation-message:88be8052-75e0-406d-8bbc-6bd0a8e25d0f",
#         "negotiationAgentProcessId": "urn:negotiation-process:ef296f8e-b3a3-487c-b3b3-575b024278f5",
#         "createdAt": "2026-08-20T22:26:55.880964Z",
#         "direction": "INBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractOfferMessage",
#         "stateTransitionFrom": "REQUESTED",
#         "stateTransitionTo": "OFFERED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractOfferMessage",
#           "consumerPid": "urn:consumer-pid:2e1f1986-c02c-44f0-8c47-f2b4fa75cc61",
#           "offer": {
#             "@id": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#             "@type": "Offer",
#             "permission": [
#               {
#                 "action": "use",
#                 "constraint": [
#                   {
#                     "leftOperand": "count",
#                     "operator": "gt",
#                     "rightOperand": "21"
#                   }
#                 ]
#               }
#             ],
#             "target": "urn:dataset:875dedc3-cb03-4f26-a865-be1eb295dc0a"
#           },
#           "providerPid": "urn:provider-pid:5173ad8f-bbea-4253-a737-5d1f8c3107fd"
#         }
#       },
#       {
#         "id": "urn:negotiation-message:77270604-d8f4-490d-8155-2fef29f550b7",
#         "negotiationAgentProcessId": "urn:negotiation-process:ef296f8e-b3a3-487c-b3b3-575b024278f5",
#         "createdAt": "2026-08-20T22:26:56.070021Z",
#         "direction": "OUTBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractRequestMessage",
#         "stateTransitionFrom": "OFFERED",
#         "stateTransitionTo": "REQUESTED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractRequestMessage",
#           "consumerPid": "urn:consumer-pid:2e1f1986-c02c-44f0-8c47-f2b4fa75cc61",
#           "offer": {
#             "@id": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#             "@type": "Offer",
#             "permission": [
#               {
#                 "action": "use"
#               }
#             ],
#             "target": "urn:dataset:875dedc3-cb03-4f26-a865-be1eb295dc0a"
#           },
#           "providerPid": "urn:provider-pid:5173ad8f-bbea-4253-a737-5d1f8c3107fd"
#         }
#       }
#     ],
#     "offers": [
#       {
#         "id": "urn:offer:7b8a0682-7655-4d5a-9ddd-2f5ee8dac726",
#         "negotiationAgentProcessId": "urn:negotiation-process:ef296f8e-b3a3-487c-b3b3-575b024278f5",
#         "negotiationAgentMessageId": "urn:negotiation-message:ba9ea65d-e085-4efa-acae-1efa34ebd65d",
#         "offerId": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#         "offerContent": {
#           "@id": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#           "@type": "Offer",
#           "permission": [
#             {
#               "action": "use",
#               "constraint": [
#                 {
#                   "leftOperand": "count",
#                   "operator": "gt",
#                   "rightOperand": "18"
#                 }
#               ]
#             }
#           ],
#           "target": "urn:dataset:875dedc3-cb03-4f26-a865-be1eb295dc0a"
#         },
#         "createdAt": "2026-08-20T22:26:55.265509Z"
#       },
#       {
#         "id": "urn:offer:449d2e1f-b507-4ab6-9cb9-278b03e1c798",
#         "negotiationAgentProcessId": "urn:negotiation-process:ef296f8e-b3a3-487c-b3b3-575b024278f5",
#         "negotiationAgentMessageId": "urn:negotiation-message:88be8052-75e0-406d-8bbc-6bd0a8e25d0f",
#         "offerId": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#         "offerContent": {
#           "@id": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#           "@type": "Offer",
#           "permission": [
#             {
#               "action": "use",
#               "constraint": [
#                 {
#                   "leftOperand": "count",
#                   "operator": "gt",
#                   "rightOperand": "21"
#                 }
#               ]
#             }
#           ],
#           "target": "urn:dataset:875dedc3-cb03-4f26-a865-be1eb295dc0a"
#         },
#         "createdAt": "2026-08-20T22:26:55.884668Z"
#       },
#       {
#         "id": "urn:offer:a122eb07-4f68-4a0f-ae19-3b4464aaec93",
#         "negotiationAgentProcessId": "urn:negotiation-process:ef296f8e-b3a3-487c-b3b3-575b024278f5",
#         "negotiationAgentMessageId": "urn:negotiation-message:77270604-d8f4-490d-8155-2fef29f550b7",
#         "offerId": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#         "offerContent": {
#           "@id": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#           "@type": "Offer",
#           "permission": [
#             {
#               "action": "use"
#             }
#           ],
#           "target": "urn:dataset:875dedc3-cb03-4f26-a865-be1eb295dc0a"
#         },
#         "createdAt": "2026-08-20T22:26:56.071779Z"
#       }
#     ],
#     "agreement": null
#   }
# }

# %% [markdown]
# ## Provider updates/confirms the offer (Provider -> Consumer)

# %%
url = data_space_provider + "/dsp/current/negotiations/rpc/setup-offer"
payload = {
    "consumerPid": cn_consumer_id,
    "providerPid": cn_provider_id,
    "offer": {
        "@id": policy_id,
        "target": target_id,
        "@type": "Offer",
        "permission": [
            {
                "action": "supermegause"
            }
        ]
    }
}
response = requests.request("POST", url, headers=json_header, data=json.dumps(payload))
response_as_json = response.json()
try:
    print(json.dumps(response_as_json, indent=2))
except KeyError:
    print("Error in response, check the payload and the endpoint.")
    print(json.dumps(response_as_json, indent=2))
    raise
# Out:
# {
#   "request": {
#     "offer": {
#       "@id": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#       "permission": [
#         {
#           "action": "supermegause"
#         }
#       ],
#       "@type": "Offer",
#       "target": "urn:dataset:875dedc3-cb03-4f26-a865-be1eb295dc0a"
#     },
#     "providerPid": "urn:provider-pid:5173ad8f-bbea-4253-a737-5d1f8c3107fd",
#     "consumerPid": "urn:consumer-pid:2e1f1986-c02c-44f0-8c47-f2b4fa75cc61"
#   },
#   "response": {
#     "@context": [
#       "https://w3id.org/dspace/2025/1/context.jsonld"
#     ],
#     "@type": "ContractNegotiation",
#     "consumerPid": "urn:consumer-pid:2e1f1986-c02c-44f0-8c47-f2b4fa75cc61",
#     "providerPid": "urn:provider-pid:5173ad8f-bbea-4253-a737-5d1f8c3107fd",
#     "state": "OFFERED"
#   },
#   "negotiationAgentModel": {
#     "id": "urn:negotiation-process:db89adba-c15e-41dd-8d4c-5b10a6a27467",
#     "state": "OFFERED",
#     "stateAttribute": null,
#     "associatedAgentPeer": "did:jwk:...",
#     "protocol": "DSP",
#     "callbackAddress": "http://127.0.0.1:1100/dsp/current",
#     "role": "Provider",
#     "properties": {},
#     "errorDetails": null,
#     "createdAt": "2026-08-20T22:26:55.233698Z",
#     "updatedAt": "2026-08-20T22:26:56.305448Z",
#     "identifiers": {
#       "consumerPid": "urn:consumer-pid:2e1f1986-c02c-44f0-8c47-f2b4fa75cc61",
#       "providerPid": "urn:provider-pid:5173ad8f-bbea-4253-a737-5d1f8c3107fd"
#     },
#     "messages": [
#       {
#         "id": "urn:negotiation-message:14f371fb-5128-496e-9e1f-b68c52e18428",
#         "negotiationAgentProcessId": "urn:negotiation-process:db89adba-c15e-41dd-8d4c-5b10a6a27467",
#         "createdAt": "2026-08-20T22:26:55.249534Z",
#         "direction": "INBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractRequestMessage",
#         "stateTransitionFrom": "-",
#         "stateTransitionTo": "REQUESTED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractRequestMessage",
#           "callbackAddress": "http://127.0.0.1:1100/dsp/current",
#           "consumerPid": "urn:consumer-pid:2e1f1986-c02c-44f0-8c47-f2b4fa75cc61",
#           "offer": {
#             "@id": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#             "@type": "Offer",
#             "permission": [
#               {
#                 "action": "use",
#                 "constraint": [
#                   {
#                     "leftOperand": "count",
#                     "operator": "gt",
#                     "rightOperand": "18"
#                   }
#                 ]
#               }
#             ],
#             "target": "urn:dataset:875dedc3-cb03-4f26-a865-be1eb295dc0a"
#           }
#         }
#       },
#       {
#         "id": "urn:negotiation-message:c34a7f02-76fa-4e22-a309-bc10db926796",
#         "negotiationAgentProcessId": "urn:negotiation-process:db89adba-c15e-41dd-8d4c-5b10a6a27467",
#         "createdAt": "2026-08-20T22:26:55.908592Z",
#         "direction": "OUTBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractOfferMessage",
#         "stateTransitionFrom": "REQUESTED",
#         "stateTransitionTo": "OFFERED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractOfferMessage",
#           "consumerPid": "urn:consumer-pid:2e1f1986-c02c-44f0-8c47-f2b4fa75cc61",
#           "offer": {
#             "@id": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#             "@type": "Offer",
#             "permission": [
#               {
#                 "action": "use",
#                 "constraint": [
#                   {
#                     "leftOperand": "count",
#                     "operator": "gt",
#                     "rightOperand": "21"
#                   }
#                 ]
#               }
#             ],
#             "target": "urn:dataset:875dedc3-cb03-4f26-a865-be1eb295dc0a"
#           },
#           "providerPid": "urn:provider-pid:5173ad8f-bbea-4253-a737-5d1f8c3107fd"
#         }
#       },
#       {
#         "id": "urn:negotiation-message:5c75cade-e5af-4540-b093-53b50e52b59a",
#         "negotiationAgentProcessId": "urn:negotiation-process:db89adba-c15e-41dd-8d4c-5b10a6a27467",
#         "createdAt": "2026-08-20T22:26:56.047636Z",
#         "direction": "INBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractRequestMessage",
#         "stateTransitionFrom": "OFFERED",
#         "stateTransitionTo": "REQUESTED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractRequestMessage",
#           "consumerPid": "urn:consumer-pid:2e1f1986-c02c-44f0-8c47-f2b4fa75cc61",
#           "offer": {
#             "@id": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#             "@type": "Offer",
#             "permission": [
#               {
#                 "action": "use"
#               }
#             ],
#             "target": "urn:dataset:875dedc3-cb03-4f26-a865-be1eb295dc0a"
#           },
#           "providerPid": "urn:provider-pid:5173ad8f-bbea-4253-a737-5d1f8c3107fd"
#         }
#       },
#       {
#         "id": "urn:negotiation-message:6d125471-6f06-4846-854d-50e5a14e0e86",
#         "negotiationAgentProcessId": "urn:negotiation-process:db89adba-c15e-41dd-8d4c-5b10a6a27467",
#         "createdAt": "2026-08-20T22:26:56.309131Z",
#         "direction": "OUTBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractOfferMessage",
#         "stateTransitionFrom": "REQUESTED",
#         "stateTransitionTo": "OFFERED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractOfferMessage",
#           "consumerPid": "urn:consumer-pid:2e1f1986-c02c-44f0-8c47-f2b4fa75cc61",
#           "offer": {
#             "@id": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#             "@type": "Offer",
#             "permission": [
#               {
#                 "action": "supermegause"
#               }
#             ],
#             "target": "urn:dataset:875dedc3-cb03-4f26-a865-be1eb295dc0a"
#           },
#           "providerPid": "urn:provider-pid:5173ad8f-bbea-4253-a737-5d1f8c3107fd"
#         }
#       }
#     ],
#     "offers": [
#       {
#         "id": "urn:offer:0bfb1bfe-f4d4-4985-95c4-ceed0f144163",
#         "negotiationAgentProcessId": "urn:negotiation-process:db89adba-c15e-41dd-8d4c-5b10a6a27467",
#         "negotiationAgentMessageId": "urn:negotiation-message:14f371fb-5128-496e-9e1f-b68c52e18428",
#         "offerId": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#         "offerContent": {
#           "@id": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#           "@type": "Offer",
#           "permission": [
#             {
#               "action": "use",
#               "constraint": [
#                 {
#                   "leftOperand": "count",
#                   "operator": "gt",
#                   "rightOperand": "18"
#                 }
#               ]
#             }
#           ],
#           "target": "urn:dataset:875dedc3-cb03-4f26-a865-be1eb295dc0a"
#         },
#         "createdAt": "2026-08-20T22:26:55.250718Z"
#       },
#       {
#         "id": "urn:offer:b1303cb4-0e17-4768-91b3-315bb5a2b665",
#         "negotiationAgentProcessId": "urn:negotiation-process:db89adba-c15e-41dd-8d4c-5b10a6a27467",
#         "negotiationAgentMessageId": "urn:negotiation-message:c34a7f02-76fa-4e22-a309-bc10db926796",
#         "offerId": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#         "offerContent": {
#           "@id": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#           "@type": "Offer",
#           "permission": [
#             {
#               "action": "use",
#               "constraint": [
#                 {
#                   "leftOperand": "count",
#                   "operator": "gt",
#                   "rightOperand": "21"
#                 }
#               ]
#             }
#           ],
#           "target": "urn:dataset:875dedc3-cb03-4f26-a865-be1eb295dc0a"
#         },
#         "createdAt": "2026-08-20T22:26:55.910692Z"
#       },
#       {
#         "id": "urn:offer:fb017091-3cda-475a-9f46-b3a0f1665f4c",
#         "negotiationAgentProcessId": "urn:negotiation-process:db89adba-c15e-41dd-8d4c-5b10a6a27467",
#         "negotiationAgentMessageId": "urn:negotiation-message:5c75cade-e5af-4540-b093-53b50e52b59a",
#         "offerId": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#         "offerContent": {
#           "@id": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#           "@type": "Offer",
#           "permission": [
#             {
#               "action": "use"
#             }
#           ],
#           "target": "urn:dataset:875dedc3-cb03-4f26-a865-be1eb295dc0a"
#         },
#         "createdAt": "2026-08-20T22:26:56.050165Z"
#       },
#       {
#         "id": "urn:offer:84f33663-c82a-49e3-8cec-8a456793595c",
#         "negotiationAgentProcessId": "urn:negotiation-process:db89adba-c15e-41dd-8d4c-5b10a6a27467",
#         "negotiationAgentMessageId": "urn:negotiation-message:6d125471-6f06-4846-854d-50e5a14e0e86",
#         "offerId": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#         "offerContent": {
#           "@id": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#           "@type": "Offer",
#           "permission": [
#             {
#               "action": "supermegause"
#             }
#           ],
#           "target": "urn:dataset:875dedc3-cb03-4f26-a865-be1eb295dc0a"
#         },
#         "createdAt": "2026-08-20T22:26:56.310999Z"
#       }
#     ],
#     "agreement": null
#   }
# }

# %% [markdown]
# ## Consumer accepts the offer (Consumer -> Provider)

# %%
url = data_space_consumer + "/dsp/current/negotiations/rpc/setup-acceptance"
payload = {
    "consumerPid": cn_consumer_id,
    "providerPid": cn_provider_id
}
response = requests.request("POST", url, headers=json_header, data=json.dumps(payload))
response_as_json = response.json()
try:
    print(json.dumps(response_as_json, indent=2))
except KeyError:
    print("Error in response, check the payload and the endpoint.")
    print(json.dumps(response_as_json, indent=2))
    raise
# Out:
# {
#   "request": {
#     "providerPid": "urn:provider-pid:5173ad8f-bbea-4253-a737-5d1f8c3107fd",
#     "consumerPid": "urn:consumer-pid:2e1f1986-c02c-44f0-8c47-f2b4fa75cc61"
#   },
#   "response": {
#     "@context": [
#       "https://w3id.org/dspace/2025/1/context.jsonld"
#     ],
#     "@type": "ContractNegotiation",
#     "consumerPid": "urn:consumer-pid:2e1f1986-c02c-44f0-8c47-f2b4fa75cc61",
#     "providerPid": "urn:provider-pid:5173ad8f-bbea-4253-a737-5d1f8c3107fd",
#     "state": "ACCEPTED"
#   },
#   "negotiationAgentModel": {
#     "id": "urn:negotiation-process:ef296f8e-b3a3-487c-b3b3-575b024278f5",
#     "state": "ACCEPTED",
#     "stateAttribute": null,
#     "associatedAgentPeer": "did:jwk:...",
#     "protocol": "DSP",
#     "callbackAddress": "http://127.0.0.1:1200/dsp/current",
#     "role": "Consumer",
#     "properties": {},
#     "errorDetails": null,
#     "createdAt": "2026-08-20T22:26:55.252336Z",
#     "updatedAt": "2026-08-20T22:26:56.366466Z",
#     "identifiers": {
#       "consumerPid": "urn:consumer-pid:2e1f1986-c02c-44f0-8c47-f2b4fa75cc61",
#       "providerPid": "urn:provider-pid:5173ad8f-bbea-4253-a737-5d1f8c3107fd"
#     },
#     "messages": [
#       {
#         "id": "urn:negotiation-message:ba9ea65d-e085-4efa-acae-1efa34ebd65d",
#         "negotiationAgentProcessId": "urn:negotiation-process:ef296f8e-b3a3-487c-b3b3-575b024278f5",
#         "createdAt": "2026-08-20T22:26:55.263711Z",
#         "direction": "OUTBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractRequestMessage",
#         "stateTransitionFrom": "-",
#         "stateTransitionTo": "REQUESTED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractRequestMessage",
#           "associatedAgentPeer": "did:jwk:...",
#           "callbackAddress": "http://127.0.0.1:1100/dsp/current",
#           "offer": {
#             "@id": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#             "@type": "Offer",
#             "permission": [
#               {
#                 "action": "use",
#                 "constraint": [
#                   {
#                     "leftOperand": "count",
#                     "operator": "gt",
#                     "rightOperand": "18"
#                   }
#                 ]
#               }
#             ],
#             "target": "urn:dataset:875dedc3-cb03-4f26-a865-be1eb295dc0a"
#           },
#           "providerAddress": "http://127.0.0.1:1200/dsp/current"
#         }
#       },
#       {
#         "id": "urn:negotiation-message:88be8052-75e0-406d-8bbc-6bd0a8e25d0f",
#         "negotiationAgentProcessId": "urn:negotiation-process:ef296f8e-b3a3-487c-b3b3-575b024278f5",
#         "createdAt": "2026-08-20T22:26:55.880964Z",
#         "direction": "INBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractOfferMessage",
#         "stateTransitionFrom": "REQUESTED",
#         "stateTransitionTo": "OFFERED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractOfferMessage",
#           "consumerPid": "urn:consumer-pid:2e1f1986-c02c-44f0-8c47-f2b4fa75cc61",
#           "offer": {
#             "@id": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#             "@type": "Offer",
#             "permission": [
#               {
#                 "action": "use",
#                 "constraint": [
#                   {
#                     "leftOperand": "count",
#                     "operator": "gt",
#                     "rightOperand": "21"
#                   }
#                 ]
#               }
#             ],
#             "target": "urn:dataset:875dedc3-cb03-4f26-a865-be1eb295dc0a"
#           },
#           "providerPid": "urn:provider-pid:5173ad8f-bbea-4253-a737-5d1f8c3107fd"
#         }
#       },
#       {
#         "id": "urn:negotiation-message:77270604-d8f4-490d-8155-2fef29f550b7",
#         "negotiationAgentProcessId": "urn:negotiation-process:ef296f8e-b3a3-487c-b3b3-575b024278f5",
#         "createdAt": "2026-08-20T22:26:56.070021Z",
#         "direction": "OUTBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractRequestMessage",
#         "stateTransitionFrom": "OFFERED",
#         "stateTransitionTo": "REQUESTED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractRequestMessage",
#           "consumerPid": "urn:consumer-pid:2e1f1986-c02c-44f0-8c47-f2b4fa75cc61",
#           "offer": {
#             "@id": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#             "@type": "Offer",
#             "permission": [
#               {
#                 "action": "use"
#               }
#             ],
#             "target": "urn:dataset:875dedc3-cb03-4f26-a865-be1eb295dc0a"
#           },
#           "providerPid": "urn:provider-pid:5173ad8f-bbea-4253-a737-5d1f8c3107fd"
#         }
#       },
#       {
#         "id": "urn:negotiation-message:c503bab2-c6a6-45a6-84c9-b5aafc02ed5d",
#         "negotiationAgentProcessId": "urn:negotiation-process:ef296f8e-b3a3-487c-b3b3-575b024278f5",
#         "createdAt": "2026-08-20T22:26:56.296937Z",
#         "direction": "INBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractOfferMessage",
#         "stateTransitionFrom": "REQUESTED",
#         "stateTransitionTo": "OFFERED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractOfferMessage",
#           "consumerPid": "urn:consumer-pid:2e1f1986-c02c-44f0-8c47-f2b4fa75cc61",
#           "offer": {
#             "@id": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#             "@type": "Offer",
#             "permission": [
#               {
#                 "action": "supermegause"
#               }
#             ],
#             "target": "urn:dataset:875dedc3-cb03-4f26-a865-be1eb295dc0a"
#           },
#           "providerPid": "urn:provider-pid:5173ad8f-bbea-4253-a737-5d1f8c3107fd"
#         }
#       },
#       {
#         "id": "urn:negotiation-message:d5e37efd-641e-4e02-b033-9e0fd87452f6",
#         "negotiationAgentProcessId": "urn:negotiation-process:ef296f8e-b3a3-487c-b3b3-575b024278f5",
#         "createdAt": "2026-08-20T22:26:56.369379Z",
#         "direction": "OUTBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractNegotiationEventMessage",
#         "stateTransitionFrom": "OFFERED",
#         "stateTransitionTo": "ACCEPTED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractNegotiationEventMessage",
#           "consumerPid": "urn:consumer-pid:2e1f1986-c02c-44f0-8c47-f2b4fa75cc61",
#           "providerPid": "urn:provider-pid:5173ad8f-bbea-4253-a737-5d1f8c3107fd"
#         }
#       }
#     ],
#     "offers": [
#       {
#         "id": "urn:offer:7b8a0682-7655-4d5a-9ddd-2f5ee8dac726",
#         "negotiationAgentProcessId": "urn:negotiation-process:ef296f8e-b3a3-487c-b3b3-575b024278f5",
#         "negotiationAgentMessageId": "urn:negotiation-message:ba9ea65d-e085-4efa-acae-1efa34ebd65d",
#         "offerId": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#         "offerContent": {
#           "@id": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#           "@type": "Offer",
#           "permission": [
#             {
#               "action": "use",
#               "constraint": [
#                 {
#                   "leftOperand": "count",
#                   "operator": "gt",
#                   "rightOperand": "18"
#                 }
#               ]
#             }
#           ],
#           "target": "urn:dataset:875dedc3-cb03-4f26-a865-be1eb295dc0a"
#         },
#         "createdAt": "2026-08-20T22:26:55.265509Z"
#       },
#       {
#         "id": "urn:offer:449d2e1f-b507-4ab6-9cb9-278b03e1c798",
#         "negotiationAgentProcessId": "urn:negotiation-process:ef296f8e-b3a3-487c-b3b3-575b024278f5",
#         "negotiationAgentMessageId": "urn:negotiation-message:88be8052-75e0-406d-8bbc-6bd0a8e25d0f",
#         "offerId": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#         "offerContent": {
#           "@id": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#           "@type": "Offer",
#           "permission": [
#             {
#               "action": "use",
#               "constraint": [
#                 {
#                   "leftOperand": "count",
#                   "operator": "gt",
#                   "rightOperand": "21"
#                 }
#               ]
#             }
#           ],
#           "target": "urn:dataset:875dedc3-cb03-4f26-a865-be1eb295dc0a"
#         },
#         "createdAt": "2026-08-20T22:26:55.884668Z"
#       },
#       {
#         "id": "urn:offer:a122eb07-4f68-4a0f-ae19-3b4464aaec93",
#         "negotiationAgentProcessId": "urn:negotiation-process:ef296f8e-b3a3-487c-b3b3-575b024278f5",
#         "negotiationAgentMessageId": "urn:negotiation-message:77270604-d8f4-490d-8155-2fef29f550b7",
#         "offerId": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#         "offerContent": {
#           "@id": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#           "@type": "Offer",
#           "permission": [
#             {
#               "action": "use"
#             }
#           ],
#           "target": "urn:dataset:875dedc3-cb03-4f26-a865-be1eb295dc0a"
#         },
#         "createdAt": "2026-08-20T22:26:56.071779Z"
#       },
#       {
#         "id": "urn:offer:28c5b03e-0a27-4844-bfd5-400465380706",
#         "negotiationAgentProcessId": "urn:negotiation-process:ef296f8e-b3a3-487c-b3b3-575b024278f5",
#         "negotiationAgentMessageId": "urn:negotiation-message:c503bab2-c6a6-45a6-84c9-b5aafc02ed5d",
#         "offerId": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#         "offerContent": {
#           "@id": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#           "@type": "Offer",
#           "permission": [
#             {
#               "action": "supermegause"
#             }
#           ],
#           "target": "urn:dataset:875dedc3-cb03-4f26-a865-be1eb295dc0a"
#         },
#         "createdAt": "2026-08-20T22:26:56.298327Z"
#       }
#     ],
#     "agreement": null
#   }
# }

# %% [markdown]
# ## Provider creates the Agreement (Provider -> Consumer)

# %%
url = data_space_provider + "/dsp/current/negotiations/rpc/setup-agreement"
payload = {
    "consumerPid": cn_consumer_id,
    "providerPid": cn_provider_id
}
response = requests.request("POST", url, headers=json_header, data=json.dumps(payload))
response_as_json = response.json()
try:
    print(json.dumps(response_as_json, indent=2))
except KeyError:
    print("Error in response, check the payload and the endpoint.")
    print(json.dumps(response_as_json, indent=2))
    raise
# Out:
# {
#   "request": {
#     "providerPid": "urn:provider-pid:5173ad8f-bbea-4253-a737-5d1f8c3107fd",
#     "consumerPid": "urn:consumer-pid:2e1f1986-c02c-44f0-8c47-f2b4fa75cc61"
#   },
#   "response": {
#     "@context": [
#       "https://w3id.org/dspace/2025/1/context.jsonld"
#     ],
#     "@type": "ContractNegotiation",
#     "consumerPid": "urn:consumer-pid:2e1f1986-c02c-44f0-8c47-f2b4fa75cc61",
#     "providerPid": "urn:provider-pid:5173ad8f-bbea-4253-a737-5d1f8c3107fd",
#     "state": "AGREED"
#   },
#   "negotiationAgentModel": {
#     "id": "urn:negotiation-process:db89adba-c15e-41dd-8d4c-5b10a6a27467",
#     "state": "AGREED",
#     "stateAttribute": null,
#     "associatedAgentPeer": "did:jwk:...",
#     "protocol": "DSP",
#     "callbackAddress": "http://127.0.0.1:1100/dsp/current",
#     "role": "Provider",
#     "properties": {},
#     "errorDetails": null,
#     "createdAt": "2026-08-20T22:26:55.233698Z",
#     "updatedAt": "2026-08-20T22:26:56.599597Z",
#     "identifiers": {
#       "consumerPid": "urn:consumer-pid:2e1f1986-c02c-44f0-8c47-f2b4fa75cc61",
#       "providerPid": "urn:provider-pid:5173ad8f-bbea-4253-a737-5d1f8c3107fd"
#     },
#     "messages": [
#       {
#         "id": "urn:negotiation-message:14f371fb-5128-496e-9e1f-b68c52e18428",
#         "negotiationAgentProcessId": "urn:negotiation-process:db89adba-c15e-41dd-8d4c-5b10a6a27467",
#         "createdAt": "2026-08-20T22:26:55.249534Z",
#         "direction": "INBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractRequestMessage",
#         "stateTransitionFrom": "-",
#         "stateTransitionTo": "REQUESTED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractRequestMessage",
#           "callbackAddress": "http://127.0.0.1:1100/dsp/current",
#           "consumerPid": "urn:consumer-pid:2e1f1986-c02c-44f0-8c47-f2b4fa75cc61",
#           "offer": {
#             "@id": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#             "@type": "Offer",
#             "permission": [
#               {
#                 "action": "use",
#                 "constraint": [
#                   {
#                     "leftOperand": "count",
#                     "operator": "gt",
#                     "rightOperand": "18"
#                   }
#                 ]
#               }
#             ],
#             "target": "urn:dataset:875dedc3-cb03-4f26-a865-be1eb295dc0a"
#           }
#         }
#       },
#       {
#         "id": "urn:negotiation-message:c34a7f02-76fa-4e22-a309-bc10db926796",
#         "negotiationAgentProcessId": "urn:negotiation-process:db89adba-c15e-41dd-8d4c-5b10a6a27467",
#         "createdAt": "2026-08-20T22:26:55.908592Z",
#         "direction": "OUTBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractOfferMessage",
#         "stateTransitionFrom": "REQUESTED",
#         "stateTransitionTo": "OFFERED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractOfferMessage",
#           "consumerPid": "urn:consumer-pid:2e1f1986-c02c-44f0-8c47-f2b4fa75cc61",
#           "offer": {
#             "@id": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#             "@type": "Offer",
#             "permission": [
#               {
#                 "action": "use",
#                 "constraint": [
#                   {
#                     "leftOperand": "count",
#                     "operator": "gt",
#                     "rightOperand": "21"
#                   }
#                 ]
#               }
#             ],
#             "target": "urn:dataset:875dedc3-cb03-4f26-a865-be1eb295dc0a"
#           },
#           "providerPid": "urn:provider-pid:5173ad8f-bbea-4253-a737-5d1f8c3107fd"
#         }
#       },
#       {
#         "id": "urn:negotiation-message:5c75cade-e5af-4540-b093-53b50e52b59a",
#         "negotiationAgentProcessId": "urn:negotiation-process:db89adba-c15e-41dd-8d4c-5b10a6a27467",
#         "createdAt": "2026-08-20T22:26:56.047636Z",
#         "direction": "INBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractRequestMessage",
#         "stateTransitionFrom": "OFFERED",
#         "stateTransitionTo": "REQUESTED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractRequestMessage",
#           "consumerPid": "urn:consumer-pid:2e1f1986-c02c-44f0-8c47-f2b4fa75cc61",
#           "offer": {
#             "@id": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#             "@type": "Offer",
#             "permission": [
#               {
#                 "action": "use"
#               }
#             ],
#             "target": "urn:dataset:875dedc3-cb03-4f26-a865-be1eb295dc0a"
#           },
#           "providerPid": "urn:provider-pid:5173ad8f-bbea-4253-a737-5d1f8c3107fd"
#         }
#       },
#       {
#         "id": "urn:negotiation-message:6d125471-6f06-4846-854d-50e5a14e0e86",
#         "negotiationAgentProcessId": "urn:negotiation-process:db89adba-c15e-41dd-8d4c-5b10a6a27467",
#         "createdAt": "2026-08-20T22:26:56.309131Z",
#         "direction": "OUTBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractOfferMessage",
#         "stateTransitionFrom": "REQUESTED",
#         "stateTransitionTo": "OFFERED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractOfferMessage",
#           "consumerPid": "urn:consumer-pid:2e1f1986-c02c-44f0-8c47-f2b4fa75cc61",
#           "offer": {
#             "@id": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#             "@type": "Offer",
#             "permission": [
#               {
#                 "action": "supermegause"
#               }
#             ],
#             "target": "urn:dataset:875dedc3-cb03-4f26-a865-be1eb295dc0a"
#           },
#           "providerPid": "urn:provider-pid:5173ad8f-bbea-4253-a737-5d1f8c3107fd"
#         }
#       },
#       {
#         "id": "urn:negotiation-message:90bd1cb3-d8fe-4328-afff-ab01c54ffe18",
#         "negotiationAgentProcessId": "urn:negotiation-process:db89adba-c15e-41dd-8d4c-5b10a6a27467",
#         "createdAt": "2026-08-20T22:26:56.359390Z",
#         "direction": "INBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractNegotiationEventMessage",
#         "stateTransitionFrom": "OFFERED",
#         "stateTransitionTo": "ACCEPTED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractNegotiationEventMessage",
#           "consumerPid": "urn:consumer-pid:2e1f1986-c02c-44f0-8c47-f2b4fa75cc61",
#           "eventType": "ACCEPTED",
#           "providerPid": "urn:provider-pid:5173ad8f-bbea-4253-a737-5d1f8c3107fd"
#         }
#       },
#       {
#         "id": "urn:negotiation-message:f2d0e61f-c330-4318-95ac-ec40c756eac7",
#         "negotiationAgentProcessId": "urn:negotiation-process:db89adba-c15e-41dd-8d4c-5b10a6a27467",
#         "createdAt": "2026-08-20T22:26:56.605754Z",
#         "direction": "OUTBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractAgreementMessage",
#         "stateTransitionFrom": "ACCEPTED",
#         "stateTransitionTo": "AGREED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractAgreementMessage",
#           "consumerPid": "urn:consumer-pid:2e1f1986-c02c-44f0-8c47-f2b4fa75cc61",
#           "providerPid": "urn:provider-pid:5173ad8f-bbea-4253-a737-5d1f8c3107fd"
#         }
#       }
#     ],
#     "offers": [
#       {
#         "id": "urn:offer:0bfb1bfe-f4d4-4985-95c4-ceed0f144163",
#         "negotiationAgentProcessId": "urn:negotiation-process:db89adba-c15e-41dd-8d4c-5b10a6a27467",
#         "negotiationAgentMessageId": "urn:negotiation-message:14f371fb-5128-496e-9e1f-b68c52e18428",
#         "offerId": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#         "offerContent": {
#           "@id": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#           "@type": "Offer",
#           "permission": [
#             {
#               "action": "use",
#               "constraint": [
#                 {
#                   "leftOperand": "count",
#                   "operator": "gt",
#                   "rightOperand": "18"
#                 }
#               ]
#             }
#           ],
#           "target": "urn:dataset:875dedc3-cb03-4f26-a865-be1eb295dc0a"
#         },
#         "createdAt": "2026-08-20T22:26:55.250718Z"
#       },
#       {
#         "id": "urn:offer:b1303cb4-0e17-4768-91b3-315bb5a2b665",
#         "negotiationAgentProcessId": "urn:negotiation-process:db89adba-c15e-41dd-8d4c-5b10a6a27467",
#         "negotiationAgentMessageId": "urn:negotiation-message:c34a7f02-76fa-4e22-a309-bc10db926796",
#         "offerId": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#         "offerContent": {
#           "@id": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#           "@type": "Offer",
#           "permission": [
#             {
#               "action": "use",
#               "constraint": [
#                 {
#                   "leftOperand": "count",
#                   "operator": "gt",
#                   "rightOperand": "21"
#                 }
#               ]
#             }
#           ],
#           "target": "urn:dataset:875dedc3-cb03-4f26-a865-be1eb295dc0a"
#         },
#         "createdAt": "2026-08-20T22:26:55.910692Z"
#       },
#       {
#         "id": "urn:offer:fb017091-3cda-475a-9f46-b3a0f1665f4c",
#         "negotiationAgentProcessId": "urn:negotiation-process:db89adba-c15e-41dd-8d4c-5b10a6a27467",
#         "negotiationAgentMessageId": "urn:negotiation-message:5c75cade-e5af-4540-b093-53b50e52b59a",
#         "offerId": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#         "offerContent": {
#           "@id": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#           "@type": "Offer",
#           "permission": [
#             {
#               "action": "use"
#             }
#           ],
#           "target": "urn:dataset:875dedc3-cb03-4f26-a865-be1eb295dc0a"
#         },
#         "createdAt": "2026-08-20T22:26:56.050165Z"
#       },
#       {
#         "id": "urn:offer:84f33663-c82a-49e3-8cec-8a456793595c",
#         "negotiationAgentProcessId": "urn:negotiation-process:db89adba-c15e-41dd-8d4c-5b10a6a27467",
#         "negotiationAgentMessageId": "urn:negotiation-message:6d125471-6f06-4846-854d-50e5a14e0e86",
#         "offerId": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#         "offerContent": {
#           "@id": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#           "@type": "Offer",
#           "permission": [
#             {
#               "action": "supermegause"
#             }
#           ],
#           "target": "urn:dataset:875dedc3-cb03-4f26-a865-be1eb295dc0a"
#         },
#         "createdAt": "2026-08-20T22:26:56.310999Z"
#       }
#     ],
#     "agreement": {
#       "id": "urn:agreement:d29ef490-f76f-4e8e-a979-29e55ba8a5d7",
#       "negotiationAgentProcessId": "urn:negotiation-process:db89adba-c15e-41dd-8d4c-5b10a6a27467",
#       "negotiationAgentMessageId": "urn:negotiation-message:f2d0e61f-c330-4318-95ac-ec40c756eac7",
#       "consumerParticipantId": "did:jwk:...",
#       "providerParticipantId": "did:jwk:...",
#       "agreementContent": {
#         "@id": "urn:agreement:d29ef490-f76f-4e8e-a979-29e55ba8a5d7",
#         "@type": "Agreement",
#         "assignee": "did:jwk:...",
#         "assigner": "did:jwk:...",
#         "permission": [
#           {
#             "action": "supermegause"
#           }
#         ],
#         "target": "urn:dataset:875dedc3-cb03-4f26-a865-be1eb295dc0a",
#         "timestamp": "1787264816"
#       },
#       "target": "urn:dataset:875dedc3-cb03-4f26-a865-be1eb295dc0a",
#       "state": "REQUESTED",
#       "createdAt": "2026-08-20T22:26:56.607342Z",
#       "updatedAt": null
#     }
#   }
# }

# %% [markdown]
# ## Consumer verifies the agreement (Consumer -> Provider)

# %%
url = data_space_consumer + "/dsp/current/negotiations/rpc/setup-verification"
payload = {
    "consumerPid": cn_consumer_id,
    "providerPid": cn_provider_id
}
response = requests.request("POST", url, headers=json_header, data=json.dumps(payload))
response_as_json = response.json()
try:
    print(json.dumps(response_as_json, indent=2))
except KeyError:
    print("Error in response, check the payload and the endpoint.")
    print(json.dumps(response_as_json, indent=2))
    raise
# Out:
# {
#   "request": {
#     "providerPid": "urn:provider-pid:5173ad8f-bbea-4253-a737-5d1f8c3107fd",
#     "consumerPid": "urn:consumer-pid:2e1f1986-c02c-44f0-8c47-f2b4fa75cc61"
#   },
#   "response": {
#     "@context": [
#       "https://w3id.org/dspace/2025/1/context.jsonld"
#     ],
#     "@type": "ContractNegotiation",
#     "consumerPid": "urn:consumer-pid:2e1f1986-c02c-44f0-8c47-f2b4fa75cc61",
#     "providerPid": "urn:provider-pid:5173ad8f-bbea-4253-a737-5d1f8c3107fd",
#     "state": "VERIFIED"
#   },
#   "negotiationAgentModel": {
#     "id": "urn:negotiation-process:ef296f8e-b3a3-487c-b3b3-575b024278f5",
#     "state": "VERIFIED",
#     "stateAttribute": null,
#     "associatedAgentPeer": "did:jwk:...",
#     "protocol": "DSP",
#     "callbackAddress": "http://127.0.0.1:1200/dsp/current",
#     "role": "Consumer",
#     "properties": {},
#     "errorDetails": null,
#     "createdAt": "2026-08-20T22:26:55.252336Z",
#     "updatedAt": "2026-08-20T22:26:56.703633Z",
#     "identifiers": {
#       "consumerPid": "urn:consumer-pid:2e1f1986-c02c-44f0-8c47-f2b4fa75cc61",
#       "providerPid": "urn:provider-pid:5173ad8f-bbea-4253-a737-5d1f8c3107fd"
#     },
#     "messages": [
#       {
#         "id": "urn:negotiation-message:ba9ea65d-e085-4efa-acae-1efa34ebd65d",
#         "negotiationAgentProcessId": "urn:negotiation-process:ef296f8e-b3a3-487c-b3b3-575b024278f5",
#         "createdAt": "2026-08-20T22:26:55.263711Z",
#         "direction": "OUTBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractRequestMessage",
#         "stateTransitionFrom": "-",
#         "stateTransitionTo": "REQUESTED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractRequestMessage",
#           "associatedAgentPeer": "did:jwk:...",
#           "callbackAddress": "http://127.0.0.1:1100/dsp/current",
#           "offer": {
#             "@id": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#             "@type": "Offer",
#             "permission": [
#               {
#                 "action": "use",
#                 "constraint": [
#                   {
#                     "leftOperand": "count",
#                     "operator": "gt",
#                     "rightOperand": "18"
#                   }
#                 ]
#               }
#             ],
#             "target": "urn:dataset:875dedc3-cb03-4f26-a865-be1eb295dc0a"
#           },
#           "providerAddress": "http://127.0.0.1:1200/dsp/current"
#         }
#       },
#       {
#         "id": "urn:negotiation-message:88be8052-75e0-406d-8bbc-6bd0a8e25d0f",
#         "negotiationAgentProcessId": "urn:negotiation-process:ef296f8e-b3a3-487c-b3b3-575b024278f5",
#         "createdAt": "2026-08-20T22:26:55.880964Z",
#         "direction": "INBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractOfferMessage",
#         "stateTransitionFrom": "REQUESTED",
#         "stateTransitionTo": "OFFERED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractOfferMessage",
#           "consumerPid": "urn:consumer-pid:2e1f1986-c02c-44f0-8c47-f2b4fa75cc61",
#           "offer": {
#             "@id": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#             "@type": "Offer",
#             "permission": [
#               {
#                 "action": "use",
#                 "constraint": [
#                   {
#                     "leftOperand": "count",
#                     "operator": "gt",
#                     "rightOperand": "21"
#                   }
#                 ]
#               }
#             ],
#             "target": "urn:dataset:875dedc3-cb03-4f26-a865-be1eb295dc0a"
#           },
#           "providerPid": "urn:provider-pid:5173ad8f-bbea-4253-a737-5d1f8c3107fd"
#         }
#       },
#       {
#         "id": "urn:negotiation-message:77270604-d8f4-490d-8155-2fef29f550b7",
#         "negotiationAgentProcessId": "urn:negotiation-process:ef296f8e-b3a3-487c-b3b3-575b024278f5",
#         "createdAt": "2026-08-20T22:26:56.070021Z",
#         "direction": "OUTBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractRequestMessage",
#         "stateTransitionFrom": "OFFERED",
#         "stateTransitionTo": "REQUESTED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractRequestMessage",
#           "consumerPid": "urn:consumer-pid:2e1f1986-c02c-44f0-8c47-f2b4fa75cc61",
#           "offer": {
#             "@id": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#             "@type": "Offer",
#             "permission": [
#               {
#                 "action": "use"
#               }
#             ],
#             "target": "urn:dataset:875dedc3-cb03-4f26-a865-be1eb295dc0a"
#           },
#           "providerPid": "urn:provider-pid:5173ad8f-bbea-4253-a737-5d1f8c3107fd"
#         }
#       },
#       {
#         "id": "urn:negotiation-message:c503bab2-c6a6-45a6-84c9-b5aafc02ed5d",
#         "negotiationAgentProcessId": "urn:negotiation-process:ef296f8e-b3a3-487c-b3b3-575b024278f5",
#         "createdAt": "2026-08-20T22:26:56.296937Z",
#         "direction": "INBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractOfferMessage",
#         "stateTransitionFrom": "REQUESTED",
#         "stateTransitionTo": "OFFERED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractOfferMessage",
#           "consumerPid": "urn:consumer-pid:2e1f1986-c02c-44f0-8c47-f2b4fa75cc61",
#           "offer": {
#             "@id": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#             "@type": "Offer",
#             "permission": [
#               {
#                 "action": "supermegause"
#               }
#             ],
#             "target": "urn:dataset:875dedc3-cb03-4f26-a865-be1eb295dc0a"
#           },
#           "providerPid": "urn:provider-pid:5173ad8f-bbea-4253-a737-5d1f8c3107fd"
#         }
#       },
#       {
#         "id": "urn:negotiation-message:d5e37efd-641e-4e02-b033-9e0fd87452f6",
#         "negotiationAgentProcessId": "urn:negotiation-process:ef296f8e-b3a3-487c-b3b3-575b024278f5",
#         "createdAt": "2026-08-20T22:26:56.369379Z",
#         "direction": "OUTBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractNegotiationEventMessage",
#         "stateTransitionFrom": "OFFERED",
#         "stateTransitionTo": "ACCEPTED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractNegotiationEventMessage",
#           "consumerPid": "urn:consumer-pid:2e1f1986-c02c-44f0-8c47-f2b4fa75cc61",
#           "providerPid": "urn:provider-pid:5173ad8f-bbea-4253-a737-5d1f8c3107fd"
#         }
#       },
#       {
#         "id": "urn:negotiation-message:fc4aaacb-1964-40af-a0f3-cf27d8c0fc74",
#         "negotiationAgentProcessId": "urn:negotiation-process:ef296f8e-b3a3-487c-b3b3-575b024278f5",
#         "createdAt": "2026-08-20T22:26:56.583615Z",
#         "direction": "INBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractAgreementMessage",
#         "stateTransitionFrom": "ACCEPTED",
#         "stateTransitionTo": "AGREED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractAgreementMessage",
#           "agreement": {
#             "@id": "urn:agreement:d29ef490-f76f-4e8e-a979-29e55ba8a5d7",
#             "@type": "Agreement",
#             "assignee": "did:jwk:...",
#             "assigner": "did:jwk:...",
#             "permission": [
#               {
#                 "action": "supermegause"
#               }
#             ],
#             "target": "urn:dataset:875dedc3-cb03-4f26-a865-be1eb295dc0a",
#             "timestamp": "1787264816"
#           },
#           "consumerPid": "urn:consumer-pid:2e1f1986-c02c-44f0-8c47-f2b4fa75cc61",
#           "providerPid": "urn:provider-pid:5173ad8f-bbea-4253-a737-5d1f8c3107fd"
#         }
#       },
#       {
#         "id": "urn:negotiation-message:1ea09dd9-a93f-4c9c-b886-794476cdc7ba",
#         "negotiationAgentProcessId": "urn:negotiation-process:ef296f8e-b3a3-487c-b3b3-575b024278f5",
#         "createdAt": "2026-08-20T22:26:56.706500Z",
#         "direction": "OUTBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractAgreementVerificationMessage",
#         "stateTransitionFrom": "AGREED",
#         "stateTransitionTo": "VERIFIED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractAgreementVerificationMessage",
#           "consumerPid": "urn:consumer-pid:2e1f1986-c02c-44f0-8c47-f2b4fa75cc61",
#           "providerPid": "urn:provider-pid:5173ad8f-bbea-4253-a737-5d1f8c3107fd"
#         }
#       }
#     ],
#     "offers": [
#       {
#         "id": "urn:offer:7b8a0682-7655-4d5a-9ddd-2f5ee8dac726",
#         "negotiationAgentProcessId": "urn:negotiation-process:ef296f8e-b3a3-487c-b3b3-575b024278f5",
#         "negotiationAgentMessageId": "urn:negotiation-message:ba9ea65d-e085-4efa-acae-1efa34ebd65d",
#         "offerId": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#         "offerContent": {
#           "@id": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#           "@type": "Offer",
#           "permission": [
#             {
#               "action": "use",
#               "constraint": [
#                 {
#                   "leftOperand": "count",
#                   "operator": "gt",
#                   "rightOperand": "18"
#                 }
#               ]
#             }
#           ],
#           "target": "urn:dataset:875dedc3-cb03-4f26-a865-be1eb295dc0a"
#         },
#         "createdAt": "2026-08-20T22:26:55.265509Z"
#       },
#       {
#         "id": "urn:offer:449d2e1f-b507-4ab6-9cb9-278b03e1c798",
#         "negotiationAgentProcessId": "urn:negotiation-process:ef296f8e-b3a3-487c-b3b3-575b024278f5",
#         "negotiationAgentMessageId": "urn:negotiation-message:88be8052-75e0-406d-8bbc-6bd0a8e25d0f",
#         "offerId": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#         "offerContent": {
#           "@id": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#           "@type": "Offer",
#           "permission": [
#             {
#               "action": "use",
#               "constraint": [
#                 {
#                   "leftOperand": "count",
#                   "operator": "gt",
#                   "rightOperand": "21"
#                 }
#               ]
#             }
#           ],
#           "target": "urn:dataset:875dedc3-cb03-4f26-a865-be1eb295dc0a"
#         },
#         "createdAt": "2026-08-20T22:26:55.884668Z"
#       },
#       {
#         "id": "urn:offer:a122eb07-4f68-4a0f-ae19-3b4464aaec93",
#         "negotiationAgentProcessId": "urn:negotiation-process:ef296f8e-b3a3-487c-b3b3-575b024278f5",
#         "negotiationAgentMessageId": "urn:negotiation-message:77270604-d8f4-490d-8155-2fef29f550b7",
#         "offerId": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#         "offerContent": {
#           "@id": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#           "@type": "Offer",
#           "permission": [
#             {
#               "action": "use"
#             }
#           ],
#           "target": "urn:dataset:875dedc3-cb03-4f26-a865-be1eb295dc0a"
#         },
#         "createdAt": "2026-08-20T22:26:56.071779Z"
#       },
#       {
#         "id": "urn:offer:28c5b03e-0a27-4844-bfd5-400465380706",
#         "negotiationAgentProcessId": "urn:negotiation-process:ef296f8e-b3a3-487c-b3b3-575b024278f5",
#         "negotiationAgentMessageId": "urn:negotiation-message:c503bab2-c6a6-45a6-84c9-b5aafc02ed5d",
#         "offerId": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#         "offerContent": {
#           "@id": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#           "@type": "Offer",
#           "permission": [
#             {
#               "action": "supermegause"
#             }
#           ],
#           "target": "urn:dataset:875dedc3-cb03-4f26-a865-be1eb295dc0a"
#         },
#         "createdAt": "2026-08-20T22:26:56.298327Z"
#       }
#     ],
#     "agreement": {
#       "id": "urn:agreement:d29ef490-f76f-4e8e-a979-29e55ba8a5d7",
#       "negotiationAgentProcessId": "urn:negotiation-process:ef296f8e-b3a3-487c-b3b3-575b024278f5",
#       "negotiationAgentMessageId": "urn:negotiation-message:fc4aaacb-1964-40af-a0f3-cf27d8c0fc74",
#       "consumerParticipantId": "did:jwk:...",
#       "providerParticipantId": "did:jwk:...",
#       "agreementContent": {
#         "@id": "urn:agreement:d29ef490-f76f-4e8e-a979-29e55ba8a5d7",
#         "@type": "Agreement",
#         "assignee": "did:jwk:...",
#         "assigner": "did:jwk:...",
#         "permission": [
#           {
#             "action": "supermegause"
#           }
#         ],
#         "target": "urn:dataset:875dedc3-cb03-4f26-a865-be1eb295dc0a",
#         "timestamp": "1787264816"
#       },
#       "target": "urn:dataset:875dedc3-cb03-4f26-a865-be1eb295dc0a",
#       "state": "ACTIVE",
#       "createdAt": "2026-08-20T22:26:56.585829Z",
#       "updatedAt": "2026-08-20T22:26:56.708923Z"
#     }
#   }
# }

# %% [markdown]
# ## Provider finalizes the negotiation (Provider -> Consumer)

# %%
url = data_space_provider + "/dsp/current/negotiations/rpc/setup-finalization"
payload = {
    "consumerPid": cn_consumer_id,
    "providerPid": cn_provider_id
}
response = requests.request("POST", url, headers=json_header, data=json.dumps(payload))
response_as_json = response.json()
try:
    agreement = response_as_json
    agreement_id = response_as_json["negotiationAgentModel"]["agreement"]["id"]
    print(json.dumps(response_as_json, indent=2))
except KeyError:
    print("Error in response, check the payload and the endpoint.")
    print(json.dumps(response_as_json, indent=2))
    raise
# Out:
# {
#   "request": {
#     "providerPid": "urn:provider-pid:5173ad8f-bbea-4253-a737-5d1f8c3107fd",
#     "consumerPid": "urn:consumer-pid:2e1f1986-c02c-44f0-8c47-f2b4fa75cc61"
#   },
#   "response": {
#     "@context": [
#       "https://w3id.org/dspace/2025/1/context.jsonld"
#     ],
#     "@type": "ContractNegotiation",
#     "consumerPid": "urn:consumer-pid:2e1f1986-c02c-44f0-8c47-f2b4fa75cc61",
#     "providerPid": "urn:provider-pid:5173ad8f-bbea-4253-a737-5d1f8c3107fd",
#     "state": "FINALIZED"
#   },
#   "negotiationAgentModel": {
#     "id": "urn:negotiation-process:db89adba-c15e-41dd-8d4c-5b10a6a27467",
#     "state": "FINALIZED",
#     "stateAttribute": null,
#     "associatedAgentPeer": "did:jwk:...",
#     "protocol": "DSP",
#     "callbackAddress": "http://127.0.0.1:1100/dsp/current",
#     "role": "Provider",
#     "properties": {},
#     "errorDetails": null,
#     "createdAt": "2026-08-20T22:26:55.233698Z",
#     "updatedAt": "2026-08-20T22:26:58.230946Z",
#     "identifiers": {
#       "providerPid": "urn:provider-pid:5173ad8f-bbea-4253-a737-5d1f8c3107fd",
#       "consumerPid": "urn:consumer-pid:2e1f1986-c02c-44f0-8c47-f2b4fa75cc61"
#     },
#     "messages": [
#       {
#         "id": "urn:negotiation-message:14f371fb-5128-496e-9e1f-b68c52e18428",
#         "negotiationAgentProcessId": "urn:negotiation-process:db89adba-c15e-41dd-8d4c-5b10a6a27467",
#         "createdAt": "2026-08-20T22:26:55.249534Z",
#         "direction": "INBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractRequestMessage",
#         "stateTransitionFrom": "-",
#         "stateTransitionTo": "REQUESTED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractRequestMessage",
#           "callbackAddress": "http://127.0.0.1:1100/dsp/current",
#           "consumerPid": "urn:consumer-pid:2e1f1986-c02c-44f0-8c47-f2b4fa75cc61",
#           "offer": {
#             "@id": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#             "@type": "Offer",
#             "permission": [
#               {
#                 "action": "use",
#                 "constraint": [
#                   {
#                     "leftOperand": "count",
#                     "operator": "gt",
#                     "rightOperand": "18"
#                   }
#                 ]
#               }
#             ],
#             "target": "urn:dataset:875dedc3-cb03-4f26-a865-be1eb295dc0a"
#           }
#         }
#       },
#       {
#         "id": "urn:negotiation-message:c34a7f02-76fa-4e22-a309-bc10db926796",
#         "negotiationAgentProcessId": "urn:negotiation-process:db89adba-c15e-41dd-8d4c-5b10a6a27467",
#         "createdAt": "2026-08-20T22:26:55.908592Z",
#         "direction": "OUTBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractOfferMessage",
#         "stateTransitionFrom": "REQUESTED",
#         "stateTransitionTo": "OFFERED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractOfferMessage",
#           "consumerPid": "urn:consumer-pid:2e1f1986-c02c-44f0-8c47-f2b4fa75cc61",
#           "offer": {
#             "@id": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#             "@type": "Offer",
#             "permission": [
#               {
#                 "action": "use",
#                 "constraint": [
#                   {
#                     "leftOperand": "count",
#                     "operator": "gt",
#                     "rightOperand": "21"
#                   }
#                 ]
#               }
#             ],
#             "target": "urn:dataset:875dedc3-cb03-4f26-a865-be1eb295dc0a"
#           },
#           "providerPid": "urn:provider-pid:5173ad8f-bbea-4253-a737-5d1f8c3107fd"
#         }
#       },
#       {
#         "id": "urn:negotiation-message:5c75cade-e5af-4540-b093-53b50e52b59a",
#         "negotiationAgentProcessId": "urn:negotiation-process:db89adba-c15e-41dd-8d4c-5b10a6a27467",
#         "createdAt": "2026-08-20T22:26:56.047636Z",
#         "direction": "INBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractRequestMessage",
#         "stateTransitionFrom": "OFFERED",
#         "stateTransitionTo": "REQUESTED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractRequestMessage",
#           "consumerPid": "urn:consumer-pid:2e1f1986-c02c-44f0-8c47-f2b4fa75cc61",
#           "offer": {
#             "@id": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#             "@type": "Offer",
#             "permission": [
#               {
#                 "action": "use"
#               }
#             ],
#             "target": "urn:dataset:875dedc3-cb03-4f26-a865-be1eb295dc0a"
#           },
#           "providerPid": "urn:provider-pid:5173ad8f-bbea-4253-a737-5d1f8c3107fd"
#         }
#       },
#       {
#         "id": "urn:negotiation-message:6d125471-6f06-4846-854d-50e5a14e0e86",
#         "negotiationAgentProcessId": "urn:negotiation-process:db89adba-c15e-41dd-8d4c-5b10a6a27467",
#         "createdAt": "2026-08-20T22:26:56.309131Z",
#         "direction": "OUTBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractOfferMessage",
#         "stateTransitionFrom": "REQUESTED",
#         "stateTransitionTo": "OFFERED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractOfferMessage",
#           "consumerPid": "urn:consumer-pid:2e1f1986-c02c-44f0-8c47-f2b4fa75cc61",
#           "offer": {
#             "@id": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#             "@type": "Offer",
#             "permission": [
#               {
#                 "action": "supermegause"
#               }
#             ],
#             "target": "urn:dataset:875dedc3-cb03-4f26-a865-be1eb295dc0a"
#           },
#           "providerPid": "urn:provider-pid:5173ad8f-bbea-4253-a737-5d1f8c3107fd"
#         }
#       },
#       {
#         "id": "urn:negotiation-message:90bd1cb3-d8fe-4328-afff-ab01c54ffe18",
#         "negotiationAgentProcessId": "urn:negotiation-process:db89adba-c15e-41dd-8d4c-5b10a6a27467",
#         "createdAt": "2026-08-20T22:26:56.359390Z",
#         "direction": "INBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractNegotiationEventMessage",
#         "stateTransitionFrom": "OFFERED",
#         "stateTransitionTo": "ACCEPTED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractNegotiationEventMessage",
#           "consumerPid": "urn:consumer-pid:2e1f1986-c02c-44f0-8c47-f2b4fa75cc61",
#           "eventType": "ACCEPTED",
#           "providerPid": "urn:provider-pid:5173ad8f-bbea-4253-a737-5d1f8c3107fd"
#         }
#       },
#       {
#         "id": "urn:negotiation-message:f2d0e61f-c330-4318-95ac-ec40c756eac7",
#         "negotiationAgentProcessId": "urn:negotiation-process:db89adba-c15e-41dd-8d4c-5b10a6a27467",
#         "createdAt": "2026-08-20T22:26:56.605754Z",
#         "direction": "OUTBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractAgreementMessage",
#         "stateTransitionFrom": "ACCEPTED",
#         "stateTransitionTo": "AGREED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractAgreementMessage",
#           "consumerPid": "urn:consumer-pid:2e1f1986-c02c-44f0-8c47-f2b4fa75cc61",
#           "providerPid": "urn:provider-pid:5173ad8f-bbea-4253-a737-5d1f8c3107fd"
#         }
#       },
#       {
#         "id": "urn:negotiation-message:6e824a8e-c54f-44b3-bbd4-ebf0b2812457",
#         "negotiationAgentProcessId": "urn:negotiation-process:db89adba-c15e-41dd-8d4c-5b10a6a27467",
#         "createdAt": "2026-08-20T22:26:56.698754Z",
#         "direction": "INBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractAgreementVerificationMessage",
#         "stateTransitionFrom": "AGREED",
#         "stateTransitionTo": "VERIFIED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractAgreementVerificationMessage",
#           "consumerPid": "urn:consumer-pid:2e1f1986-c02c-44f0-8c47-f2b4fa75cc61",
#           "providerPid": "urn:provider-pid:5173ad8f-bbea-4253-a737-5d1f8c3107fd"
#         }
#       },
#       {
#         "id": "urn:negotiation-message:4d5f3307-6acf-484f-9e78-029f3b7dab0b",
#         "negotiationAgentProcessId": "urn:negotiation-process:db89adba-c15e-41dd-8d4c-5b10a6a27467",
#         "createdAt": "2026-08-20T22:26:58.240444Z",
#         "direction": "OUTBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractNegotiationEventMessage",
#         "stateTransitionFrom": "VERIFIED",
#         "stateTransitionTo": "FINALIZED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractNegotiationEventMessage",
#           "consumerPid": "urn:consumer-pid:2e1f1986-c02c-44f0-8c47-f2b4fa75cc61",
#           "providerPid": "urn:provider-pid:5173ad8f-bbea-4253-a737-5d1f8c3107fd"
#         }
#       }
#     ],
#     "offers": [
#       {
#         "id": "urn:offer:0bfb1bfe-f4d4-4985-95c4-ceed0f144163",
#         "negotiationAgentProcessId": "urn:negotiation-process:db89adba-c15e-41dd-8d4c-5b10a6a27467",
#         "negotiationAgentMessageId": "urn:negotiation-message:14f371fb-5128-496e-9e1f-b68c52e18428",
#         "offerId": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#         "offerContent": {
#           "@id": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#           "@type": "Offer",
#           "permission": [
#             {
#               "action": "use",
#               "constraint": [
#                 {
#                   "leftOperand": "count",
#                   "operator": "gt",
#                   "rightOperand": "18"
#                 }
#               ]
#             }
#           ],
#           "target": "urn:dataset:875dedc3-cb03-4f26-a865-be1eb295dc0a"
#         },
#         "createdAt": "2026-08-20T22:26:55.250718Z"
#       },
#       {
#         "id": "urn:offer:b1303cb4-0e17-4768-91b3-315bb5a2b665",
#         "negotiationAgentProcessId": "urn:negotiation-process:db89adba-c15e-41dd-8d4c-5b10a6a27467",
#         "negotiationAgentMessageId": "urn:negotiation-message:c34a7f02-76fa-4e22-a309-bc10db926796",
#         "offerId": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#         "offerContent": {
#           "@id": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#           "@type": "Offer",
#           "permission": [
#             {
#               "action": "use",
#               "constraint": [
#                 {
#                   "leftOperand": "count",
#                   "operator": "gt",
#                   "rightOperand": "21"
#                 }
#               ]
#             }
#           ],
#           "target": "urn:dataset:875dedc3-cb03-4f26-a865-be1eb295dc0a"
#         },
#         "createdAt": "2026-08-20T22:26:55.910692Z"
#       },
#       {
#         "id": "urn:offer:fb017091-3cda-475a-9f46-b3a0f1665f4c",
#         "negotiationAgentProcessId": "urn:negotiation-process:db89adba-c15e-41dd-8d4c-5b10a6a27467",
#         "negotiationAgentMessageId": "urn:negotiation-message:5c75cade-e5af-4540-b093-53b50e52b59a",
#         "offerId": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#         "offerContent": {
#           "@id": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#           "@type": "Offer",
#           "permission": [
#             {
#               "action": "use"
#             }
#           ],
#           "target": "urn:dataset:875dedc3-cb03-4f26-a865-be1eb295dc0a"
#         },
#         "createdAt": "2026-08-20T22:26:56.050165Z"
#       },
#       {
#         "id": "urn:offer:84f33663-c82a-49e3-8cec-8a456793595c",
#         "negotiationAgentProcessId": "urn:negotiation-process:db89adba-c15e-41dd-8d4c-5b10a6a27467",
#         "negotiationAgentMessageId": "urn:negotiation-message:6d125471-6f06-4846-854d-50e5a14e0e86",
#         "offerId": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#         "offerContent": {
#           "@id": "urn:odrl-policy:ceca791f-83fb-444e-ab88-73fbbb2d4c17",
#           "@type": "Offer",
#           "permission": [
#             {
#               "action": "supermegause"
#             }
#           ],
#           "target": "urn:dataset:875dedc3-cb03-4f26-a865-be1eb295dc0a"
#         },
#         "createdAt": "2026-08-20T22:26:56.310999Z"
#       }
#     ],
#     "agreement": {
#       "id": "urn:agreement:d29ef490-f76f-4e8e-a979-29e55ba8a5d7",
#       "negotiationAgentProcessId": "urn:negotiation-process:db89adba-c15e-41dd-8d4c-5b10a6a27467",
#       "negotiationAgentMessageId": "urn:negotiation-message:f2d0e61f-c330-4318-95ac-ec40c756eac7",
#       "consumerParticipantId": "did:jwk:...",
#       "providerParticipantId": "did:jwk:...",
#       "agreementContent": {
#         "@id": "urn:agreement:d29ef490-f76f-4e8e-a979-29e55ba8a5d7",
#         "@type": "Agreement",
#         "assignee": "did:jwk:...",
#         "assigner": "did:jwk:...",
#         "permission": [
#           {
#             "action": "supermegause"
#           }
#         ],
#         "target": "urn:dataset:875dedc3-cb03-4f26-a865-be1eb295dc0a",
#         "timestamp": "1787264816"
#       },
#       "target": "urn:dataset:875dedc3-cb03-4f26-a865-be1eb295dc0a",
#       "state": "ACTIVE",
#       "createdAt": "2026-08-20T22:26:56.607342Z",
#       "updatedAt": "2026-08-20T22:26:58.247713Z"
#     }
#   }
# }

# %% [markdown]
# ## Final agreement

# %%
print("Final agreement: \n{}\n".format(json.dumps(agreement["negotiationAgentModel"]["agreement"], indent=2)))
print("Final agreement id: \n{}\n".format(agreement_id))
# Out:
# Final agreement:
# {
#   "id": "urn:agreement:d29ef490-f76f-4e8e-a979-29e55ba8a5d7",
#   "negotiationAgentProcessId": "urn:negotiation-process:db89adba-c15e-41dd-8d4c-5b10a6a27467",
#   "negotiationAgentMessageId": "urn:negotiation-message:f2d0e61f-c330-4318-95ac-ec40c756eac7",
#   "consumerParticipantId": "did:jwk:...",
#   "providerParticipantId": "did:jwk:...",
#   "agreementContent": {
#     "@id": "urn:agreement:d29ef490-f76f-4e8e-a979-29e55ba8a5d7",
#     "@type": "Agreement",
#     "assignee": "did:jwk:...",
#     "assigner": "did:jwk:...",
#     "permission": [
#       {
#         "action": "supermegause"
#       }
#     ],
#     "target": "urn:dataset:875dedc3-cb03-4f26-a865-be1eb295dc0a",
#     "timestamp": "1787264816"
#   },
#   "target": "urn:dataset:875dedc3-cb03-4f26-a865-be1eb295dc0a",
#   "state": "ACTIVE",
#   "createdAt": "2026-08-20T22:26:56.607342Z",
#   "updatedAt": "2026-08-20T22:26:58.247713Z"
# }
#
# Final agreement id:
# urn:agreement:d29ef490-f76f-4e8e-a979-29e55ba8a5d7

# %% [markdown]
# # Transfer Negotiation with Agents

# %% [markdown]
# ## Transfer request setup (Consumer -> Provider)

# %%
url = data_space_provider + "/dsp/current/transfers/request"
payload = {
  "@context": [
    "https://w3id.org/dspace/2025/1/context.jsonld"],
  "@type": "TransferSuspensionMessage",
  "providerPid": "urn:uuid:a343fcbf-99fc-4ce8-8e9b-148c97605aab",
  "consumerPid": "urn:uuid:32541fe6-c580-409e-85a8-8a9a32fbe833",
  "code": "99",
  "reason": [
    "Policy violation"
  ]
}
response = requests.request("POST", url, headers={
    "Content-Type": "application/json",
    "Authorization": "Bearer 6BWir9NBYEEmniXWI3Ilqe39VKy4O-rl66JXxf4XV6o"
}, data=json.dumps(payload))
response_as_text = response.text
response_as_text
# Out:
# ''
