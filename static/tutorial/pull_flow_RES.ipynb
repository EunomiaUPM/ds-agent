# %% [markdown]
# # Preconditions
# `./setup_auth.ipynb` and `./setup_catalog_policies.ipynb`will run

# %%
# %run ./setup_catalog_policies_oauth.ipynb
# Out:
# /Users/apabook/Desktop/ds-protocol/static/tutorial/venv/bin/python
# {
#     "participant_id": "did:jwk:...",
#     "participant_nick": "Myself",
#     "participant_type": "Agent",
#     "base_url": "http://127.0.0.1:1200",
#     "token": null,
#     "saved_at": "2026-09-02T14:25:08.215460Z",
#     "last_interaction": "2026-09-12T11:11:25.104854Z",
#     "extra_fields": {},
#     "is_me": true
# }
# {
#     "participant_id": "did:jwk:...",
#     "participant_nick": "Myself",
#     "participant_type": "Agent",
#     "base_url": "http://127.0.0.1:1100",
#     "token": null,
#     "saved_at": "2026-09-02T14:25:08.305843Z",
#     "last_interaction": "2026-09-12T11:11:25.194688Z",
#     "extra_fields": {},
#     "is_me": true
# }
# Provider DID: did:jwk:...
#
# Provider token: akuTZ784tLl7j96fX09XjK8ACYhdReuR4QHzfLClQP4
#
# Consumer DID: did:jwk:...
#
# Consumer token: akuTZ784tLl7j96fX09XjK8ACYhdReuR4QHzfLClQP4
# {
#     "dctConformsTo": null,
#     "dctCreator": null,
#     "dctIdentifier": "urn:catalog:6041b710-8595-45ff-88da-9bcb4a9e62a3",
#     "dctIssued": "2026-09-02T14:25:08.952727Z",
#     "dctModified": null,
#     "dctTitle": null,
#     "dspaceMainCatalog": true,
#     "dspaceParticipantId": "did:jwk:...",
#     "foafHomePage": null,
#     "id": "urn:catalog:6041b710-8595-45ff-88da-9bcb4a9e62a3"
# }
# {
#     "catalogId": "urn:catalog:6041b710-8595-45ff-88da-9bcb4a9e62a3",
#     "dcatEndpointDescription": null,
#     "dcatEndpointUrl": "http://127.0.0.1:1200/dsp/current",
#     "dctConformsTo": null,
#     "dctCreator": null,
#     "dctDescription": null,
#     "dctIdentifier": "urn:data-service:d7d3ab47-170c-456f-8c04-6f563e2c585c",
#     "dctIssued": "2026-09-02T14:25:09.001755Z",
#     "dctModified": null,
#     "dctTitle": null,
#     "dspaceMainDataService": true,
#     "id": "urn:data-service:d7d3ab47-170c-456f-8c04-6f563e2c585c"
# }
# {
#     "catalogId": "urn:catalog:6041b710-8595-45ff-88da-9bcb4a9e62a3",
#     "dctConformsTo": null,
#     "dctCreator": null,
#     "dctDescription": null,
#     "dctIdentifier": "urn:dataset:315bc6af-0bcd-49d0-9885-040ff03651e4",
#     "dctIssued": "2026-09-12T16:30:51.306026Z",
#     "dctModified": null,
#     "dctTitle": "My dataspace dataset",
#     "id": "urn:dataset:315bc6af-0bcd-49d0-9885-040ff03651e4"
# }
# {
#     "datasetId": "urn:dataset:315bc6af-0bcd-49d0-9885-040ff03651e4",
#     "dcatAccessService": "urn:data-service:d7d3ab47-170c-456f-8c04-6f563e2c585c",
#     "dctDescription": "This is the distribution of my dataset",
#     "dctFormat": "http+asd",
#     "dctIssued": "2026-09-12T16:30:51.409930Z",
#     "dctModified": null,
#     "dctTitle": "Distribution of my dataset",
#     "id": "urn:distribution:a72ec725-0727-46c6-9efd-a4cbb3dbc767"
# }
# {
#     "datasetId": "urn:dataset:315bc6af-0bcd-49d0-9885-040ff03651e4",
#     "dcatAccessService": "urn:data-service:d7d3ab47-170c-456f-8c04-6f563e2c585c",
#     "dctDescription": "This is the distribution of my streaming dataset",
#     "dctFormat": "http+pushing",
#     "dctIssued": "2026-09-12T16:30:51.421069Z",
#     "dctModified": null,
#     "dctTitle": "Distribution of a streaming dataset",
#     "id": "urn:distribution:fd839324-d953-407f-9d7d-c0bcf45d1d54"
# }
# [
#     {
#         "author": "",
#         "content": {
#             "permission": [
#                 {
#                     "action": "use",
#                     "constraint": [
#                         {
#                             "leftOperand": "bla",
#                             "operator": "eq",
#                             "rightOperand": "$bla"
#                         }
#                     ]
#                 }
#             ]
#         },
#         "date": "2026-09-02T14:25:09.008924Z",
#         "description": "Mi example super policy",
#         "id": "policy-1",
#         "parameters": {
#             "$bla": {
#                 "dataType": "string",
#                 "restrictions": {},
#                 "ui": {
#                     "hidden": false
#                 }
#             }
#         },
#         "title": "Mi example policy",
#         "version": "1.0"
#     }
# ]
# {
#     "createdAt": "2026-09-12T16:30:51.437811Z",
#     "description": "Research access for UPM: grants read access to did:web:university.upm.es valid until 2025-12-31.",
#     "entity": "urn:dataset:315bc6af-0bcd-49d0-9885-040ff03651e4",
#     "entityType": "Dataset",
#     "id": "urn:odrl-policy:1824d329-a2a6-4672-b9dd-cf09afe354cd",
#     "instantiationParameters": {
#         "$bla": "did:web:university.upm.es"
#     },
#     "odrlOffer": {
#         "permission": [
#             {
#                 "action": "use",
#                 "constraint": [
#                     {
#                         "leftOperand": "bla",
#                         "operator": "eq",
#                         "rightOperand": "did:web:university.upm.es"
#                     }
#                 ]
#             }
#         ]
#     },
#     "sourceTemplateId": "policy-1",
#     "sourceTemplateVersion": "1.0"
# }
# {
#     "createdAt": "2026-09-12T16:30:51.449077Z",
#     "description": "Commercial use licence valid for 2025: permits usage for commercial purposes with mandatory attribution. Derivation of the dataset is prohibited.",
#     "entity": "urn:dataset:315bc6af-0bcd-49d0-9885-040ff03651e4",
#     "entityType": "Dataset",
#     "id": "urn:odrl-policy:b21c3ec5-a737-4caf-82bf-950258ea48c4",
#     "instantiationParameters": null,
#     "odrlOffer": {
#         "obligation": [
#             {
#                 "action": "attribute",
#                 "constraint": [
#                     {
#                         "leftOperand": "recipient",
#                         "operator": "isA",
#                         "rightOperand": "public"
#                     }
#                 ]
#             }
#         ],
#         "permission": [
#             {
#                 "action": "use",
#                 "constraint": [
#                     {
#                         "leftOperand": "dateTime",
#                         "operator": "gteq",
#                         "rightOperand": "2025-01-01T00:00:00Z"
#                     },
#                     {
#                         "leftOperand": "dateTime",
#                         "operator": "lteq",
#                         "rightOperand": "2025-12-31T23:59:59Z"
#                     },
#                     {
#                         "leftOperand": "purpose",
#                         "operator": "isA",
#                         "rightOperand": "commercial"
#                     }
#                 ]
#             }
#         ],
#         "prohibition": [
#             {
#                 "action": "derive",
#                 "constraint": []
#             }
#         ]
#     },
#     "sourceTemplateId": null,
#     "sourceTemplateVersion": null
# }
# {
#     "createdAt": "2026-09-12T16:30:51.460530Z",
#     "description": "Research trial access (Mar\u2013Sep 2025): read-only, limited to 10 000 requests, restricted to research purposes. Redistribution and reproduction are prohibited.",
#     "entity": "urn:dataset:315bc6af-0bcd-49d0-9885-040ff03651e4",
#     "entityType": "Dataset",
#     "id": "urn:odrl-policy:b411bcfb-3240-4b85-9a1c-e6e6ec9bd104",
#     "instantiationParameters": null,
#     "odrlOffer": {
#         "obligation": [],
#         "permission": [
#             {
#                 "action": "read",
#                 "constraint": [
#                     {
#                         "leftOperand": "dateTime",
#                         "operator": "gteq",
#                         "rightOperand": "2025-03-01T00:00:00Z"
#                     },
#                     {
#                         "leftOperand": "dateTime",
#                         "operator": "lteq",
#                         "rightOperand": "2025-09-01T00:00:00Z"
#                     },
#                     {
#                         "leftOperand": "purpose",
#                         "operator": "isA",
#                         "rightOperand": "research"
#                     },
#                     {
#                         "leftOperand": "count",
#                         "operator": "lteq",
#                         "rightOperand": "10000"
#                     }
#                 ]
#             }
#         ],
#         "prohibition": [
#             {
#                 "action": "distribute",
#                 "constraint": []
#             },
#             {
#                 "action": "reproduce",
#                 "constraint": []
#             }
#         ]
#     },
#     "sourceTemplateId": null,
#     "sourceTemplateVersion": null
# }
# {
#     "message": "Database Error",
#     "error_code": 5100,
#     "details": "Secret already exists"
# }
# {
#     "name": "urn:connector-template:f47cea32-8d68-4d24-b03a-8cb45ba85232",
#     "author": "admin",
#     "description": null,
#     "version": "1.0",
#     "createdAt": "2026-09-12T16:30:51.573323Z",
#     "authentication": {
#         "type": "BEARER_TOKEN",
#         "token": {
#             "type": "PLAIN",
#             "content": "{{__RUNTIME_SECRET_{/ecostars/api_key}__}}"
#         }
#     },
#     "interaction": {
#         "mode": "PULL",
#         "dataAccess": {
#             "protocol": "HTTP",
#             "urlTemplate": "{{__ACCESS_URL__}}",
#             "method": "{{__ACCESS_METHODS__}}",
#             "headers": "{{__ACCESS_HEADERS__}}",
#             "bodyTemplate": null
#         }
#     },
#     "parameters": [
#         {
#             "name": "ACCESS_URL",
#             "title": "Url",
#             "description": null,
#             "paramType": "STRING",
#             "required": true,
#             "defaultValue": null
#         },
#         {
#             "name": "ACCESS_METHODS",
#             "title": "Methods",
#             "description": null,
#             "paramType": "VEC<STRING>",
#             "required": true,
#             "defaultValue": null
#         },
#         {
#             "name": "ACCESS_HEADERS",
#             "title": "Headers",
#             "description": null,
#             "paramType": "MAP<STRING,STRING>",
#             "required": true,
#             "defaultValue": null
#         }
#     ]
# }
# {
#     "id": "urn:connector-instance:afb2766a-0fc4-4392-8e7f-1942a9fcf425",
#     "name": "urn:connector-template:f47cea32-8d68-4d24-b03a-8cb45ba85232",
#     "author": null,
#     "description": null,
#     "version": "1.0",
#     "createdAt": "2026-09-12T16:30:51.630034Z",
#     "authenticationConfig": {
#         "type": "BEARER_TOKEN",
#         "token": {
#             "type": "PLAIN",
#             "content": "{{__RUNTIME_SECRET_{/ecostars/api_key}__}}"
#         }
#     },
#     "interaction": {
#         "mode": "PULL",
#         "dataAccess": {
#             "protocol": "HTTP",
#             "urlTemplate": "http://127.0.0.1:8081",
#             "method": [
#                 "GET",
#                 "HEAD"
#             ],
#             "headers": {
#                 "Content-type": "application/json"
#             },
#             "bodyTemplate": null
#         }
#     },
#     "distributionId": "urn:distribution:a72ec725-0727-46c6-9efd-a4cbb3dbc767"
# }
# {
#     "name": "urn:connector-template:aa368a4c-2c88-47ce-a48a-60a98ea5b92e",
#     "author": "admin",
#     "description": null,
#     "version": "1.0",
#     "createdAt": "2026-09-12T16:30:51.686310Z",
#     "authentication": {
#         "type": "BEARER_TOKEN",
#         "token": {
#             "type": "PLAIN",
#             "content": "{{__RUNTIME_SECRET_{/ecostars/api_key}__}}"
#         }
#     },
#     "interaction": {
#         "mode": "PUSH",
#         "subscribe": {
#             "protocol": "HTTP",
#             "urlTemplate": "{{__SUB_URL__}}",
#             "method": "POST",
#             "headers": {},
#             "bodyTemplate": "{\"url\": \"{{__SYS_OWN_URL_DOCKER__}}{{__RUNTIME_INGRESS__}}\", \"event_type\": \"hotel_waste_generated\"}"
#         },
#         "unsubscribe": {
#             "protocol": "HTTP",
#             "urlTemplate": "{{__UNSUB_URL__}}/{{__RUNTIME_JSON_{.subscription.data.ID}__}}",
#             "method": "POST",
#             "headers": {},
#             "bodyTemplate": "{}"
#         }
#     },
#     "parameters": [
#         {
#             "name": "SUB_URL",
#             "title": "Subscription URL",
#             "description": null,
#             "paramType": "STRING",
#             "required": true,
#             "defaultValue": null
#         },
#         {
#             "name": "UNSUB_URL",
#             "title": "Unsubscription URL",
#             "description": null,
#             "paramType": "STRING",
#             "required": true,
#             "defaultValue": null
#         }
#     ]
# }
# {
#     "id": "urn:connector-instance:6adbe3a1-2bbe-4f15-a67e-1d532bfe11d0",
#     "name": "urn:connector-template:aa368a4c-2c88-47ce-a48a-60a98ea5b92e",
#     "author": null,
#     "description": null,
#     "version": "1.0",
#     "createdAt": "2026-09-12T16:30:51.736088Z",
#     "authenticationConfig": {
#         "type": "BEARER_TOKEN",
#         "token": {
#             "type": "PLAIN",
#             "content": "{{__RUNTIME_SECRET_{/ecostars/api_key}__}}"
#         }
#     },
#     "interaction": {
#         "mode": "PUSH",
#         "subscribe": {
#             "protocol": "HTTP",
#             "urlTemplate": "http://127.0.0.1:8082/subscriptions/subscribe",
#             "method": "POST",
#             "headers": {},
#             "bodyTemplate": "{\"url\": \"http://host.docker.internal:1200{{__RUNTIME_INGRESS__}}\", \"event_type\": \"hotel_waste_generated\"}"
#         },
#         "unsubscribe": {
#             "protocol": "HTTP",
#             "urlTemplate": "http://127.0.0.1:8082/subscriptions/unsubscribe/{{__RUNTIME_JSON_{.subscription.data.ID}__}}",
#             "method": "POST",
#             "headers": {},
#             "bodyTemplate": "{}"
#         }
#     },
#     "distributionId": "urn:distribution:fd839324-d953-407f-9d7d-c0bcf45d1d54"
# }
# Selected dataset target:
# urn:dataset:315bc6af-0bcd-49d0-9885-040ff03651e4
#
# Selected policy id:
# urn:odrl-policy:ca61cbbd-f1ce-4c53-a6e8-645b57232c2b
#
# Provider negotiation URL for DSP 2025:
# http://127.0.0.1:1200/dsp/current
#
# Consumer callback address:
# http://127.0.0.1:1100/dsp/current

# %% [markdown]
# # Contract Negotiation

# %% [markdown]
# ## Initialization of negotiation request (Consumer -> Provider)

# %%
url = data_space_consumer + "/dsp/current/negotiations/rpc/setup-request-init"
payload = {
    "associatedAgentPeer": data_space_provider_participant_id,
    "providerAddress": data_space_provider_dsp_endpoint,
    "callbackAddress": data_space_consumer_dsp_endpoint,
    "offer": {
        "@id": policy_id,
        "target": target_id,
        "@type": "Offer",
        "permission": [
            {
                "action": "use", 
                "constraint": [{
                    "leftOperand": "count", 
                    "operator": "gt", 
                    "rightOperand": "18"
                }]
            }
        ]
    }
}




try:
    response = requests.request("POST", url, headers=json_header, data=json.dumps(payload))
    response_as_json = response.json()
    cn_consumer_id = response_as_json["response"]["consumerPid"]
    cn_provider_id = response_as_json["response"]["providerPid"]
    print(json.dumps(response_as_json, indent=2))
except Exception as e:
    print("Error in response, {}.".format(e))
# Out:
# {
#   "request": {
#     "associatedAgentPeer": "did:jwk:...",
#     "providerAddress": "http://127.0.0.1:1200/dsp/current",
#     "callbackAddress": "http://127.0.0.1:1100/dsp/current",
#     "offer": {
#       "@id": "urn:odrl-policy:ca61cbbd-f1ce-4c53-a6e8-645b57232c2b",
#       "permission": [
#         {
#           "action": "use",
#           "constraint": [
#             {
#               "rightOperand": "18",
#               "leftOperand": "count",
#               "operator": "gt"
#             }
#           ]
#         }
#       ],
#       "@type": "Offer",
#       "target": "urn:dataset:315bc6af-0bcd-49d0-9885-040ff03651e4"
#     }
#   },
#   "response": {
#     "@context": [
#       "https://w3id.org/dspace/2025/1/context.jsonld"
#     ],
#     "@type": "ContractNegotiation",
#     "consumerPid": "urn:consumer-pid:a5b3d705-b6c6-4af1-8624-46fb881a3e57",
#     "providerPid": "urn:provider-pid:b180c970-9f4f-4206-91bd-97857a008d15",
#     "state": "REQUESTED"
#   },
#   "negotiationAgentModel": {
#     "id": "urn:negotiation-process:729e0980-539a-4721-bdea-3f891f003e02",
#     "state": "REQUESTED",
#     "stateAttribute": null,
#     "associatedAgentPeer": "did:jwk:...",
#     "protocol": "DSP",
#     "callbackAddress": "http://127.0.0.1:1200/dsp/current",
#     "role": "Consumer",
#     "properties": {},
#     "errorDetails": null,
#     "createdAt": "2026-09-12T16:31:25.530544Z",
#     "updatedAt": null,
#     "identifiers": {
#       "providerPid": "urn:provider-pid:b180c970-9f4f-4206-91bd-97857a008d15",
#       "consumerPid": "urn:consumer-pid:a5b3d705-b6c6-4af1-8624-46fb881a3e57"
#     },
#     "messages": [
#       {
#         "id": "urn:negotiation-message:b7019083-7cbc-4c89-bbdc-c3e2b8d1dd68",
#         "negotiationAgentProcessId": "urn:negotiation-process:729e0980-539a-4721-bdea-3f891f003e02",
#         "createdAt": "2026-09-12T16:31:25.623267Z",
#         "direction": "OUTBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractRequestMessage",
#         "stateTransitionFrom": "-",
#         "stateTransitionTo": "REQUESTED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractRequestMessage",
#           "associatedAgentPeer": "did:jwk:...",
#           "callbackAddress": "http://127.0.0.1:1100/dsp/current",
#           "offer": {
#             "@id": "urn:odrl-policy:ca61cbbd-f1ce-4c53-a6e8-645b57232c2b",
#             "@type": "Offer",
#             "permission": [
#               {
#                 "action": "use",
#                 "constraint": [
#                   {
#                     "leftOperand": "count",
#                     "operator": "gt",
#                     "rightOperand": "18"
#                   }
#                 ]
#               }
#             ],
#             "target": "urn:dataset:315bc6af-0bcd-49d0-9885-040ff03651e4"
#           },
#           "providerAddress": "http://127.0.0.1:1200/dsp/current"
#         }
#       }
#     ],
#     "offers": [
#       {
#         "id": "urn:offer:2399f223-819d-46b6-bd6d-03366f4bd0c5",
#         "negotiationAgentProcessId": "urn:negotiation-process:729e0980-539a-4721-bdea-3f891f003e02",
#         "negotiationAgentMessageId": "urn:negotiation-message:b7019083-7cbc-4c89-bbdc-c3e2b8d1dd68",
#         "offerId": "urn:odrl-policy:ca61cbbd-f1ce-4c53-a6e8-645b57232c2b",
#         "offerContent": {
#           "@id": "urn:odrl-policy:ca61cbbd-f1ce-4c53-a6e8-645b57232c2b",
#           "@type": "Offer",
#           "permission": [
#             {
#               "action": "use",
#               "constraint": [
#                 {
#                   "leftOperand": "count",
#                   "operator": "gt",
#                   "rightOperand": "18"
#                 }
#               ]
#             }
#           ],
#           "target": "urn:dataset:315bc6af-0bcd-49d0-9885-040ff03651e4"
#         },
#         "createdAt": "2026-09-12T16:31:25.712189Z"
#       }
#     ],
#     "agreement": null
#   }
# }

# %% [markdown]
# ## Provider creates initial offer (Provider -> Consumer)

# %%
# Provider creates initial offer (Provider -> Consumer)
url = data_space_provider + "/dsp/current/negotiations/rpc/setup-offer"
payload = {
    "consumerPid": cn_consumer_id,  # remove to test offer from provider
    "providerPid": cn_provider_id,  # remove to test offer from provider
    "offer": {
        "@id": policy_id,
        "target": target_id,
        "@type": "Offer",
        "permission": [
            {
                "action": "use", 
                "constraint": [{
                    "leftOperand": "count", 
                    "operator": "gt", 
                    "rightOperand": "21"
                }]
            }
        ]
    }
}
response = requests.request("POST", url, headers=json_header, data=json.dumps(payload))
response_as_json = response.json()
try:
    print(json.dumps(response_as_json, indent=2))
except KeyError:
    print("Error in response, check the payload and the endpoint.")
    print(json.dumps(response_as_json, indent=2))
    raise
# Out:
# {
#   "@context": [
#     "https://w3id.org/dspace/2025/1/context.jsonld"
#   ],
#   "@type": "ContractNegotiationError",
#   "consumerPid": null,
#   "providerPid": null,
#   "code": "3120",
#   "reason": [
#     "Format Error"
#   ]
# }

# %% [markdown]
# ## Consumer sends negotiation request based on offer (Consumer -> Provider)

# %%
url = data_space_consumer + "/dsp/current/negotiations/rpc/setup-request"
payload = {
    "consumerPid": cn_consumer_id,
    "providerPid": cn_provider_id,
    "offer": {
        "@id": policy_id,
        "target": target_id,
        "@type": "Offer",
        "permission": [
            {
                "action": "use"

            }
        ]
    }
}
response = requests.request("POST", url, headers=json_header, data=json.dumps(payload))
response_as_json = response.json()
try:
    print(json.dumps(response_as_json, indent=2))
except KeyError:
    print("Error in response, check the payload and the endpoint.")
    print(json.dumps(response_as_json, indent=2))
    raise
# Out:
# {
#   "@context": [
#     "https://w3id.org/dspace/2025/1/context.jsonld"
#   ],
#   "@type": "ContractNegotiationError",
#   "consumerPid": null,
#   "providerPid": null,
#   "code": "3120",
#   "reason": [
#     "Format Error"
#   ]
# }

# %% [markdown]
# ## Provider updates/confirms the offer (Provider -> Consumer)

# %%
url = data_space_provider + "/dsp/current/negotiations/rpc/setup-offer"
payload = {
    "consumerPid": cn_consumer_id,
    "providerPid": cn_provider_id,
    "offer": {
        "@id": policy_id,
        "target": target_id,
        "@type": "Offer",
        "permission": [
            {
                "action": "supermegause"
            }
        ]
    }
}
response = requests.request("POST", url, headers=json_header, data=json.dumps(payload))
response_as_json = response.json()
try:
    print(json.dumps(response_as_json, indent=2))
except KeyError:
    print("Error in response, check the payload and the endpoint.")
    print(json.dumps(response_as_json, indent=2))
    raise
# Out:
# {
#   "@context": [
#     "https://w3id.org/dspace/2025/1/context.jsonld"
#   ],
#   "@type": "ContractNegotiationError",
#   "consumerPid": null,
#   "providerPid": null,
#   "code": "3120",
#   "reason": [
#     "Format Error"
#   ]
# }

# %% [markdown]
# ## Consumer accepts the offer (Consumer -> Provider)

# %%
url = data_space_consumer + "/dsp/current/negotiations/rpc/setup-acceptance"
payload = {
    "consumerPid": cn_consumer_id,
    "providerPid": cn_provider_id
}
response = requests.request("POST", url, headers=json_header, data=json.dumps(payload))
response_as_json = response.json()
try:
    print(json.dumps(response_as_json, indent=2))
except KeyError:
    print("Error in response, check the payload and the endpoint.")
    print(json.dumps(response_as_json, indent=2))
    raise
# Out:
# {
#   "request": {
#     "providerPid": "urn:provider-pid:46d1e04c-e5bf-44c6-958f-28c86841a2ee",
#     "consumerPid": "urn:consumer-pid:2c0de6f9-cefe-4653-97db-2076248745b6"
#   },
#   "response": {
#     "@context": [
#       "https://w3id.org/dspace/2025/1/context.jsonld"
#     ],
#     "@type": "ContractNegotiation",
#     "consumerPid": "urn:consumer-pid:2c0de6f9-cefe-4653-97db-2076248745b6",
#     "providerPid": "urn:provider-pid:46d1e04c-e5bf-44c6-958f-28c86841a2ee",
#     "state": "ACCEPTED"
#   },
#   "negotiationAgentModel": {
#     "id": "urn:negotiation-process:ed7adbb1-bc79-4740-9b46-fcbb10514a8e",
#     "state": "ACCEPTED",
#     "stateAttribute": null,
#     "associatedAgentPeer": "did:jwk:...",
#     "protocol": "DSP",
#     "callbackAddress": "http://127.0.0.1:1200/dsp/current",
#     "role": "Consumer",
#     "properties": {},
#     "errorDetails": null,
#     "createdAt": "2026-09-12T11:26:26.266189Z",
#     "updatedAt": "2026-09-12T11:26:26.834998Z",
#     "identifiers": {
#       "providerPid": "urn:provider-pid:46d1e04c-e5bf-44c6-958f-28c86841a2ee",
#       "consumerPid": "urn:consumer-pid:2c0de6f9-cefe-4653-97db-2076248745b6"
#     },
#     "messages": [
#       {
#         "id": "urn:negotiation-message:297a6b3d-8189-4f13-a6e1-19f7d397c003",
#         "negotiationAgentProcessId": "urn:negotiation-process:ed7adbb1-bc79-4740-9b46-fcbb10514a8e",
#         "createdAt": "2026-09-12T11:26:26.338285Z",
#         "direction": "OUTBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractRequestMessage",
#         "stateTransitionFrom": "-",
#         "stateTransitionTo": "REQUESTED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractRequestMessage",
#           "associatedAgentPeer": "did:jwk:...",
#           "callbackAddress": "http://127.0.0.1:1100/dsp/current",
#           "offer": {
#             "@id": "urn:odrl-policy:ca61cbbd-f1ce-4c53-a6e8-645b57232c2b",
#             "@type": "Offer",
#             "permission": [
#               {
#                 "action": "use",
#                 "constraint": [
#                   {
#                     "leftOperand": "count",
#                     "operator": "gt",
#                     "rightOperand": "18"
#                   }
#                 ]
#               }
#             ],
#             "target": "urn:dataset:afa2f634-93f2-4b0a-87eb-62a2a6c7965c"
#           },
#           "providerAddress": "http://127.0.0.1:1200/dsp/current"
#         }
#       },
#       {
#         "id": "urn:negotiation-message:225bffc5-debb-4e1f-a349-f74e3fe5576f",
#         "negotiationAgentProcessId": "urn:negotiation-process:ed7adbb1-bc79-4740-9b46-fcbb10514a8e",
#         "createdAt": "2026-09-12T11:26:26.401955Z",
#         "direction": "INBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractOfferMessage",
#         "stateTransitionFrom": "REQUESTED",
#         "stateTransitionTo": "OFFERED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractOfferMessage",
#           "consumerPid": "urn:consumer-pid:2c0de6f9-cefe-4653-97db-2076248745b6",
#           "offer": {
#             "@id": "urn:odrl-policy:ca61cbbd-f1ce-4c53-a6e8-645b57232c2b",
#             "@type": "Offer",
#             "permission": [
#               {
#                 "action": "use",
#                 "constraint": [
#                   {
#                     "leftOperand": "count",
#                     "operator": "gt",
#                     "rightOperand": "21"
#                   }
#                 ]
#               }
#             ],
#             "target": "urn:dataset:afa2f634-93f2-4b0a-87eb-62a2a6c7965c"
#           },
#           "providerPid": "urn:provider-pid:46d1e04c-e5bf-44c6-958f-28c86841a2ee"
#         }
#       },
#       {
#         "id": "urn:negotiation-message:41d18832-df53-48e1-bd68-1e016c1fb798",
#         "negotiationAgentProcessId": "urn:negotiation-process:ed7adbb1-bc79-4740-9b46-fcbb10514a8e",
#         "createdAt": "2026-09-12T11:26:26.596661Z",
#         "direction": "OUTBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractRequestMessage",
#         "stateTransitionFrom": "OFFERED",
#         "stateTransitionTo": "REQUESTED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractRequestMessage",
#           "consumerPid": "urn:consumer-pid:2c0de6f9-cefe-4653-97db-2076248745b6",
#           "offer": {
#             "@id": "urn:odrl-policy:ca61cbbd-f1ce-4c53-a6e8-645b57232c2b",
#             "@type": "Offer",
#             "permission": [
#               {
#                 "action": "use"
#               }
#             ],
#             "target": "urn:dataset:afa2f634-93f2-4b0a-87eb-62a2a6c7965c"
#           },
#           "providerPid": "urn:provider-pid:46d1e04c-e5bf-44c6-958f-28c86841a2ee"
#         }
#       },
#       {
#         "id": "urn:negotiation-message:048b3672-a1d5-4d81-9bdd-58307610c0b3",
#         "negotiationAgentProcessId": "urn:negotiation-process:ed7adbb1-bc79-4740-9b46-fcbb10514a8e",
#         "createdAt": "2026-09-12T11:26:26.682618Z",
#         "direction": "INBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractOfferMessage",
#         "stateTransitionFrom": "REQUESTED",
#         "stateTransitionTo": "OFFERED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractOfferMessage",
#           "consumerPid": "urn:consumer-pid:2c0de6f9-cefe-4653-97db-2076248745b6",
#           "offer": {
#             "@id": "urn:odrl-policy:ca61cbbd-f1ce-4c53-a6e8-645b57232c2b",
#             "@type": "Offer",
#             "permission": [
#               {
#                 "action": "supermegause"
#               }
#             ],
#             "target": "urn:dataset:afa2f634-93f2-4b0a-87eb-62a2a6c7965c"
#           },
#           "providerPid": "urn:provider-pid:46d1e04c-e5bf-44c6-958f-28c86841a2ee"
#         }
#       },
#       {
#         "id": "urn:negotiation-message:50e29f00-c096-4e7b-9bf5-377bcabe91b4",
#         "negotiationAgentProcessId": "urn:negotiation-process:ed7adbb1-bc79-4740-9b46-fcbb10514a8e",
#         "createdAt": "2026-09-12T11:26:26.850985Z",
#         "direction": "OUTBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractNegotiationEventMessage",
#         "stateTransitionFrom": "OFFERED",
#         "stateTransitionTo": "ACCEPTED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractNegotiationEventMessage",
#           "consumerPid": "urn:consumer-pid:2c0de6f9-cefe-4653-97db-2076248745b6",
#           "providerPid": "urn:provider-pid:46d1e04c-e5bf-44c6-958f-28c86841a2ee"
#         }
#       }
#     ],
#     "offers": [
#       {
#         "id": "urn:offer:fe0bde40-ce78-4dd5-93ca-117b3f41075c",
#         "negotiationAgentProcessId": "urn:negotiation-process:ed7adbb1-bc79-4740-9b46-fcbb10514a8e",
#         "negotiationAgentMessageId": "urn:negotiation-message:297a6b3d-8189-4f13-a6e1-19f7d397c003",
#         "offerId": "urn:odrl-policy:ca61cbbd-f1ce-4c53-a6e8-645b57232c2b",
#         "offerContent": {
#           "@id": "urn:odrl-policy:ca61cbbd-f1ce-4c53-a6e8-645b57232c2b",
#           "@type": "Offer",
#           "permission": [
#             {
#               "action": "use",
#               "constraint": [
#                 {
#                   "leftOperand": "count",
#                   "operator": "gt",
#                   "rightOperand": "18"
#                 }
#               ]
#             }
#           ],
#           "target": "urn:dataset:afa2f634-93f2-4b0a-87eb-62a2a6c7965c"
#         },
#         "createdAt": "2026-09-12T11:26:26.342680Z"
#       },
#       {
#         "id": "urn:offer:b9adec6f-33e3-4e0b-8273-535162ef3de8",
#         "negotiationAgentProcessId": "urn:negotiation-process:ed7adbb1-bc79-4740-9b46-fcbb10514a8e",
#         "negotiationAgentMessageId": "urn:negotiation-message:225bffc5-debb-4e1f-a349-f74e3fe5576f",
#         "offerId": "urn:odrl-policy:ca61cbbd-f1ce-4c53-a6e8-645b57232c2b",
#         "offerContent": {
#           "@id": "urn:odrl-policy:ca61cbbd-f1ce-4c53-a6e8-645b57232c2b",
#           "@type": "Offer",
#           "permission": [
#             {
#               "action": "use",
#               "constraint": [
#                 {
#                   "leftOperand": "count",
#                   "operator": "gt",
#                   "rightOperand": "21"
#                 }
#               ]
#             }
#           ],
#           "target": "urn:dataset:afa2f634-93f2-4b0a-87eb-62a2a6c7965c"
#         },
#         "createdAt": "2026-09-12T11:26:26.407631Z"
#       },
#       {
#         "id": "urn:offer:de827a70-df2b-42af-8147-3b4049ae2682",
#         "negotiationAgentProcessId": "urn:negotiation-process:ed7adbb1-bc79-4740-9b46-fcbb10514a8e",
#         "negotiationAgentMessageId": "urn:negotiation-message:41d18832-df53-48e1-bd68-1e016c1fb798",
#         "offerId": "urn:odrl-policy:ca61cbbd-f1ce-4c53-a6e8-645b57232c2b",
#         "offerContent": {
#           "@id": "urn:odrl-policy:ca61cbbd-f1ce-4c53-a6e8-645b57232c2b",
#           "@type": "Offer",
#           "permission": [
#             {
#               "action": "use"
#             }
#           ],
#           "target": "urn:dataset:afa2f634-93f2-4b0a-87eb-62a2a6c7965c"
#         },
#         "createdAt": "2026-09-12T11:26:26.605539Z"
#       },
#       {
#         "id": "urn:offer:64120f07-6799-4e52-a274-f58e8c698a07",
#         "negotiationAgentProcessId": "urn:negotiation-process:ed7adbb1-bc79-4740-9b46-fcbb10514a8e",
#         "negotiationAgentMessageId": "urn:negotiation-message:048b3672-a1d5-4d81-9bdd-58307610c0b3",
#         "offerId": "urn:odrl-policy:ca61cbbd-f1ce-4c53-a6e8-645b57232c2b",
#         "offerContent": {
#           "@id": "urn:odrl-policy:ca61cbbd-f1ce-4c53-a6e8-645b57232c2b",
#           "@type": "Offer",
#           "permission": [
#             {
#               "action": "supermegause"
#             }
#           ],
#           "target": "urn:dataset:afa2f634-93f2-4b0a-87eb-62a2a6c7965c"
#         },
#         "createdAt": "2026-09-12T11:26:26.688744Z"
#       }
#     ],
#     "agreement": null
#   }
# }

# %% [markdown]
# ## Provider creates the Agreement (Provider -> Consumer)

# %%
url = data_space_provider + "/dsp/current/negotiations/rpc/setup-agreement"
payload = {
    "consumerPid": cn_consumer_id,
    "providerPid": cn_provider_id
}
response = requests.request("POST", url, headers=json_header, data=json.dumps(payload))
response_as_json = response.json()
try:
    print(json.dumps(response_as_json, indent=2))
except KeyError:
    print("Error in response, check the payload and the endpoint.")
    print(json.dumps(response_as_json, indent=2))
    raise
# Out:
# {
#   "request": {
#     "providerPid": "urn:provider-pid:46d1e04c-e5bf-44c6-958f-28c86841a2ee",
#     "consumerPid": "urn:consumer-pid:2c0de6f9-cefe-4653-97db-2076248745b6"
#   },
#   "response": {
#     "@context": [
#       "https://w3id.org/dspace/2025/1/context.jsonld"
#     ],
#     "@type": "ContractNegotiation",
#     "consumerPid": "urn:consumer-pid:2c0de6f9-cefe-4653-97db-2076248745b6",
#     "providerPid": "urn:provider-pid:46d1e04c-e5bf-44c6-958f-28c86841a2ee",
#     "state": "AGREED"
#   },
#   "negotiationAgentModel": {
#     "id": "urn:negotiation-process:51029669-e112-46c5-a683-1834a11f13e1",
#     "state": "AGREED",
#     "stateAttribute": null,
#     "associatedAgentPeer": "did:jwk:...",
#     "protocol": "DSP",
#     "callbackAddress": "http://127.0.0.1:1100/dsp/current",
#     "role": "Provider",
#     "properties": {},
#     "errorDetails": null,
#     "createdAt": "2026-09-12T11:26:26.184763Z",
#     "updatedAt": "2026-09-12T11:26:27.022991Z",
#     "identifiers": {
#       "providerPid": "urn:provider-pid:46d1e04c-e5bf-44c6-958f-28c86841a2ee",
#       "consumerPid": "urn:consumer-pid:2c0de6f9-cefe-4653-97db-2076248745b6"
#     },
#     "messages": [
#       {
#         "id": "urn:negotiation-message:d229cfae-0b6e-4494-876f-b82d71782a5f",
#         "negotiationAgentProcessId": "urn:negotiation-process:51029669-e112-46c5-a683-1834a11f13e1",
#         "createdAt": "2026-09-12T11:26:26.251132Z",
#         "direction": "INBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractRequestMessage",
#         "stateTransitionFrom": "-",
#         "stateTransitionTo": "REQUESTED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractRequestMessage",
#           "callbackAddress": "http://127.0.0.1:1100/dsp/current",
#           "consumerPid": "urn:consumer-pid:2c0de6f9-cefe-4653-97db-2076248745b6",
#           "offer": {
#             "@id": "urn:odrl-policy:ca61cbbd-f1ce-4c53-a6e8-645b57232c2b",
#             "@type": "Offer",
#             "permission": [
#               {
#                 "action": "use",
#                 "constraint": [
#                   {
#                     "leftOperand": "count",
#                     "operator": "gt",
#                     "rightOperand": "18"
#                   }
#                 ]
#               }
#             ],
#             "target": "urn:dataset:afa2f634-93f2-4b0a-87eb-62a2a6c7965c"
#           }
#         }
#       },
#       {
#         "id": "urn:negotiation-message:650daf08-11d0-4e6a-9aa2-5a53ebd57bc2",
#         "negotiationAgentProcessId": "urn:negotiation-process:51029669-e112-46c5-a683-1834a11f13e1",
#         "createdAt": "2026-09-12T11:26:26.430818Z",
#         "direction": "OUTBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractOfferMessage",
#         "stateTransitionFrom": "REQUESTED",
#         "stateTransitionTo": "OFFERED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractOfferMessage",
#           "consumerPid": "urn:consumer-pid:2c0de6f9-cefe-4653-97db-2076248745b6",
#           "offer": {
#             "@id": "urn:odrl-policy:ca61cbbd-f1ce-4c53-a6e8-645b57232c2b",
#             "@type": "Offer",
#             "permission": [
#               {
#                 "action": "use",
#                 "constraint": [
#                   {
#                     "leftOperand": "count",
#                     "operator": "gt",
#                     "rightOperand": "21"
#                   }
#                 ]
#               }
#             ],
#             "target": "urn:dataset:afa2f634-93f2-4b0a-87eb-62a2a6c7965c"
#           },
#           "providerPid": "urn:provider-pid:46d1e04c-e5bf-44c6-958f-28c86841a2ee"
#         }
#       },
#       {
#         "id": "urn:negotiation-message:f0e784c8-b4a7-4ca3-b21e-102c40c96cee",
#         "negotiationAgentProcessId": "urn:negotiation-process:51029669-e112-46c5-a683-1834a11f13e1",
#         "createdAt": "2026-09-12T11:26:26.568676Z",
#         "direction": "INBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractRequestMessage",
#         "stateTransitionFrom": "OFFERED",
#         "stateTransitionTo": "REQUESTED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractRequestMessage",
#           "consumerPid": "urn:consumer-pid:2c0de6f9-cefe-4653-97db-2076248745b6",
#           "offer": {
#             "@id": "urn:odrl-policy:ca61cbbd-f1ce-4c53-a6e8-645b57232c2b",
#             "@type": "Offer",
#             "permission": [
#               {
#                 "action": "use"
#               }
#             ],
#             "target": "urn:dataset:afa2f634-93f2-4b0a-87eb-62a2a6c7965c"
#           },
#           "providerPid": "urn:provider-pid:46d1e04c-e5bf-44c6-958f-28c86841a2ee"
#         }
#       },
#       {
#         "id": "urn:negotiation-message:06f46103-d2d1-46c9-99a6-2a379c2d42ed",
#         "negotiationAgentProcessId": "urn:negotiation-process:51029669-e112-46c5-a683-1834a11f13e1",
#         "createdAt": "2026-09-12T11:26:26.717874Z",
#         "direction": "OUTBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractOfferMessage",
#         "stateTransitionFrom": "REQUESTED",
#         "stateTransitionTo": "OFFERED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractOfferMessage",
#           "consumerPid": "urn:consumer-pid:2c0de6f9-cefe-4653-97db-2076248745b6",
#           "offer": {
#             "@id": "urn:odrl-policy:ca61cbbd-f1ce-4c53-a6e8-645b57232c2b",
#             "@type": "Offer",
#             "permission": [
#               {
#                 "action": "supermegause"
#               }
#             ],
#             "target": "urn:dataset:afa2f634-93f2-4b0a-87eb-62a2a6c7965c"
#           },
#           "providerPid": "urn:provider-pid:46d1e04c-e5bf-44c6-958f-28c86841a2ee"
#         }
#       },
#       {
#         "id": "urn:negotiation-message:58a146e5-46cf-48ab-b5e2-2d071a525ea7",
#         "negotiationAgentProcessId": "urn:negotiation-process:51029669-e112-46c5-a683-1834a11f13e1",
#         "createdAt": "2026-09-12T11:26:26.815485Z",
#         "direction": "INBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractNegotiationEventMessage",
#         "stateTransitionFrom": "OFFERED",
#         "stateTransitionTo": "ACCEPTED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractNegotiationEventMessage",
#           "consumerPid": "urn:consumer-pid:2c0de6f9-cefe-4653-97db-2076248745b6",
#           "eventType": "ACCEPTED",
#           "providerPid": "urn:provider-pid:46d1e04c-e5bf-44c6-958f-28c86841a2ee"
#         }
#       },
#       {
#         "id": "urn:negotiation-message:142e2045-8284-4078-b289-6382ee0b2b2f",
#         "negotiationAgentProcessId": "urn:negotiation-process:51029669-e112-46c5-a683-1834a11f13e1",
#         "createdAt": "2026-09-12T11:26:27.034238Z",
#         "direction": "OUTBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractAgreementMessage",
#         "stateTransitionFrom": "ACCEPTED",
#         "stateTransitionTo": "AGREED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractAgreementMessage",
#           "consumerPid": "urn:consumer-pid:2c0de6f9-cefe-4653-97db-2076248745b6",
#           "providerPid": "urn:provider-pid:46d1e04c-e5bf-44c6-958f-28c86841a2ee"
#         }
#       }
#     ],
#     "offers": [
#       {
#         "id": "urn:offer:7602fa53-6125-4524-98a4-b6cb592dc23d",
#         "negotiationAgentProcessId": "urn:negotiation-process:51029669-e112-46c5-a683-1834a11f13e1",
#         "negotiationAgentMessageId": "urn:negotiation-message:d229cfae-0b6e-4494-876f-b82d71782a5f",
#         "offerId": "urn:odrl-policy:ca61cbbd-f1ce-4c53-a6e8-645b57232c2b",
#         "offerContent": {
#           "@id": "urn:odrl-policy:ca61cbbd-f1ce-4c53-a6e8-645b57232c2b",
#           "@type": "Offer",
#           "permission": [
#             {
#               "action": "use",
#               "constraint": [
#                 {
#                   "leftOperand": "count",
#                   "operator": "gt",
#                   "rightOperand": "18"
#                 }
#               ]
#             }
#           ],
#           "target": "urn:dataset:afa2f634-93f2-4b0a-87eb-62a2a6c7965c"
#         },
#         "createdAt": "2026-09-12T11:26:26.257650Z"
#       },
#       {
#         "id": "urn:offer:4730c249-6ff6-41ec-8199-0dfae5552473",
#         "negotiationAgentProcessId": "urn:negotiation-process:51029669-e112-46c5-a683-1834a11f13e1",
#         "negotiationAgentMessageId": "urn:negotiation-message:650daf08-11d0-4e6a-9aa2-5a53ebd57bc2",
#         "offerId": "urn:odrl-policy:ca61cbbd-f1ce-4c53-a6e8-645b57232c2b",
#         "offerContent": {
#           "@id": "urn:odrl-policy:ca61cbbd-f1ce-4c53-a6e8-645b57232c2b",
#           "@type": "Offer",
#           "permission": [
#             {
#               "action": "use",
#               "constraint": [
#                 {
#                   "leftOperand": "count",
#                   "operator": "gt",
#                   "rightOperand": "21"
#                 }
#               ]
#             }
#           ],
#           "target": "urn:dataset:afa2f634-93f2-4b0a-87eb-62a2a6c7965c"
#         },
#         "createdAt": "2026-09-12T11:26:26.439594Z"
#       },
#       {
#         "id": "urn:offer:c47df020-6747-4ecb-bda8-7670ff1e5029",
#         "negotiationAgentProcessId": "urn:negotiation-process:51029669-e112-46c5-a683-1834a11f13e1",
#         "negotiationAgentMessageId": "urn:negotiation-message:f0e784c8-b4a7-4ca3-b21e-102c40c96cee",
#         "offerId": "urn:odrl-policy:ca61cbbd-f1ce-4c53-a6e8-645b57232c2b",
#         "offerContent": {
#           "@id": "urn:odrl-policy:ca61cbbd-f1ce-4c53-a6e8-645b57232c2b",
#           "@type": "Offer",
#           "permission": [
#             {
#               "action": "use"
#             }
#           ],
#           "target": "urn:dataset:afa2f634-93f2-4b0a-87eb-62a2a6c7965c"
#         },
#         "createdAt": "2026-09-12T11:26:26.573332Z"
#       },
#       {
#         "id": "urn:offer:c6892844-9689-4435-aa82-26ccbcb5eba9",
#         "negotiationAgentProcessId": "urn:negotiation-process:51029669-e112-46c5-a683-1834a11f13e1",
#         "negotiationAgentMessageId": "urn:negotiation-message:06f46103-d2d1-46c9-99a6-2a379c2d42ed",
#         "offerId": "urn:odrl-policy:ca61cbbd-f1ce-4c53-a6e8-645b57232c2b",
#         "offerContent": {
#           "@id": "urn:odrl-policy:ca61cbbd-f1ce-4c53-a6e8-645b57232c2b",
#           "@type": "Offer",
#           "permission": [
#             {
#               "action": "supermegause"
#             }
#           ],
#           "target": "urn:dataset:afa2f634-93f2-4b0a-87eb-62a2a6c7965c"
#         },
#         "createdAt": "2026-09-12T11:26:26.722064Z"
#       }
#     ],
#     "agreement": {
#       "id": "urn:agreement:ef6888b0-fad6-4422-a138-6efa1e9f9759",
#       "negotiationAgentProcessId": "urn:negotiation-process:51029669-e112-46c5-a683-1834a11f13e1",
#       "negotiationAgentMessageId": "urn:negotiation-message:142e2045-8284-4078-b289-6382ee0b2b2f",
#       "consumerParticipantId": "did:jwk:...",
#       "providerParticipantId": "did:jwk:...",
#       "agreementContent": {
#         "@id": "urn:agreement:ef6888b0-fad6-4422-a138-6efa1e9f9759",
#         "@type": "Agreement",
#         "assignee": "did:jwk:...",
#         "assigner": "did:jwk:...",
#         "permission": [
#           {
#             "action": "supermegause"
#           }
#         ],
#         "target": "urn:dataset:afa2f634-93f2-4b0a-87eb-62a2a6c7965c",
#         "timestamp": "1789212386"
#       },
#       "target": "urn:dataset:afa2f634-93f2-4b0a-87eb-62a2a6c7965c",
#       "state": "REQUESTED",
#       "createdAt": "2026-09-12T11:26:27.066709Z",
#       "updatedAt": null
#     }
#   }
# }

# %% [markdown]
# ## Consumer verifies the agreement (Consumer -> Provider)

# %%
url = data_space_consumer + "/dsp/current/negotiations/rpc/setup-verification"
payload = {
    "consumerPid": cn_consumer_id,
    "providerPid": cn_provider_id
}
response = requests.request("POST", url, headers=json_header, data=json.dumps(payload))
response_as_json = response.json()
try:
    print(json.dumps(response_as_json, indent=2))
except KeyError:
    print("Error in response, check the payload and the endpoint.")
    print(json.dumps(response_as_json, indent=2))
    raise
# Out:
# {
#   "request": {
#     "providerPid": "urn:provider-pid:46d1e04c-e5bf-44c6-958f-28c86841a2ee",
#     "consumerPid": "urn:consumer-pid:2c0de6f9-cefe-4653-97db-2076248745b6"
#   },
#   "response": {
#     "@context": [
#       "https://w3id.org/dspace/2025/1/context.jsonld"
#     ],
#     "@type": "ContractNegotiation",
#     "consumerPid": "urn:consumer-pid:2c0de6f9-cefe-4653-97db-2076248745b6",
#     "providerPid": "urn:provider-pid:46d1e04c-e5bf-44c6-958f-28c86841a2ee",
#     "state": "VERIFIED"
#   },
#   "negotiationAgentModel": {
#     "id": "urn:negotiation-process:ed7adbb1-bc79-4740-9b46-fcbb10514a8e",
#     "state": "VERIFIED",
#     "stateAttribute": null,
#     "associatedAgentPeer": "did:jwk:...",
#     "protocol": "DSP",
#     "callbackAddress": "http://127.0.0.1:1200/dsp/current",
#     "role": "Consumer",
#     "properties": {},
#     "errorDetails": null,
#     "createdAt": "2026-09-12T11:26:26.266189Z",
#     "updatedAt": "2026-09-12T11:26:27.205264Z",
#     "identifiers": {
#       "consumerPid": "urn:consumer-pid:2c0de6f9-cefe-4653-97db-2076248745b6",
#       "providerPid": "urn:provider-pid:46d1e04c-e5bf-44c6-958f-28c86841a2ee"
#     },
#     "messages": [
#       {
#         "id": "urn:negotiation-message:297a6b3d-8189-4f13-a6e1-19f7d397c003",
#         "negotiationAgentProcessId": "urn:negotiation-process:ed7adbb1-bc79-4740-9b46-fcbb10514a8e",
#         "createdAt": "2026-09-12T11:26:26.338285Z",
#         "direction": "OUTBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractRequestMessage",
#         "stateTransitionFrom": "-",
#         "stateTransitionTo": "REQUESTED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractRequestMessage",
#           "associatedAgentPeer": "did:jwk:...",
#           "callbackAddress": "http://127.0.0.1:1100/dsp/current",
#           "offer": {
#             "@id": "urn:odrl-policy:ca61cbbd-f1ce-4c53-a6e8-645b57232c2b",
#             "@type": "Offer",
#             "permission": [
#               {
#                 "action": "use",
#                 "constraint": [
#                   {
#                     "leftOperand": "count",
#                     "operator": "gt",
#                     "rightOperand": "18"
#                   }
#                 ]
#               }
#             ],
#             "target": "urn:dataset:afa2f634-93f2-4b0a-87eb-62a2a6c7965c"
#           },
#           "providerAddress": "http://127.0.0.1:1200/dsp/current"
#         }
#       },
#       {
#         "id": "urn:negotiation-message:225bffc5-debb-4e1f-a349-f74e3fe5576f",
#         "negotiationAgentProcessId": "urn:negotiation-process:ed7adbb1-bc79-4740-9b46-fcbb10514a8e",
#         "createdAt": "2026-09-12T11:26:26.401955Z",
#         "direction": "INBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractOfferMessage",
#         "stateTransitionFrom": "REQUESTED",
#         "stateTransitionTo": "OFFERED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractOfferMessage",
#           "consumerPid": "urn:consumer-pid:2c0de6f9-cefe-4653-97db-2076248745b6",
#           "offer": {
#             "@id": "urn:odrl-policy:ca61cbbd-f1ce-4c53-a6e8-645b57232c2b",
#             "@type": "Offer",
#             "permission": [
#               {
#                 "action": "use",
#                 "constraint": [
#                   {
#                     "leftOperand": "count",
#                     "operator": "gt",
#                     "rightOperand": "21"
#                   }
#                 ]
#               }
#             ],
#             "target": "urn:dataset:afa2f634-93f2-4b0a-87eb-62a2a6c7965c"
#           },
#           "providerPid": "urn:provider-pid:46d1e04c-e5bf-44c6-958f-28c86841a2ee"
#         }
#       },
#       {
#         "id": "urn:negotiation-message:41d18832-df53-48e1-bd68-1e016c1fb798",
#         "negotiationAgentProcessId": "urn:negotiation-process:ed7adbb1-bc79-4740-9b46-fcbb10514a8e",
#         "createdAt": "2026-09-12T11:26:26.596661Z",
#         "direction": "OUTBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractRequestMessage",
#         "stateTransitionFrom": "OFFERED",
#         "stateTransitionTo": "REQUESTED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractRequestMessage",
#           "consumerPid": "urn:consumer-pid:2c0de6f9-cefe-4653-97db-2076248745b6",
#           "offer": {
#             "@id": "urn:odrl-policy:ca61cbbd-f1ce-4c53-a6e8-645b57232c2b",
#             "@type": "Offer",
#             "permission": [
#               {
#                 "action": "use"
#               }
#             ],
#             "target": "urn:dataset:afa2f634-93f2-4b0a-87eb-62a2a6c7965c"
#           },
#           "providerPid": "urn:provider-pid:46d1e04c-e5bf-44c6-958f-28c86841a2ee"
#         }
#       },
#       {
#         "id": "urn:negotiation-message:048b3672-a1d5-4d81-9bdd-58307610c0b3",
#         "negotiationAgentProcessId": "urn:negotiation-process:ed7adbb1-bc79-4740-9b46-fcbb10514a8e",
#         "createdAt": "2026-09-12T11:26:26.682618Z",
#         "direction": "INBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractOfferMessage",
#         "stateTransitionFrom": "REQUESTED",
#         "stateTransitionTo": "OFFERED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractOfferMessage",
#           "consumerPid": "urn:consumer-pid:2c0de6f9-cefe-4653-97db-2076248745b6",
#           "offer": {
#             "@id": "urn:odrl-policy:ca61cbbd-f1ce-4c53-a6e8-645b57232c2b",
#             "@type": "Offer",
#             "permission": [
#               {
#                 "action": "supermegause"
#               }
#             ],
#             "target": "urn:dataset:afa2f634-93f2-4b0a-87eb-62a2a6c7965c"
#           },
#           "providerPid": "urn:provider-pid:46d1e04c-e5bf-44c6-958f-28c86841a2ee"
#         }
#       },
#       {
#         "id": "urn:negotiation-message:50e29f00-c096-4e7b-9bf5-377bcabe91b4",
#         "negotiationAgentProcessId": "urn:negotiation-process:ed7adbb1-bc79-4740-9b46-fcbb10514a8e",
#         "createdAt": "2026-09-12T11:26:26.850985Z",
#         "direction": "OUTBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractNegotiationEventMessage",
#         "stateTransitionFrom": "OFFERED",
#         "stateTransitionTo": "ACCEPTED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractNegotiationEventMessage",
#           "consumerPid": "urn:consumer-pid:2c0de6f9-cefe-4653-97db-2076248745b6",
#           "providerPid": "urn:provider-pid:46d1e04c-e5bf-44c6-958f-28c86841a2ee"
#         }
#       },
#       {
#         "id": "urn:negotiation-message:2e566975-662f-4832-8747-1aa318eba482",
#         "negotiationAgentProcessId": "urn:negotiation-process:ed7adbb1-bc79-4740-9b46-fcbb10514a8e",
#         "createdAt": "2026-09-12T11:26:26.987026Z",
#         "direction": "INBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractAgreementMessage",
#         "stateTransitionFrom": "ACCEPTED",
#         "stateTransitionTo": "AGREED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractAgreementMessage",
#           "agreement": {
#             "@id": "urn:agreement:ef6888b0-fad6-4422-a138-6efa1e9f9759",
#             "@type": "Agreement",
#             "assignee": "did:jwk:...",
#             "assigner": "did:jwk:...",
#             "permission": [
#               {
#                 "action": "supermegause"
#               }
#             ],
#             "target": "urn:dataset:afa2f634-93f2-4b0a-87eb-62a2a6c7965c",
#             "timestamp": "1789212386"
#           },
#           "consumerPid": "urn:consumer-pid:2c0de6f9-cefe-4653-97db-2076248745b6",
#           "providerPid": "urn:provider-pid:46d1e04c-e5bf-44c6-958f-28c86841a2ee"
#         }
#       },
#       {
#         "id": "urn:negotiation-message:6bc5c54f-b733-4351-af64-60a173ab2d39",
#         "negotiationAgentProcessId": "urn:negotiation-process:ed7adbb1-bc79-4740-9b46-fcbb10514a8e",
#         "createdAt": "2026-09-12T11:26:27.229509Z",
#         "direction": "OUTBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractAgreementVerificationMessage",
#         "stateTransitionFrom": "AGREED",
#         "stateTransitionTo": "VERIFIED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractAgreementVerificationMessage",
#           "consumerPid": "urn:consumer-pid:2c0de6f9-cefe-4653-97db-2076248745b6",
#           "providerPid": "urn:provider-pid:46d1e04c-e5bf-44c6-958f-28c86841a2ee"
#         }
#       }
#     ],
#     "offers": [
#       {
#         "id": "urn:offer:fe0bde40-ce78-4dd5-93ca-117b3f41075c",
#         "negotiationAgentProcessId": "urn:negotiation-process:ed7adbb1-bc79-4740-9b46-fcbb10514a8e",
#         "negotiationAgentMessageId": "urn:negotiation-message:297a6b3d-8189-4f13-a6e1-19f7d397c003",
#         "offerId": "urn:odrl-policy:ca61cbbd-f1ce-4c53-a6e8-645b57232c2b",
#         "offerContent": {
#           "@id": "urn:odrl-policy:ca61cbbd-f1ce-4c53-a6e8-645b57232c2b",
#           "@type": "Offer",
#           "permission": [
#             {
#               "action": "use",
#               "constraint": [
#                 {
#                   "leftOperand": "count",
#                   "operator": "gt",
#                   "rightOperand": "18"
#                 }
#               ]
#             }
#           ],
#           "target": "urn:dataset:afa2f634-93f2-4b0a-87eb-62a2a6c7965c"
#         },
#         "createdAt": "2026-09-12T11:26:26.342680Z"
#       },
#       {
#         "id": "urn:offer:b9adec6f-33e3-4e0b-8273-535162ef3de8",
#         "negotiationAgentProcessId": "urn:negotiation-process:ed7adbb1-bc79-4740-9b46-fcbb10514a8e",
#         "negotiationAgentMessageId": "urn:negotiation-message:225bffc5-debb-4e1f-a349-f74e3fe5576f",
#         "offerId": "urn:odrl-policy:ca61cbbd-f1ce-4c53-a6e8-645b57232c2b",
#         "offerContent": {
#           "@id": "urn:odrl-policy:ca61cbbd-f1ce-4c53-a6e8-645b57232c2b",
#           "@type": "Offer",
#           "permission": [
#             {
#               "action": "use",
#               "constraint": [
#                 {
#                   "leftOperand": "count",
#                   "operator": "gt",
#                   "rightOperand": "21"
#                 }
#               ]
#             }
#           ],
#           "target": "urn:dataset:afa2f634-93f2-4b0a-87eb-62a2a6c7965c"
#         },
#         "createdAt": "2026-09-12T11:26:26.407631Z"
#       },
#       {
#         "id": "urn:offer:de827a70-df2b-42af-8147-3b4049ae2682",
#         "negotiationAgentProcessId": "urn:negotiation-process:ed7adbb1-bc79-4740-9b46-fcbb10514a8e",
#         "negotiationAgentMessageId": "urn:negotiation-message:41d18832-df53-48e1-bd68-1e016c1fb798",
#         "offerId": "urn:odrl-policy:ca61cbbd-f1ce-4c53-a6e8-645b57232c2b",
#         "offerContent": {
#           "@id": "urn:odrl-policy:ca61cbbd-f1ce-4c53-a6e8-645b57232c2b",
#           "@type": "Offer",
#           "permission": [
#             {
#               "action": "use"
#             }
#           ],
#           "target": "urn:dataset:afa2f634-93f2-4b0a-87eb-62a2a6c7965c"
#         },
#         "createdAt": "2026-09-12T11:26:26.605539Z"
#       },
#       {
#         "id": "urn:offer:64120f07-6799-4e52-a274-f58e8c698a07",
#         "negotiationAgentProcessId": "urn:negotiation-process:ed7adbb1-bc79-4740-9b46-fcbb10514a8e",
#         "negotiationAgentMessageId": "urn:negotiation-message:048b3672-a1d5-4d81-9bdd-58307610c0b3",
#         "offerId": "urn:odrl-policy:ca61cbbd-f1ce-4c53-a6e8-645b57232c2b",
#         "offerContent": {
#           "@id": "urn:odrl-policy:ca61cbbd-f1ce-4c53-a6e8-645b57232c2b",
#           "@type": "Offer",
#           "permission": [
#             {
#               "action": "supermegause"
#             }
#           ],
#           "target": "urn:dataset:afa2f634-93f2-4b0a-87eb-62a2a6c7965c"
#         },
#         "createdAt": "2026-09-12T11:26:26.688744Z"
#       }
#     ],
#     "agreement": {
#       "id": "urn:agreement:ef6888b0-fad6-4422-a138-6efa1e9f9759",
#       "negotiationAgentProcessId": "urn:negotiation-process:ed7adbb1-bc79-4740-9b46-fcbb10514a8e",
#       "negotiationAgentMessageId": "urn:negotiation-message:2e566975-662f-4832-8747-1aa318eba482",
#       "consumerParticipantId": "did:jwk:...",
#       "providerParticipantId": "did:jwk:...",
#       "agreementContent": {
#         "@id": "urn:agreement:ef6888b0-fad6-4422-a138-6efa1e9f9759",
#         "@type": "Agreement",
#         "assignee": "did:jwk:...",
#         "assigner": "did:jwk:...",
#         "permission": [
#           {
#             "action": "supermegause"
#           }
#         ],
#         "target": "urn:dataset:afa2f634-93f2-4b0a-87eb-62a2a6c7965c",
#         "timestamp": "1789212386"
#       },
#       "target": "urn:dataset:afa2f634-93f2-4b0a-87eb-62a2a6c7965c",
#       "state": "ACTIVE",
#       "createdAt": "2026-09-12T11:26:27.003459Z",
#       "updatedAt": "2026-09-12T11:26:27.241661Z"
#     }
#   }
# }

# %% [markdown]
# ## Provider finalizes the negotiation (Provider -> Consumer)

# %%
url = data_space_provider + "/dsp/current/negotiations/rpc/setup-finalization"
payload = {
    "consumerPid": cn_consumer_id,
    "providerPid": cn_provider_id
}
response = requests.request("POST", url, headers=json_header, data=json.dumps(payload))
response_as_json = response.json()
try:
    agreement = response_as_json
    agreement_id = response_as_json["negotiationAgentModel"]["agreement"]["id"]
    print(json.dumps(response_as_json, indent=2))
except KeyError:
    print("Error in response, check the payload and the endpoint.")
    print(json.dumps(response_as_json, indent=2))
    raise
# Out:
# {
#   "request": {
#     "providerPid": "urn:provider-pid:46d1e04c-e5bf-44c6-958f-28c86841a2ee",
#     "consumerPid": "urn:consumer-pid:2c0de6f9-cefe-4653-97db-2076248745b6"
#   },
#   "response": {
#     "@context": [
#       "https://w3id.org/dspace/2025/1/context.jsonld"
#     ],
#     "@type": "ContractNegotiation",
#     "consumerPid": "urn:consumer-pid:2c0de6f9-cefe-4653-97db-2076248745b6",
#     "providerPid": "urn:provider-pid:46d1e04c-e5bf-44c6-958f-28c86841a2ee",
#     "state": "FINALIZED"
#   },
#   "negotiationAgentModel": {
#     "id": "urn:negotiation-process:51029669-e112-46c5-a683-1834a11f13e1",
#     "state": "FINALIZED",
#     "stateAttribute": null,
#     "associatedAgentPeer": "did:jwk:...",
#     "protocol": "DSP",
#     "callbackAddress": "http://127.0.0.1:1100/dsp/current",
#     "role": "Provider",
#     "properties": {},
#     "errorDetails": null,
#     "createdAt": "2026-09-12T11:26:26.184763Z",
#     "updatedAt": "2026-09-12T11:26:27.360111Z",
#     "identifiers": {
#       "consumerPid": "urn:consumer-pid:2c0de6f9-cefe-4653-97db-2076248745b6",
#       "providerPid": "urn:provider-pid:46d1e04c-e5bf-44c6-958f-28c86841a2ee"
#     },
#     "messages": [
#       {
#         "id": "urn:negotiation-message:d229cfae-0b6e-4494-876f-b82d71782a5f",
#         "negotiationAgentProcessId": "urn:negotiation-process:51029669-e112-46c5-a683-1834a11f13e1",
#         "createdAt": "2026-09-12T11:26:26.251132Z",
#         "direction": "INBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractRequestMessage",
#         "stateTransitionFrom": "-",
#         "stateTransitionTo": "REQUESTED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractRequestMessage",
#           "callbackAddress": "http://127.0.0.1:1100/dsp/current",
#           "consumerPid": "urn:consumer-pid:2c0de6f9-cefe-4653-97db-2076248745b6",
#           "offer": {
#             "@id": "urn:odrl-policy:ca61cbbd-f1ce-4c53-a6e8-645b57232c2b",
#             "@type": "Offer",
#             "permission": [
#               {
#                 "action": "use",
#                 "constraint": [
#                   {
#                     "leftOperand": "count",
#                     "operator": "gt",
#                     "rightOperand": "18"
#                   }
#                 ]
#               }
#             ],
#             "target": "urn:dataset:afa2f634-93f2-4b0a-87eb-62a2a6c7965c"
#           }
#         }
#       },
#       {
#         "id": "urn:negotiation-message:650daf08-11d0-4e6a-9aa2-5a53ebd57bc2",
#         "negotiationAgentProcessId": "urn:negotiation-process:51029669-e112-46c5-a683-1834a11f13e1",
#         "createdAt": "2026-09-12T11:26:26.430818Z",
#         "direction": "OUTBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractOfferMessage",
#         "stateTransitionFrom": "REQUESTED",
#         "stateTransitionTo": "OFFERED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractOfferMessage",
#           "consumerPid": "urn:consumer-pid:2c0de6f9-cefe-4653-97db-2076248745b6",
#           "offer": {
#             "@id": "urn:odrl-policy:ca61cbbd-f1ce-4c53-a6e8-645b57232c2b",
#             "@type": "Offer",
#             "permission": [
#               {
#                 "action": "use",
#                 "constraint": [
#                   {
#                     "leftOperand": "count",
#                     "operator": "gt",
#                     "rightOperand": "21"
#                   }
#                 ]
#               }
#             ],
#             "target": "urn:dataset:afa2f634-93f2-4b0a-87eb-62a2a6c7965c"
#           },
#           "providerPid": "urn:provider-pid:46d1e04c-e5bf-44c6-958f-28c86841a2ee"
#         }
#       },
#       {
#         "id": "urn:negotiation-message:f0e784c8-b4a7-4ca3-b21e-102c40c96cee",
#         "negotiationAgentProcessId": "urn:negotiation-process:51029669-e112-46c5-a683-1834a11f13e1",
#         "createdAt": "2026-09-12T11:26:26.568676Z",
#         "direction": "INBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractRequestMessage",
#         "stateTransitionFrom": "OFFERED",
#         "stateTransitionTo": "REQUESTED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractRequestMessage",
#           "consumerPid": "urn:consumer-pid:2c0de6f9-cefe-4653-97db-2076248745b6",
#           "offer": {
#             "@id": "urn:odrl-policy:ca61cbbd-f1ce-4c53-a6e8-645b57232c2b",
#             "@type": "Offer",
#             "permission": [
#               {
#                 "action": "use"
#               }
#             ],
#             "target": "urn:dataset:afa2f634-93f2-4b0a-87eb-62a2a6c7965c"
#           },
#           "providerPid": "urn:provider-pid:46d1e04c-e5bf-44c6-958f-28c86841a2ee"
#         }
#       },
#       {
#         "id": "urn:negotiation-message:06f46103-d2d1-46c9-99a6-2a379c2d42ed",
#         "negotiationAgentProcessId": "urn:negotiation-process:51029669-e112-46c5-a683-1834a11f13e1",
#         "createdAt": "2026-09-12T11:26:26.717874Z",
#         "direction": "OUTBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractOfferMessage",
#         "stateTransitionFrom": "REQUESTED",
#         "stateTransitionTo": "OFFERED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractOfferMessage",
#           "consumerPid": "urn:consumer-pid:2c0de6f9-cefe-4653-97db-2076248745b6",
#           "offer": {
#             "@id": "urn:odrl-policy:ca61cbbd-f1ce-4c53-a6e8-645b57232c2b",
#             "@type": "Offer",
#             "permission": [
#               {
#                 "action": "supermegause"
#               }
#             ],
#             "target": "urn:dataset:afa2f634-93f2-4b0a-87eb-62a2a6c7965c"
#           },
#           "providerPid": "urn:provider-pid:46d1e04c-e5bf-44c6-958f-28c86841a2ee"
#         }
#       },
#       {
#         "id": "urn:negotiation-message:58a146e5-46cf-48ab-b5e2-2d071a525ea7",
#         "negotiationAgentProcessId": "urn:negotiation-process:51029669-e112-46c5-a683-1834a11f13e1",
#         "createdAt": "2026-09-12T11:26:26.815485Z",
#         "direction": "INBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractNegotiationEventMessage",
#         "stateTransitionFrom": "OFFERED",
#         "stateTransitionTo": "ACCEPTED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractNegotiationEventMessage",
#           "consumerPid": "urn:consumer-pid:2c0de6f9-cefe-4653-97db-2076248745b6",
#           "eventType": "ACCEPTED",
#           "providerPid": "urn:provider-pid:46d1e04c-e5bf-44c6-958f-28c86841a2ee"
#         }
#       },
#       {
#         "id": "urn:negotiation-message:142e2045-8284-4078-b289-6382ee0b2b2f",
#         "negotiationAgentProcessId": "urn:negotiation-process:51029669-e112-46c5-a683-1834a11f13e1",
#         "createdAt": "2026-09-12T11:26:27.034238Z",
#         "direction": "OUTBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractAgreementMessage",
#         "stateTransitionFrom": "ACCEPTED",
#         "stateTransitionTo": "AGREED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractAgreementMessage",
#           "consumerPid": "urn:consumer-pid:2c0de6f9-cefe-4653-97db-2076248745b6",
#           "providerPid": "urn:provider-pid:46d1e04c-e5bf-44c6-958f-28c86841a2ee"
#         }
#       },
#       {
#         "id": "urn:negotiation-message:5c5e48a2-2355-41d7-a60d-16db73d9549f",
#         "negotiationAgentProcessId": "urn:negotiation-process:51029669-e112-46c5-a683-1834a11f13e1",
#         "createdAt": "2026-09-12T11:26:27.156101Z",
#         "direction": "INBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractAgreementVerificationMessage",
#         "stateTransitionFrom": "AGREED",
#         "stateTransitionTo": "VERIFIED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractAgreementVerificationMessage",
#           "consumerPid": "urn:consumer-pid:2c0de6f9-cefe-4653-97db-2076248745b6",
#           "providerPid": "urn:provider-pid:46d1e04c-e5bf-44c6-958f-28c86841a2ee"
#         }
#       },
#       {
#         "id": "urn:negotiation-message:a35cd05f-fc86-486d-9929-b93ae234af5f",
#         "negotiationAgentProcessId": "urn:negotiation-process:51029669-e112-46c5-a683-1834a11f13e1",
#         "createdAt": "2026-09-12T11:26:27.373732Z",
#         "direction": "OUTBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractNegotiationEventMessage",
#         "stateTransitionFrom": "VERIFIED",
#         "stateTransitionTo": "FINALIZED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractNegotiationEventMessage",
#           "consumerPid": "urn:consumer-pid:2c0de6f9-cefe-4653-97db-2076248745b6",
#           "providerPid": "urn:provider-pid:46d1e04c-e5bf-44c6-958f-28c86841a2ee"
#         }
#       }
#     ],
#     "offers": [
#       {
#         "id": "urn:offer:7602fa53-6125-4524-98a4-b6cb592dc23d",
#         "negotiationAgentProcessId": "urn:negotiation-process:51029669-e112-46c5-a683-1834a11f13e1",
#         "negotiationAgentMessageId": "urn:negotiation-message:d229cfae-0b6e-4494-876f-b82d71782a5f",
#         "offerId": "urn:odrl-policy:ca61cbbd-f1ce-4c53-a6e8-645b57232c2b",
#         "offerContent": {
#           "@id": "urn:odrl-policy:ca61cbbd-f1ce-4c53-a6e8-645b57232c2b",
#           "@type": "Offer",
#           "permission": [
#             {
#               "action": "use",
#               "constraint": [
#                 {
#                   "leftOperand": "count",
#                   "operator": "gt",
#                   "rightOperand": "18"
#                 }
#               ]
#             }
#           ],
#           "target": "urn:dataset:afa2f634-93f2-4b0a-87eb-62a2a6c7965c"
#         },
#         "createdAt": "2026-09-12T11:26:26.257650Z"
#       },
#       {
#         "id": "urn:offer:4730c249-6ff6-41ec-8199-0dfae5552473",
#         "negotiationAgentProcessId": "urn:negotiation-process:51029669-e112-46c5-a683-1834a11f13e1",
#         "negotiationAgentMessageId": "urn:negotiation-message:650daf08-11d0-4e6a-9aa2-5a53ebd57bc2",
#         "offerId": "urn:odrl-policy:ca61cbbd-f1ce-4c53-a6e8-645b57232c2b",
#         "offerContent": {
#           "@id": "urn:odrl-policy:ca61cbbd-f1ce-4c53-a6e8-645b57232c2b",
#           "@type": "Offer",
#           "permission": [
#             {
#               "action": "use",
#               "constraint": [
#                 {
#                   "leftOperand": "count",
#                   "operator": "gt",
#                   "rightOperand": "21"
#                 }
#               ]
#             }
#           ],
#           "target": "urn:dataset:afa2f634-93f2-4b0a-87eb-62a2a6c7965c"
#         },
#         "createdAt": "2026-09-12T11:26:26.439594Z"
#       },
#       {
#         "id": "urn:offer:c47df020-6747-4ecb-bda8-7670ff1e5029",
#         "negotiationAgentProcessId": "urn:negotiation-process:51029669-e112-46c5-a683-1834a11f13e1",
#         "negotiationAgentMessageId": "urn:negotiation-message:f0e784c8-b4a7-4ca3-b21e-102c40c96cee",
#         "offerId": "urn:odrl-policy:ca61cbbd-f1ce-4c53-a6e8-645b57232c2b",
#         "offerContent": {
#           "@id": "urn:odrl-policy:ca61cbbd-f1ce-4c53-a6e8-645b57232c2b",
#           "@type": "Offer",
#           "permission": [
#             {
#               "action": "use"
#             }
#           ],
#           "target": "urn:dataset:afa2f634-93f2-4b0a-87eb-62a2a6c7965c"
#         },
#         "createdAt": "2026-09-12T11:26:26.573332Z"
#       },
#       {
#         "id": "urn:offer:c6892844-9689-4435-aa82-26ccbcb5eba9",
#         "negotiationAgentProcessId": "urn:negotiation-process:51029669-e112-46c5-a683-1834a11f13e1",
#         "negotiationAgentMessageId": "urn:negotiation-message:06f46103-d2d1-46c9-99a6-2a379c2d42ed",
#         "offerId": "urn:odrl-policy:ca61cbbd-f1ce-4c53-a6e8-645b57232c2b",
#         "offerContent": {
#           "@id": "urn:odrl-policy:ca61cbbd-f1ce-4c53-a6e8-645b57232c2b",
#           "@type": "Offer",
#           "permission": [
#             {
#               "action": "supermegause"
#             }
#           ],
#           "target": "urn:dataset:afa2f634-93f2-4b0a-87eb-62a2a6c7965c"
#         },
#         "createdAt": "2026-09-12T11:26:26.722064Z"
#       }
#     ],
#     "agreement": {
#       "id": "urn:agreement:ef6888b0-fad6-4422-a138-6efa1e9f9759",
#       "negotiationAgentProcessId": "urn:negotiation-process:51029669-e112-46c5-a683-1834a11f13e1",
#       "negotiationAgentMessageId": "urn:negotiation-message:142e2045-8284-4078-b289-6382ee0b2b2f",
#       "consumerParticipantId": "did:jwk:...",
#       "providerParticipantId": "did:jwk:...",
#       "agreementContent": {
#         "@id": "urn:agreement:ef6888b0-fad6-4422-a138-6efa1e9f9759",
#         "@type": "Agreement",
#         "assignee": "did:jwk:...",
#         "assigner": "did:jwk:...",
#         "permission": [
#           {
#             "action": "supermegause"
#           }
#         ],
#         "target": "urn:dataset:afa2f634-93f2-4b0a-87eb-62a2a6c7965c",
#         "timestamp": "1789212386"
#       },
#       "target": "urn:dataset:afa2f634-93f2-4b0a-87eb-62a2a6c7965c",
#       "state": "ACTIVE",
#       "createdAt": "2026-09-12T11:26:27.066709Z",
#       "updatedAt": "2026-09-12T11:26:27.379866Z"
#     }
#   }
# }

# %% [markdown]
# ## Final agreement

# %%
print("Final agreement: \n{}\n".format(json.dumps(agreement["negotiationAgentModel"]["agreement"], indent=2)))
print("Final agreement id: \n{}\n".format(agreement_id))
# Out:
# Final agreement:
# {
#   "id": "urn:agreement:ef6888b0-fad6-4422-a138-6efa1e9f9759",
#   "negotiationAgentProcessId": "urn:negotiation-process:51029669-e112-46c5-a683-1834a11f13e1",
#   "negotiationAgentMessageId": "urn:negotiation-message:142e2045-8284-4078-b289-6382ee0b2b2f",
#   "consumerParticipantId": "did:jwk:...",
#   "providerParticipantId": "did:jwk:...",
#   "agreementContent": {
#     "@id": "urn:agreement:ef6888b0-fad6-4422-a138-6efa1e9f9759",
#     "@type": "Agreement",
#     "assignee": "did:jwk:...",
#     "assigner": "did:jwk:...",
#     "permission": [
#       {
#         "action": "supermegause"
#       }
#     ],
#     "target": "urn:dataset:afa2f634-93f2-4b0a-87eb-62a2a6c7965c",
#     "timestamp": "1789212386"
#   },
#   "target": "urn:dataset:afa2f634-93f2-4b0a-87eb-62a2a6c7965c",
#   "state": "ACTIVE",
#   "createdAt": "2026-09-12T11:26:27.066709Z",
#   "updatedAt": "2026-09-12T11:26:27.379866Z"
# }
#
# Final agreement id:
# urn:agreement:ef6888b0-fad6-4422-a138-6efa1e9f9759

# %% [markdown]
# # Transfer Negotiation with Agents

# %% [markdown]
# ## Transfer request setup (Consumer -> Provider)

# %%
url = data_space_provider + "/dsp/current/transfers/request"
payload = {
  "@context": [
    "https://w3id.org/dspace/2025/1/context.jsonld"
  ],
  "@type": "TransferRequestMessage",
  "consumerPid": "urn:uuid:32541fe6-c580-409e-85a8-8a9a32fbe833",
  "agreementId": "urn:uuid:e8dc8655-44c2-46ef-b701-4cffdc2faa44",
  "format": "example:HTTP_PUSH",
  "dataAddress": {
    "@type": "DataAddress",
    "endpointType": "https://w3id.org/idsa/v4.1/HTTP",
    "endpoint": "http://example.com",
    "endpointProperties": [
      {
        "@type": "EndpointProperty",
        "name": "authorization",
        "value": "TOKEN-ABCDEFG"
      },
      {
        "@type": "EndpointProperty",
        "name": "authType",
        "value": "bearer"
      }
    ]
  },
  "callbackAddress": "https://example.com/callback"
}

response = requests.request("POST", url, headers={
    "Content-Type": "application/json",
    "Authorization": "Bearer akuTZ784tLl7j96fX09XjK8ACYhdReuR4QHzfLClQP4"
}, data=json.dumps(payload))
response_as_text = response.text
response_as_text
# Out:
# ''

# %%
url = data_space_provider + "/dsp/current/transfers/request"
payload = {
  "@context": "https://w3id.org/dspace/2025/1/context.jsonld",
  "@graph": [
    {
      "@id": "_:msg",
      "@type": "TransferRequestMessage",
      "consumerPid": "urn:uuid:32541fe6-c580-409e-85a8-8a9a32fbe833",
      "agreementId": "urn:uuid:e8dc8655-44c2-46ef-b701-4cffdc2faa44",
      "format": "example:HTTP_PUSH",
      "callbackAddress": "https://example.com/callback",
      "dataAddress": { "@id": "_:addr" }
    },
    {
      "@id": "_:addr",
      "@type": "DataAddress",
      "endpointType": "https://w3id.org/idsa/v4.1/HTTP",
      "endpoint": "http://example.com",
      "endpointProperties": [{ "@id": "_:p1" }, { "@id": "_:p2" }]
    },
    { "@id": "_:p1", "@type": "EndpointProperty", "name": "authorization", "value": "TOKEN-ABCDEFG" },
    { "@id": "_:p2", "@type": "EndpointProperty", "name": "authType", "value": "bearer" }
  ]
}

response = requests.request("POST", url, headers={
    "Content-Type": "application/json",
    "Authorization": "Bearer akuTZ784tLl7j96fX09XjK8ACYhdReuR4QHzfLClQP4"
}, data=json.dumps(payload))
response_as_text = response.text
response_as_text
# Out:
# ''

# %%
url = data_space_provider + "/dsp/current/transfers/asd/start"
payload = [
  {
    "@type": ["https://w3id.org/dspace/2025/1/TransferRequestMessage"],
    "https://w3id.org/dspace/2025/1/consumerPid": [
      { "@id": "urn:uuid:32541fe6-c580-409e-85a8-8a9a32fbe833" }
    ],
    "https://w3id.org/dspace/2025/1/agreementId": [
      { "@id": "urn:uuid:e8dc8655-44c2-46ef-b701-4cffdc2faa44" }
    ],
    "http://purl.org/dc/terms/format": [
      { "@id": "example:HTTP_PUSH" }
    ],
    "https://w3id.org/dspace/2025/1/callbackAddress": [
      { "@value": "https://example.com/callback" }
    ],
    "https://w3id.org/dspace/2025/1/dataAddress": [
      {
        "@type": ["https://w3id.org/dspace/2025/1/DataAddress"],
        "https://w3id.org/dspace/2025/1/endpointType": [
          { "@id": "https://w3id.org/idsa/v4.1/HTTP" }
        ],
        "https://w3id.org/dspace/2025/1/endpoint": [
          { "@value": "http://example.com" }
        ],
        "https://w3id.org/dspace/2025/1/endpointProperties": [
          {
            "@type": ["https://w3id.org/dspace/2025/1/EndpointProperty"],
            "https://w3id.org/dspace/2025/1/name": [{ "@value": "authorization" }],
            "https://w3id.org/dspace/2025/1/value": [{ "@value": "TOKEN-ABCDEFG" }]
          },
          {
            "@type": ["https://w3id.org/dspace/2025/1/EndpointProperty"],
            "https://w3id.org/dspace/2025/1/name": [{ "@value": "authType" }],
            "https://w3id.org/dspace/2025/1/value": [{ "@value": "bearer" }]
          }
        ]
      }
    ]
  }
]

response = requests.request("POST", url, headers={
    "Content-Type": "application/json",
    "Authorization": "Bearer akuTZ784tLl7j96fX09XjK8ACYhdReuR4QHzfLClQP4"
}, data=json.dumps(payload))
response_as_text = response.text
response_as_text
# Out:
# ''
